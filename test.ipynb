# %% [markdown]
# ### **[Imports]**

# %%
import requests
from bs4 import BeautifulSoup 
import csv
from datetime import datetime

# 전체 크롤링
import os
import time
import random

# %%
response = requests.get("https://www.spnews.co.kr/news/articleView.html?idxno=101229")  
soup = BeautifulSoup(response.text, 'html.parser') 
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-mobile="false" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=1080" name="viewport"/>
# <meta content="SPN 서울평양뉴스" name="apple-mobile-web-app-title">
# <meta content="max-image-preview:large" name="robots"/>
# <!-- 메타태그정보 //-->
# <link as="image" href="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" rel="preload"/>
# <meta content="[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공 - SPN 서울평양뉴스" name="title">
# <meta content='북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.노동신문은 12일 "수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생' name="description">
# <meta content="북한N &gt; 경제/산업" name="Classification">
# <meta content="SPN 서울평양뉴스" name="Copyright"/>
# <meta content="안윤석 대기자" name="author"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="SPN 서울평양뉴스" property="og:site_name"/>
# <meta content="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.spnews.co.kr/news/articleView.html?idxno=101229" property="og:url"/>
# <meta content="[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공 - SPN 서울평양뉴스" property="og:title"/>
# <meta content='북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.노동신문은 12일 "수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생' property="og:description"/>
# <meta content="안윤석 대기자" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공 - SPN 서울평양뉴스" name="twitter:title"/>
# <meta content='북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.노동신문은 12일 "수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생' name="twitter:description"/>
# <meta content="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" name="twitter:image"/>
# <meta content="https://www.spnews.co.kr/news/articleView.html?idxno=101229" name="twitter:site"/>
# <meta content="안윤석 대기자" name="twitter:creator"/>
# <meta content="101229" property="dable:item_id"/>
# <meta content="안윤석 대기자" property="dable:author"/>
# <meta content="북한N" property="article:section"/>
# <meta content="경제/산업" property="article:section1"/>
# <meta content="2025-11-12T07:00:04+09:00" property="article:published_time"/>
# <!--// 메타태그정보 -->
# <link href="https://cdn.spnews.co.kr/image/logo/favicon.ico" rel="shortcut icon"/>
# <title>[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공 &lt; 경제/산업 &lt; 북한N &lt; 기사본문 - SPN 서울평양뉴스</title>
# <link href="https://cdn.spnews.co.kr/rss/gn_rss_allArticle.xml" rel="alternate" type="application/rss+xml">
# <link href="https://cdn.spnews.co.kr/rss/gn_rss_S1N16.xml" rel="alternate" type="application/rss+xml"/>
# <link href="https://www.spnews.co.kr/news/articleView.html?idxno=101229" id="canonical" rel="canonical"/>
# <!--<link rel="amphtml" href="https://www.spnews.co.kr/news/articleViewAmp.html?idxno=101229">--> <!-- 구글AMP태그 -->
# <link href="https://cdn.spnews.co.kr/css/common.min.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/css/font.style.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/css/plugins.min.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/css/style.min.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/css/article.style.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/css/design.style.css" rel="stylesheet"/>
# <link href="https://cdn.spnews.co.kr/menuskin/pd_01/menubar.css" rel="stylesheet"/>
# <script src="https://cdn.spnews.co.kr/script/jquery.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/jquery-ui.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/slick.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/jquery.rwdImageMaps.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/what-input.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/foundation.min.js"></script>
# <script src="https://cdn.spnews.co.kr/menuskin/pd_01/menubar.js"></script>
# <script src="https://cdn.spnews.co.kr/script/user.style.js"></script>
# <script src="https://cdn.spnews.co.kr/script/jquery.timepicker.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/jquery.tabslet.min.js"></script>
# <script src="https://cdn.spnews.co.kr/script/common.js"></script>
# <script src="https://cdn.spnews.co.kr/script/Util.js"></script>
# <script src="https://cdn.spnews.co.kr/script/Bannerpop.js"></script>
# <script src="https://cdn.spnews.co.kr/script/ImageViewer.js"></script>
# <script>
# $(function(e) {
# 	// 이미지맵
# 	$('img[usemap]').rwdImageMaps();
#
# 	// 기사뷰 이미지관련
# 			//resizePhoto(); // ImageViewer(lightbox) 로 대체
#
# 		// 기사본문 복사 출처 표기
# 		_articleSelect.copy('SPN 서울평양뉴스(https://www.spnews.co.kr)');
# 	});
#
# // 도메인
# var SITE_DOMAIN = 'https://www.spnews.co.kr'
# 	,CDN_DOMAIN = 'https://cdn.spnews.co.kr'
# 	,___currentTime	= 1763472284;
#
# // 즐겨찾기 스크립트
# function bookmark() {
# 	window.external.AddFavorite("https://www.spnews.co.kr", "SPN 서울평양뉴스")
# }
# </script>
# <style>
# :root {
# 	--nd-primary: #002978;
# 	--nd-primary-hover: #00256c;
# 	--nd-primary-active: #002160;
# 	--nd-primary-rgb: 0, 41, 120;
# 	--nd-site-width: 1080px;
#     --nd-index-width: 1080px;
# 	--nd-writing-content-max-width: 600px;
# }
# .width-1080 {width:1080px}
# .max-width-1080 {max-width:1080px}
# .min-width-1080 {min-width:1080px}
# </style>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-150944387-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-150944387-1');
# </script>
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "3ae1d54a18922";
# wcs_do();
# </script>
# <!-- 20210720 추가 -->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "7414227de66c4";
# if(window.wcs) {
#   wcs_do();
# }
# </script>
# <!-- 20210811 추가 -->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "b7159ac54507c0";
# if(window.wcs) {
#   wcs_do();
# }
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-202525871-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-202525871-1');
# </script>
# <!---------------------->
# <!-- Global site tag (gtag.js) - Google Analytics 20220523 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-GGDCHLLX2L"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-GGDCHLLX2L');
# </script>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-JBEF4H7RSP"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-JBEF4H7RSP');
# </script><!--PC 기사뷰 head 코드 (20241030)(AD173027033398)//-->
# <!-- <head>와 </head> 사이에 삽입해주세요. -->
# <script async="" src="//send.mci1.co.kr/delivery/js/31775025/23210467653" type="text/javascript"></script>
# <!-- news article schema -->
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "NewsArticle",
#     "mainEntityOfPage" : {
#         "@type": "WebPage",
#         "@id": "https://www.spnews.co.kr/news/articleView.html?idxno=101229"
#     },
#     "headline": "[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공",
#     "description": "북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.노동신문은 12일 &quot;수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생산건물들을 개건하고 모든 공정이 자동화, 흐름선화된 과일가공품생산기지를 건설했다&quot;고 보도했다.&quot;공장에서는 과일농축즙, 과일단물, 과일살즙음료, 말린과일, 과일가루, 과일단묵생산공정을 완공한데 이어 최근 과일통졸임, 과일단졸임, 과일발효식초생산공정을 간춰 총 9가지에 달하는 과일가공품을 생산할 수 있다&quot;고 소개했다.신문은 또 &quot;황해북도농업과학연구소에서 지역의 기상기후적 특성에",
#     "datePublished": "2025-11-12T07:00:04+09:00",
#     "dateModified":"2025-11-12T07:11:11+09:00",
#     "author":[ {
#         "@type": "Person",
#         "name": "안윤석 대기자"
#     }],
#     "image": {
#         "@type": "ImageObject",
#         "url": "https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg",
#         "width": "600",
#         "height": "371"
#     },
#     "publisher": {
#         "@type": "Organization",
#         "name": "SPN 서울평양뉴스",
#         "alternateName": "SPN 서울평양뉴스",
#         "logo": {
#             "@type": "ImageObject",
#             "url": "https://cdn.spnews.co.kr/image/logo/toplogo_20240924032445.png",
#             "width":"300",
#             "height": "110"
#         }
#     }
# }
# </script>
# </link></meta></meta></meta></meta></head>
# <body class="" style="">
# <nav class="skip-nav">
# <a class="skip-nav-item" href="#user-menu" onclick="document.getElementById('user-menu').tabIndex = -1;document.getElementById('user-menu').focus();return false;">주요서비스 바로가기</a>
# <a class="skip-nav-item" href="#user-container" onclick="document.getElementById('user-container').tabIndex = -1;document.getElementById('user-container').focus();return false;">본문 바로가기</a>
# <a class="skip-nav-item" href="#user-footer" onclick="document.getElementById('user-footer').tabIndex = -1;document.getElementById('user-footer').focus();return false;">매체정보 바로가기</a>
# <a class="skip-nav-item" href="#userLogin" onclick="document.getElementById('userLogin').tabIndex = -1;document.getElementById('userLogin').focus();return false;">로그인 바로가기</a>
# <a class="skip-nav-item" href="#userSearch" onclick="document.getElementById('userSearch').tabIndex = -1;document.getElementById('userSearch').focus();return false;">기사검색 바로가기</a>
# </nav>
# <div class="off-canvas-content" data-off-canvas-content="">
# <div class="user-wrap" id="user-wrap">
# <div id="user-wrapper">
# <header class="user-header" id="user-header">
# <div class="clearfix text-center">
# </div>
# <style>
# #header-wrapper.basic, #header-wrapper .mode-inner, #nav-header {width:1080px}
# #user-nav {background-color:#002978}
#
# /* 1차 */
#
# /* 2차 - vertical */
# #header-wrapper.vertical #user-nav .user-menu .secline > ul {border-color:#002978}
#
# /* 2차 - 배경 slideDown */
# #header-wrapper.horizon #user-nav.active::before {border-top-color:#002978}
#
# /* 2차 - vertical & use autobox */
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline > ul {width:1080px;padding-right:calc(1080px - 300px)}
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a.a-sub-hover,
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a:hover {color:#fff;background-color:#002978}
# </style>
# <!-- 메뉴 시작 //-->
# <div class="vertical full center" data-main-code="S1N16" data-multi-code="" data-serial-code="/news/articleView.html" data-sub-code="S2N20" id="header-wrapper">
# <!-- 최상단영역 //-->
# <div id="user-gnb">
# <div class="mode-inner align-center">
# <!-- 최종편집 //-->
# <div class="user-intro">UPDATED. 2025-11-18 17:26 (화) </div>
# <!--// 최종편집 -->
# <!-- 로그인 //-->
# <ul class="user-logbox no-bullet" id="userLogin">
# <li><a href="https://www.spnews.co.kr/member/login.html" target="_top">로그인</a></li>
# <li><a href="https://www.spnews.co.kr/member/index.html" target="_top">회원가입</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleView.html?idxno=101229" onclick="setCookie('view_pc', 'n', 1);" target="_top"><i class="icon-mobile"></i>모바일웹</a></li>
# </ul>
# <!--// 로그인 -->
# </div>
# </div>
# <!--// 최상단영역 -->
# <!-- 로고영역 //-->
# <header id="nav-header">
# <div class="user-banner text-left">
# <!--아카데미-배너--><script src="https://cdn.spnews.co.kr/bannerpop/uploads/js/65.js?1747195382"></script><!--//아카데미-배너--> </div>
# <div class="user-logo text-center">
# <a href="https://www.spnews.co.kr" target="_top">
# <img alt="SPN 서울평양뉴스" height="110" loading="lazy" src="https://cdn.spnews.co.kr/image/logo/toplogo_20240924032445.png" width="300"/>
# </a>
# </div>
# <div class="user-banner text-right">
# <!--241002_nk데이터마트--><script src="https://cdn.spnews.co.kr/bannerpop/uploads/js/52.js?1727832287"></script><!--//241002_nk데이터마트--> </div>
# </header>
# <!--// 로고영역 -->
# <!-- 메뉴바 //-->
# <nav id="user-nav">
# <div class="mode-inner">
# <!-- 전체 -->
# <button class="user-allbtn d-flex align-center" data-toggle="offCanvas" title="전체메뉴" type="button">
# <i class="icon-bars"><span class="show-for-sr">전체메뉴 버튼</span></i>
# </button>
# <!-- 섹션 //-->
# <ul class="user-menu d-flex no-bullet" id="user-menu">
# <li class="secline">
# <a data-code="S1N17" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N17&amp;view_type=sm" target="_top">서울&amp;</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N22" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N22&amp;view_type=sm" target="_top">대통령실/총리실</a>
# </li>
# <li class="sub">
# <a data-code="S2N23" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N23&amp;view_type=sm" target="_top">통일</a>
# </li>
# <li class="sub">
# <a data-code="S2N24" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N24&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="sub">
# <a data-code="S2N25" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N25&amp;view_type=sm" target="_top">국방</a>
# </li>
# <li class="sub">
# <a data-code="S2N26" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N26&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N16" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm" target="_top">북한N</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N17" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N17&amp;view_type=sm" target="_top">정치</a>
# </li>
# <li class="sub">
# <a data-code="S2N18" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N18&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="sub">
# <a data-code="S2N19" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N19&amp;view_type=sm" target="_top">군사</a>
# </li>
# <li class="sub">
# <a data-code="S2N20" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm" target="_top">경제/산업</a>
# </li>
# <li class="sub">
# <a data-code="S2N21" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N21&amp;view_type=sm" target="_top">사회/문화/체육</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N6" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N6&amp;view_type=sm" target="_top">한반도W</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N12" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N12&amp;view_type=sm" target="_top">미주</a>
# </li>
# <li class="sub">
# <a data-code="S2N13" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N13&amp;view_type=sm" target="_top">유럽,아프리카</a>
# </li>
# <li class="sub">
# <a data-code="S2N14" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N14&amp;view_type=sm" target="_top">아시아,호주</a>
# </li>
# <li class="sub">
# <a data-code="S2N16" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N16&amp;view_type=sm" target="_top">국제기구</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N19" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N19&amp;view_type=sm" target="_top">이슈+</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N38" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N38&amp;view_type=sm" target="_top">전문가분석</a>
# </li>
# <li class="sub">
# <a data-code="S2N39" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N39&amp;view_type=sm" target="_top">노동신문 분석</a>
# </li>
# <li class="sub">
# <a data-code="S2N32" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N32&amp;view_type=sm" target="_top">칼럼</a>
# </li>
# <li class="sub">
# <a data-code="S2N33" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N33&amp;view_type=sm" target="_top">학술</a>
# </li>
# <li class="sub">
# <a data-code="S2N34" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N34&amp;view_type=sm" target="_top">행사</a>
# </li>
# <li class="sub">
# <a data-code="S2N35" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N35&amp;view_type=sm" target="_top">인터뷰/사람들</a>
# </li>
# <li class="sub">
# <a data-code="S2N36" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N36&amp;view_type=sm" target="_top">미션/한민족</a>
# </li>
# <li class="sub">
# <a data-code="S2N37" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N37&amp;view_type=sm" target="_top">인사/동정</a>
# </li>
# <li class="sub">
# <a data-code="S2N40" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N40&amp;view_type=sm" target="_top">NK 리포트</a>
# </li>
# <li class="sub">
# <a data-code="S2N41" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N41&amp;view_type=sm" target="_top">북한 경제산업 동향</a>
# </li>
# <li class="sub">
# <a data-code="S2N43" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N43&amp;view_type=sm" target="_top">나의 길</a>
# </li>
# </ul>
# </li>
# </ul>
# <!--// 섹션 -->
# <!-- etc link //-->
# <div class="user-etc d-flex align-center justify-center">
# <a href="https://www.weather.go.kr/w/weather/forecast/nk-weather/nk-land-forecast.do" target="_blank"><i class="icon-cloud-o"></i> 오늘 북한 날씨</a>
# <a href="http://map.ngii.go.kr/ms/map/NlipMap.do?tabGb=north" target="_blank"><i class="icon-map-o"></i> 북한 위성 지도</a>
# </div>
# <!--// etc link -->
# <!-- 검색 //-->
# <div class="user-search" id="userSearch">
# <button class="search-btn d-flex align-center" type="button"><i class="icon-search-thin"></i></button>
# <fieldset class="user-search-form">
# <form action="https://www.spnews.co.kr/news/articleList.html" class="d-flex align-center justify-center" method="get" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="기사검색" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="icon-search-thin"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# </div>
# <!--// 검색 -->
# </div>
# </nav>
# <!--// 메뉴바 -->
# </div>
# <!--// 메뉴 끝 -->
# <script>
# <!--
# //메뉴 스타일 불러옴 : 메뉴 /script/menubar.js 와 같이 사용되어야 함
# var menuIndexHold = true,
# menuOverHold = true,
# submenuStyle = "vertical",
# sizeMode = "full",
# subShow = "hold",
# submenuPosi = "center",
# effectSwitch = "on",
# subSlideSpeed = 150,
# subFadeSpeed = 150;
#
# $(document).ready(function(){
#
# 	var $headerWrap = $('#header-wrapper')
# 		, $userNav = $headerWrap.find('#user-nav')
# 		, $userSearch = $userNav.find('.user-search')
# 		, $searchBtn = $userSearch.find('.search-btn')
# 		, $searchForm = $userSearch.find('.user-search-form');
#
# 	$searchBtn.on('click', function(){
# 		$userSearch.toggleClass('on');
# 		$searchForm.slideToggle();
# 	});
#
# });
# //-->
# </script>
# </header>
# <main class="user-container" id="user-container">
# <div class="index-width" id="layer-popups"></div>
# <div class="position-relative index-width"><div class="view-aside left-wing" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="20" id="floating_banner_left">
# </div>
# <div class="view-aside right-wing" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="20" id="floating_banner_right">
# </div>
# </div>
# <div class="position-relative index-width" id="wingBanner">
# <div class="wing-banner-left">
# <!--기사뷰_좌측 날개//-->
# <style>#AD173068023121.ad-template { margin:auto; position:relative; display:block; clear:both; z-index:1; padding-top:0px; }
# #AD173068023121.ad-template .col { text-align:center; }
# #AD173068023121.ad-template .col .ad-view { position:relative; width:300px; }</style>
# <!-- AD Manager | AD173068023121 //-->
# <div class="ad-template wing-banner" data-direction="left" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="15" id="AD173068023121">
# <div class="col"><div class="ad-view"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:좌측날개상단 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23209545071"></ins>
# </div></div>
# </div>
# <!--// AD Manager | AD173068023121 --> </div>
# <div class="wing-banner-right">
# </div>
# </div>
# <script src="https://cdn.spnews.co.kr/script/share.sns.js"></script>
# <script>
# 	var site_ismobile		= '';			// 현재 모바일접속 여부
# 	var kakaojavascriptkey	= '';	// 카카오앱 자바스크립트키
# 	var articleIdxno		= '101229';
# 	var snsKakaoSend		= function(sns, url, title, desc, img){		// kakao용 함수
# 								if(sns == "kakao") {
# 									sendKakaoTalk(url, title, desc, img);
# 								}else if(sns == "kakaostory") {
# 									shareStory(url, title, desc, img);
# 								}
# 							};
#
# 	$(document).ready(function(e) {
#
# 		$('button.sns-share-btns').on('click', function(e) {
# 			var sns		= $(this).data('sharesns');
# 			var title	= $(this).data('title');
# 			var desc	= $(this).data('desc');
# 			var url		= $(this).data('url');
# 			var img		= $(this).data('image');
#
# 			if(sns == "link") return true;
#
# 			// SNS 공유 통계 집계 (공유하기에 영향을 주지않도록 체크하지는 않음)
# 			snsShareStats(articleIdxno, sns);
#
# 			if($.inArray(sns, ["kakao","kakaostory"])>=0){
# 				// kakao가 이미 로딩 되었다면 실행 or not, url 로딩 시킴
# 				if("Kakao" in window) snsKakaoSend(sns, url, title, desc, img);
# 				else{
# 					var script=document.createElement("script");
# 					script.src="//developers.kakao.com/sdk/js/kakao.min.js";
# 					script.onload=function(e){
# 						if(kakaojavascriptkey){
# 							kakaoinit(kakaojavascriptkey);
# 							snsKakaoSend(sns, url, title, desc, img);
# 						}
# 					};
# 					script.onerror=function(e){};
#
# 					document.querySelector("head").appendChild(script);
# 				}
#
# 				return false;
# 			}
#
# 			if(sns == "band") {
# 				shareBand(url, title);
# 			}else if(sns == "telegram") {
#                 shareTelegram(url, title);
# 			}else{
# 				shareOtherSNS(sns, title, url, img);
# 			}
#
# 		});
# 	});
# </script>
# <style>
# /* edit skin css START */
# #article-view .article-view-content {display:table;width:100%;table-layout:fixed}
# #article-view .article-view-content > .grid {display:table-cell;width:100%;vertical-align:top}
# #article-view .article-view-content > .grid.side {width:364px;padding-left:64px}
# #article-view .grid.side .sticky {width:100%}
# #article-view .grid.side .sticky::after {content:'';display:table;clear:both}
# #article-view .sticky-article {display:block}
# #article-view .sticky-article::after {content:'';display:table;clear:both}
# #article-view .sticky-article .article-sns, #article-view .sticky-article .article-sns ~ .article-body {float:left}
# #article-view .sticky-article .article-sns {width:36px}
# #article-view .social-group {justify-content:center;margin-bottom:1.5rem}
# #article-view .sticky-article .article-sns ~ .article-body {width:calc(100% - 36px);padding-left:40px}
# #article-view .article-veiw-body {margin-bottom:5rem}
# @media screen and (max-width: 63.9375em) {
# 	.mobile #article-view .article-view-content, .mobile #article-view .article-view-content > .grid {display:block;width:auto}
# 	.mobile #article-view .article-view-content {table-layout:inherit}
# 	.mobile #article-view .article-view-content > .grid {vertical-align:inherit}
# 	.mobile #article-view .article-view-content > .grid.side {padding-left:0}
# 	.mobile #article-view .respons-edit > [class*="float-"] {float:none !important;width:auto !important;padding:0 !important}
# 	.mobile #article-view .respons-edit > .float-right {display:none !important}
# }
# @media screen and (max-width: 39.9375em) {
# 	.mobile #article-view .sticky-article .article-sns, .mobile #article-view .sticky-article .article-sns ~ .article-body {float:none;width:auto}
# 	.mobile #article-view .sticky-article .article-sns {margin-bottom:1.5rem}
# 	.mobile #article-view .sticky-article .article-sns ~ .article-body {padding-left:0}
# 	.mobile #article-view .social-group {justify-content:center}
# 	.mobile #article-view .grid.side {--nd-box-skin-margin:0 calc(var(--nd-user-padding-x, 0px) * -1);}
# 	.mobile .sticky-container {height:auto !important}
# 	.mobile .sticky {position:static !important;top:auto !important;bottom:auto !important;max-width:none !important;margin:0 !important}
# }
# /* edit skin css END */
# </style>
# <div id="article-view">
# <div class="wrapper index-max-width">
# <script>
# 	// 기사면 상단 네비게이션 호출
# 	articleHeader.setScroll();
#
# 	$(window).scroll(function() {
#         var currY = $(this).scrollTop();
#         var postHeight = $(this).height();
#         var scrollHeight = $('body').height();
#         var scrollPercent = (currY / (scrollHeight - postHeight)) * 100;
#         $('.aht-bar').css('width', scrollPercent +"%");
#     });
# </script>
# <!-- 기사면 상단 네비게이션 //-->
# <div id="sticky-header">
# <!-- 이전/다음 기사 버튼 //-->
# <button class="aht-btn prev" onclick="javascript:articleHeader.move(
# 				'prev',
# 				'embargo_date',
# 				'1762898404_101229',
# 				'S1N16',
# 				'S2N20',
# 				'');" tabindex="-1" title="이전기사" type="button"><i class="icon-angle-left-thin"></i><span class="show-for-sr">이전 기사보기</span></button>
# <button class="aht-btn next" onclick="javascript:articleHeader.move(
# 				'next',
# 				'embargo_date',
# 				'1762898404_101229',
# 				'S1N16',
# 				'S2N20',
# 				'');" tabindex="-1" title="다음기사" type="button"><i class="icon-angle-right-thin"></i><span class="show-for-sr">다음 기사보기</span></button>
# <!--// 이전/다음 기사 버튼 -->
# <!-- 상단 컨텐츠 //-->
# <div class="aht-wrapper width-1080">
# <div class="item logo"><a href="https://www.spnews.co.kr" tabindex="-1"><img alt="SPN 서울평양뉴스" src="https://cdn.spnews.co.kr/image/logo/printlogo_20240924032445.png"/></a></div>
# <div class="item titles"><span class="aht-title-view" tabindex="-1">[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공</span></div>
# <div class="item options">
# <div class="quick-tool">
# <button class="tool" data-tooltip="" onclick="articlePrint('101229')" tabindex="-1" title="인쇄" type="button"><i class="icon-print"><span class="show-for-sr">바로가기</span></i></button>
# <button class="tool sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-tooltip="" tabindex="-1" title="URL주소" type="button"><i class="icon-link"><span class="show-for-sr">복사하기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" tabindex="-1" title="본문글씨 줄이기" type="button" value="down"><i class="font-size down"><span class="show-for-sr">본문 글씨 줄이기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" tabindex="-1" title="본문글씨 키우기" type="button" value="up"><i class="font-size up"><span class="show-for-sr">본문 글씨 키우기</span></i></button>
# </div>
# </div>
# </div>
# <!--// 상단 컨텐츠 -->
# <!-- 스크롤 상태바 //-->
# <div class="aht-control">
# <div class="aht-bar user-border-top"><span class="show-for-sr">스크롤 이동 상태바</span></div>
# </div>
# <!--// 스크롤 상태바 -->
# </div>
# <!--// 기사면 상단 네비게이션 -->
# <!-- 기사본문 상단 //-->
# <header class="article-view-header">
# <!-- breadcrumbs //-->
# <nav role="navigation">
# <ul class="breadcrumbs">
# <li><a href="https://www.spnews.co.kr"><i class="icon-home"></i> 홈</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm">북한N</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm">경제/산업</a></li>
# </ul>
# </nav>
# <h1 class="heading">[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공</h1>
# <!-- infomation  // -->
# <div class="info-group">
# <article class="item">
# <ul class="infomation">
# <li>
# <i class="icon-user-o"><span class="show-for-sr">기자명</span></i>
# 					안윤석 대기자				</li>
# <li><i class="icon-clock-o"></i> 입력 2025.11.12 07:00</li>
# <li><i class="icon-check-circle-o"></i> 수정 2025.11.12 07:11</li>
# <li><i class="icon-comment-o"></i> 댓글 0</li>
# </ul>
# </article>
# <article class="item">
# <div class="quick-tool">
# <button class="tool" data-tooltip="" onclick="articlePrint('101229')" title="인쇄" type="button"><i class="icon-print"><span class="show-for-sr">바로가기</span></i></button>
# <button class="tool sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-tooltip="" title="URL주소" type="button"><i class="icon-link"><span class="show-for-sr">복사하기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" title="본문글씨 줄이기" type="button" value="down"><i class="font-size down"><span class="show-for-sr">본문 글씨 줄이기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" title="본문글씨 키우기" type="button" value="up"><i class="font-size up"><span class="show-for-sr">본문 글씨 키우기</span></i></button>
# </div>
# </article>
# </div>
# </header>
# <!--// 기사본문 상단 -->
# <section class="article-view-content" id="articleViewCon">
# <article class="grid body">
# <div class="sticky-article" id="snsAnchor">
# <aside class="article-sns" data-sticky-container="">
# <div class="sticky" data-anchor="snsAnchor" data-check-every="0" data-dynamic-height="false" data-margin-top="5" data-sticky="">
# <div class="social-group">
# <button aria-label="페이스북" class="sns sns-share-btns facebook" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="facebook" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="페이스북" type="button">
# <i class="icon-facebook"></i>
# </button>
# <button aria-label="트위터" class="sns sns-share-btns twitter" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="twitter" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="트위터" type="button">
# <i class="icon-twitter"></i>
# </button>
# <button aria-label="URL복사" class="sns sns-share-btns link sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="link" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="URL복사" type="button">
# <i class="icon-link"></i>
# </button>
# <button aria-label="이메일(으)로 기사보내기" class="sns mail" onclick="articleMail('101229')" title="이메일" type="button"><i class="icon-mail"></i></button>
# <button aria-label="다른공유찾기" class="sns share" data-open="article-sns" title="다른 공유" type="button"><i class="icon-share-alt"></i></button>
# <button aria-label="기사스크랩하기" class="sns bookmark scrap-btn user-bg" data-idxno="101229" title="기사스크랩" type="button"><i class="icon-bookmark"></i></button>
# <script>
# 					$(document).ready(function(e) {
# 						$('.scrap-btn').on('click', function(e) {
# 							var idxno = $(this).data('idxno');
#
# 							if(confirm("기사를 스크랩 하시겠습니까?")){
# 								$.ajax({
# 									type: 'post',
# 									dataType: 'json',
# 									url: '/news/articleScrap.ajax.php',
# 									data: {'tp':'A', 'idxno':idxno},
# 									success: function(data) {
# 										alert(data[1]);
# 									},
# 									error: function(error, request) {
# 										alert('error!!!');
# 										console.log("code:"+request.status+"\n"+"message:"+request.responseText+"\n"+"error:"+error);
# 									}
# 								});
# 							}
# 						});
# 					});
# 				</script>
# </div>
# </div>
# <div class="reveal" data-animation-in="fade-in" data-animation-out="fade-out" data-close-on-click="false" data-close-on-esc="false" data-reveal="" id="article-sns">
# <div class="reveal-header">
# <div class="reveal-title">이 기사를 공유합니다</div>
# </div>
# <section class="reveal-container">
# <div class="social-group for-other">
# <button aria-label="페이스북" class="sns sns-share-btns facebook" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="facebook" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="페이스북" type="button">
# <i class="icon-facebook"></i>
# </button>
# <button aria-label="트위터" class="sns sns-share-btns twitter" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="twitter" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="트위터" type="button">
# <i class="icon-twitter"></i>
# </button>
# ...
# </ul>
# <div class="ndsoft">
# <a href="http://www.ndsoft.co.kr/" rel="nofollow sponsored ugc" target="_blank"><img alt="ND소프트" height="9" loading="lazy" src="https://cdn.spnews.co.kr/image/ndsoft.svg" width="72"/></a>
# </div>
# </address>
# </div>
# </div>
# </div>
# </footer>
# <div class="clearfix text-center">
# </div>
# <button aria-label="위로" class="back-to-top" id="back-to-top" type="button"></button>
# <a class="desktop-to-mobile hide" href="https://www.spnews.co.kr/news/articleView.html?idxno=101229" onclick="setCookie('view_pc', 'n', 1);">모바일버전</a>
# </div>
# </div>
# <div class="off-canvas position-left global-menu-wrapper" data-content-scroll="false" data-off-canvas="" data-transition="slide" id="offCanvas" tabindex="-1">
# <nav class="global-menu-container">
# <header class="global-menu-header">
# <a class="global-menu-title" href="https://www.spnews.co.kr" target="_top">SPN 서울평양뉴스</a>
# <button aria-label="close global menu" class="btn-close ms-auto" data-close="" type="button"></button>
# </header>
# <main class="global-menu-body">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link active" href="https://www.spnews.co.kr/news/articleList.html?view_type=sm" target="_top">전체기사</a>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N16" target="_top">북한N</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N17&amp;view_type=sm" target="_top">정치</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N18&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N19&amp;view_type=sm" target="_top">군사</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm" target="_top">경제/산업</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N21&amp;view_type=sm" target="_top">사회/문화/체육</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N42&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N17" target="_top">서울&amp;</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N17&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N22&amp;view_type=sm" target="_top">대통령실/총리실</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N23&amp;view_type=sm" target="_top">통일</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N24&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N25&amp;view_type=sm" target="_top">국방</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N26&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N6" target="_top">한반도W</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N6&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N12&amp;view_type=sm" target="_top">미주</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N13&amp;view_type=sm" target="_top">유럽,아프리카</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N14&amp;view_type=sm" target="_top">아시아,호주</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N16&amp;view_type=sm" target="_top">국제기구</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N19" target="_top">이슈+</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N19&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N38&amp;view_type=sm" target="_top">전문가분석</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N39&amp;view_type=sm" target="_top">노동신문 분석</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N32&amp;view_type=sm" target="_top">칼럼</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N33&amp;view_type=sm" target="_top">학술</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N34&amp;view_type=sm" target="_top">행사</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N35&amp;view_type=sm" target="_top">인터뷰/사람들</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N36&amp;view_type=sm" target="_top">미션/한민족</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N37&amp;view_type=sm" target="_top">인사/동정</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N40&amp;view_type=sm" target="_top">NK 리포트</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N41&amp;view_type=sm" target="_top">북한 경제산업 동향</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N43&amp;view_type=sm" target="_top">나의 길</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N10&amp;view_type=sm" target="_top">오늘의 북한</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N11&amp;view_type=sm" target="_top">SPN TV</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N20&amp;view_type=sm" target="_top">SPNGO</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N21&amp;view_type=sm" target="_top">평양 사이언스</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N22&amp;view_type=sm" target="_top">최일 함장의 잠수함 리얼리티</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N23&amp;view_type=sm" target="_top">노동신문 돋보기</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N24&amp;view_type=sm" target="_top">NK 농업</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N25&amp;view_type=sm" target="_top">NK 건설</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N26&amp;view_type=sm" target="_top">NK 위성포커스</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N27&amp;view_type=sm" target="_top">K-방산</a>
# </li>
# </ul>
# </main>
# </nav>
# </div>
# <script>
# const bannerpop = new Bannerpop();
# // Popup Json
# var ___popup = [];
# bannerpop.popup();
# </script>
# <script>
# // back to the top
# $(document).scroll(function(){
# 	var sDocumentHeight = $(document).height() - $(window).height();
# 	if($(document).scrollTop() > 0){
# 		$('#back-to-top').fadeIn();
# 	}else{
# 		$('#back-to-top').fadeOut();
# 	}
# });
#
# $('#back-to-top, a[href="#top"]').click(function(){
# 	$('html, body').animate( {scrollTop:0}, 100);
# });
#
# // 모바일버전 이동 버튼
# if (Util.isMobileDevice() === true) $(".desktop-to-mobile").removeClass("hide");
# </script>
# <!-- 구글 애드센스 S -->
# <script src="https://cdn.spnews.co.kr/adManager/js/lab.js"></script>
# <script>
# jQuery(function($) {
# 	setTimeout(function() {
# 		$LAB
# 		.script("//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js")
# 		.wait(function () {
# 			var adn = jQuery('.adsbygoogle').length;
# 			if (adn > 0) {
# 				for (var i = 0; i < adn; i++) {
# 					(adsbygoogle = window.adsbygoogle || []).push({});
# 				}
# 			}
# 		});
# 	}, 1000);
# });
# </script>
# <!-- 구글 애드센스 E -->
# <script>
# $(document).ready(function(){
# 	// 닫기 버튼 자동 노출
# 	$('.ad-template.ad-close .ad-view').each(function(){
# 		$(this).append('<div class="ad-close-btn"><i class="icon-close"></i></div>');
# 	})
#
# 	// 닫기 버튼 클릭 시 이벤트
# 	$('body').on('click', '.ad-close-btn', function(){
# 		$(this).closest('.ad-view').slideUp();
# 	})
#
# 	// isND
# 	var ____is_nd = getCookie('____is_nd');
# 	if(____is_nd) {
# 				// ND IP만 광고 ID 보이기
# 		$('.ad-template').each(function(){
# 			$(this).append('<div class="ad-code-id">'+$(this).attr('id')+'</div>');
# 		})
#
# 				// 광고 ID 자동 숨김 설정 시
# 		$('.ad-code-id').hide();
#
# 		$('.ad-template').mouseenter(function(){
# 			$(this).find('.ad-code-id').show();
# 		}).mouseleave(function(){
# 			$(this).find('.ad-code-id').hide();
# 		})
#
#
# 			}
# })
#
#
#
# /* ****************************************** */
# /* 날개배너 스크립트  */
# /* ****************************************** */
# $('#wingBanner .wing-banner-left .wing-banner').each(function(){
# 	if( $(this).data('scroll') == 'y' ) $(this).addClass('scroll-on');
# });
#
# $(window).scroll(function() {
# 	if( $('#wingBanner .wing-banner').length > 0 ){											// 날개배너가 있으면 작동
#
# 		var scrollingHeight_L = nonScrollingHeight_L = scrollingHeight_R = nonScrollingHeight_R = 0;
#
# 		$('#wingBanner .wing-banner').each(function(idx){
# 			var $_this		= $(this),														// 날개배너
# 				scroll		= $_this.data('scroll'),										// 날개배너 스크롤 여부
# 				topMargin	= $_this.data('top-margin'),									// 날개배너 상단여백
# 				downMargin	= $_this.data('down-margin'),									// 날개배너 하단여백
# 				duration	= $_this.data('duration'),										// 날개배너 스크롤 속도
# 				direction	= $_this.data('direction'),										// 날개배너 위치
# 				// bannerTop	= $_this.offset().top,											// 날개배너 상단 위치 (가변)
# 				bannderHeight = $_this.outerHeight();										// 날개배너 높이 (고정)
#
# 			var fixWingBannertop	= $('#wingBanner').offset().top;						// 날개배너 상단 위치 (고정)
#
# 			var articleTitleHeight	= $('#sticky-header.scroll').height();			// 날개배너 스크롤 시 상단 타이틀 높이 (기사 본문 시)
# 			if(!articleTitleHeight) articleTitleHeight = 0;
#
# 			var $_userFooter		= $('#user-footer'),									// 사이트 Footer
# 				userFooterHeight	= $_userFooter.outerHeight();							// 사이트 Footer 높이 (고정)
#
# 			var winScrollTop		= $(window).scrollTop(),								// 윈도우 스크롤 위치 (가변)
# 				winHeight			= $(window).height(),									// 윈도우 높이
# 				docHeight			= $(document).height();									// 페이지 높이
#
# 			switch (direction) {															// 날개 배너 위치 별
# 				case 'left':
# 					if(scroll == 'y') scrollingHeight_L += bannderHeight;					// 순서대로 노출되는 날개배너 중 스크롤 하는 배너의 높이값 (좌)
# 					else nonScrollingHeight_L += bannderHeight;								// 순서대로 노출되는 날개배너 중 스크롤 하지 않는 배너의 높이값 (좌)
# 					break;
#
# 				case 'right':
# 					if(scroll == 'y') scrollingHeight_R += bannderHeight;					// 순서대로 노출되는 날개배너 중 스크롤 하는 배너의 높이값 (우)
# 					else nonScrollingHeight_R += bannderHeight;								// 순서대로 노출되는 날개배너 중 스크롤 하지 않는 배너의 높이값 (우)
# 					break;
# 			}
#
# 			if(scroll == 'y') {																// 스크롤 배너만 움직임 처리
# 				var bannerAllHeight = siteAllHeight = 0;
#
# 				// 좌우측 각각 배너 스크롤 처리를 위해 나눠서 처리
# 				if(direction == 'left'){																			// 좌측 날개
# 					var wingBnTop_L = winScrollTop - fixWingBannertop + topMargin - nonScrollingHeight_L;			// 날개배너 스크롤 위치 (가변)
#
# 					if( articleTitleHeight ) wingBnTop_L += articleTitleHeight;										// 기사본문 시 상단 스크롤 타이틀이 나타나면 스크롤 타이틀 만큼 날개배너 위치 조정
#
# 					if((fixWingBannertop + nonScrollingHeight_L) < winScrollTop) {
#
# 						bannerAllHeight = articleTitleHeight + scrollingHeight_L + 1;								// 상단 타이틀 + 스크롤배너의 총 높이
# 						siteAllHeight = winHeight - userFooterHeight + downMargin;									// 윈도우 높이 + 사이트 Footer 높이
#
# 						if( (winScrollTop >= ((docHeight - userFooterHeight) - winHeight)) && (bannerAllHeight >= siteAllHeight) ) {					// 사이트 Footer 넘어가는 경우 처리
# 							wingBnTop_L -= ((userFooterHeight + downMargin) - (winHeight - (scrollingHeight_L + topMargin + articleTitleHeight)));
# 							$('#wingBanner .wing-banner-left .wing-banner.scroll-on').animate({top:wingBnTop_L+"px" },{queue: false, duration: duration});		// 마지막 배너 움직임 처리
# 						}
# 					} else {
# 						wingBnTop_L = 0;																			// 최상단 처리
# 					}
# 					$_this.animate({top:wingBnTop_L+"px" },{queue: false, duration: duration});
#
# 				} else {																							// 우측 날개
#
# 					var wingBnTop_R = winScrollTop - fixWingBannertop + topMargin - nonScrollingHeight_R;			// 날개배너 스크롤 위치 (가변)
#
# 					if( articleTitleHeight ) wingBnTop_R += articleTitleHeight;										// 기사본문 시 상단 스크롤 타이틀이 나타나면 스크롤 타이틀 만큼 날개배너 위치 조정
#
# 					if((fixWingBannertop + nonScrollingHeight_R) < winScrollTop) {
#
# 						bannerAllHeight = articleTitleHeight + scrollingHeight_R + 1;								// 상단 타이틀 + 스크롤배너의 총 높이
# 						siteAllHeight = winHeight - userFooterHeight + downMargin;									// 윈도우 높이 + 사이트 Footer 높이
#
# 						if( (winScrollTop >= ((docHeight - userFooterHeight) - winHeight)) && (bannerAllHeight >= siteAllHeight) ) {					// 사이트 Footer 넘어가는 경우 처리
# 							wingBnTop_R -= ((userFooterHeight + downMargin) - (winHeight - (scrollingHeight_R + topMargin + articleTitleHeight)));
# 							$('#wingBanner .wing-banner-right .wing-banner.scroll-on').animate({top:wingBnTop_R+"px" },{queue: false, duration: duration});		// 마지막 배너 움직임 처리
# 						}
# 					} else {
# 						wingBnTop_R = 0;																			// 최상단 처리
# 					}
# 					$_this.animate({top:wingBnTop_R+"px" },{queue: false, duration: duration});
# 				}
# 			}
# 		});
# 	}
#
# });
# </script>
# </body>
# </html>

# %% [markdown]
# ### **[Notes]**

# %%
soup.find("meta", property="og:url")
# Out:
# <meta content="https://www.spnews.co.kr/news/articleView.html?idxno=101229" property="og:url"/>

# %%
soup.html.body
# Out:
# <body class="" style="">
# <nav class="skip-nav">
# <a class="skip-nav-item" href="#user-menu" onclick="document.getElementById('user-menu').tabIndex = -1;document.getElementById('user-menu').focus();return false;">주요서비스 바로가기</a>
# <a class="skip-nav-item" href="#user-container" onclick="document.getElementById('user-container').tabIndex = -1;document.getElementById('user-container').focus();return false;">본문 바로가기</a>
# <a class="skip-nav-item" href="#user-footer" onclick="document.getElementById('user-footer').tabIndex = -1;document.getElementById('user-footer').focus();return false;">매체정보 바로가기</a>
# <a class="skip-nav-item" href="#userLogin" onclick="document.getElementById('userLogin').tabIndex = -1;document.getElementById('userLogin').focus();return false;">로그인 바로가기</a>
# <a class="skip-nav-item" href="#userSearch" onclick="document.getElementById('userSearch').tabIndex = -1;document.getElementById('userSearch').focus();return false;">기사검색 바로가기</a>
# </nav>
# <div class="off-canvas-content" data-off-canvas-content="">
# <div class="user-wrap" id="user-wrap">
# <div id="user-wrapper">
# <header class="user-header" id="user-header">
# <div class="clearfix text-center">
# </div>
# <style>
# #header-wrapper.basic, #header-wrapper .mode-inner, #nav-header {width:1080px}
# #user-nav {background-color:#002978}
#
# /* 1차 */
#
# /* 2차 - vertical */
# #header-wrapper.vertical #user-nav .user-menu .secline > ul {border-color:#002978}
#
# /* 2차 - 배경 slideDown */
# #header-wrapper.horizon #user-nav.active::before {border-top-color:#002978}
#
# /* 2차 - vertical & use autobox */
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline > ul {width:1080px;padding-right:calc(1080px - 300px)}
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a.a-sub-hover,
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a:hover {color:#fff;background-color:#002978}
# </style>
# <!-- 메뉴 시작 //-->
# <div class="vertical full center" data-main-code="S1N16" data-multi-code="" data-serial-code="/news/articleView.html" data-sub-code="S2N20" id="header-wrapper">
# <!-- 최상단영역 //-->
# <div id="user-gnb">
# <div class="mode-inner align-center">
# <!-- 최종편집 //-->
# <div class="user-intro">UPDATED. 2025-11-17 17:24 (월) </div>
# <!--// 최종편집 -->
# <!-- 로그인 //-->
# <ul class="user-logbox no-bullet" id="userLogin">
# <li><a href="https://www.spnews.co.kr/member/login.html" target="_top">로그인</a></li>
# <li><a href="https://www.spnews.co.kr/member/index.html" target="_top">회원가입</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleView.html?idxno=101229" onclick="setCookie('view_pc', 'n', 1);" target="_top"><i class="icon-mobile"></i>모바일웹</a></li>
# </ul>
# <!--// 로그인 -->
# </div>
# </div>
# <!--// 최상단영역 -->
# <!-- 로고영역 //-->
# <header id="nav-header">
# <div class="user-banner text-left">
# <!--아카데미-배너--><script src="https://cdn.spnews.co.kr/bannerpop/uploads/js/65.js?1747195382"></script><!--//아카데미-배너--> </div>
# <div class="user-logo text-center">
# <a href="https://www.spnews.co.kr" target="_top">
# <img alt="SPN 서울평양뉴스" height="110" loading="lazy" src="https://cdn.spnews.co.kr/image/logo/toplogo_20240924032445.png" width="300"/>
# </a>
# </div>
# <div class="user-banner text-right">
# <!--241002_nk데이터마트--><script src="https://cdn.spnews.co.kr/bannerpop/uploads/js/52.js?1727832287"></script><!--//241002_nk데이터마트--> </div>
# </header>
# <!--// 로고영역 -->
# <!-- 메뉴바 //-->
# <nav id="user-nav">
# <div class="mode-inner">
# <!-- 전체 -->
# <button class="user-allbtn d-flex align-center" data-toggle="offCanvas" title="전체메뉴" type="button">
# <i class="icon-bars"><span class="show-for-sr">전체메뉴 버튼</span></i>
# </button>
# <!-- 섹션 //-->
# <ul class="user-menu d-flex no-bullet" id="user-menu">
# <li class="secline">
# <a data-code="S1N17" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N17&amp;view_type=sm" target="_top">서울&amp;</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N22" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N22&amp;view_type=sm" target="_top">대통령실/총리실</a>
# </li>
# <li class="sub">
# <a data-code="S2N23" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N23&amp;view_type=sm" target="_top">통일</a>
# </li>
# <li class="sub">
# <a data-code="S2N24" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N24&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="sub">
# <a data-code="S2N25" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N25&amp;view_type=sm" target="_top">국방</a>
# </li>
# <li class="sub">
# <a data-code="S2N26" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N26&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N16" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm" target="_top">북한N</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N17" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N17&amp;view_type=sm" target="_top">정치</a>
# </li>
# <li class="sub">
# <a data-code="S2N18" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N18&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="sub">
# <a data-code="S2N19" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N19&amp;view_type=sm" target="_top">군사</a>
# </li>
# <li class="sub">
# <a data-code="S2N20" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm" target="_top">경제/산업</a>
# </li>
# <li class="sub">
# <a data-code="S2N21" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N21&amp;view_type=sm" target="_top">사회/문화/체육</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N6" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N6&amp;view_type=sm" target="_top">한반도W</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N12" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N12&amp;view_type=sm" target="_top">미주</a>
# </li>
# <li class="sub">
# <a data-code="S2N13" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N13&amp;view_type=sm" target="_top">유럽,아프리카</a>
# </li>
# <li class="sub">
# <a data-code="S2N14" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N14&amp;view_type=sm" target="_top">아시아,호주</a>
# </li>
# <li class="sub">
# <a data-code="S2N16" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N16&amp;view_type=sm" target="_top">국제기구</a>
# </li>
# </ul>
# </li>
# <li class="secline">
# <a data-code="S1N19" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N19&amp;view_type=sm" target="_top">이슈+</a>
# <ul class="no-bullet">
# <li class="sub">
# <a data-code="S2N38" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N38&amp;view_type=sm" target="_top">전문가분석</a>
# </li>
# <li class="sub">
# <a data-code="S2N39" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N39&amp;view_type=sm" target="_top">노동신문 분석</a>
# </li>
# <li class="sub">
# <a data-code="S2N32" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N32&amp;view_type=sm" target="_top">칼럼</a>
# </li>
# <li class="sub">
# <a data-code="S2N33" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N33&amp;view_type=sm" target="_top">학술</a>
# </li>
# <li class="sub">
# <a data-code="S2N34" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N34&amp;view_type=sm" target="_top">행사</a>
# </li>
# <li class="sub">
# <a data-code="S2N35" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N35&amp;view_type=sm" target="_top">인터뷰/사람들</a>
# </li>
# <li class="sub">
# <a data-code="S2N36" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N36&amp;view_type=sm" target="_top">미션/한민족</a>
# </li>
# <li class="sub">
# <a data-code="S2N37" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N37&amp;view_type=sm" target="_top">인사/동정</a>
# </li>
# <li class="sub">
# <a data-code="S2N40" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N40&amp;view_type=sm" target="_top">NK 리포트</a>
# </li>
# <li class="sub">
# <a data-code="S2N41" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N41&amp;view_type=sm" target="_top">북한 경제산업 동향</a>
# </li>
# <li class="sub">
# <a data-code="S2N43" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N43&amp;view_type=sm" target="_top">나의 길</a>
# </li>
# </ul>
# </li>
# </ul>
# <!--// 섹션 -->
# <!-- etc link //-->
# <div class="user-etc d-flex align-center justify-center">
# <a href="https://www.weather.go.kr/w/weather/forecast/nk-weather/nk-land-forecast.do" target="_blank"><i class="icon-cloud-o"></i> 오늘 북한 날씨</a>
# <a href="http://map.ngii.go.kr/ms/map/NlipMap.do?tabGb=north" target="_blank"><i class="icon-map-o"></i> 북한 위성 지도</a>
# </div>
# <!--// etc link -->
# <!-- 검색 //-->
# <div class="user-search" id="userSearch">
# <button class="search-btn d-flex align-center" type="button"><i class="icon-search-thin"></i></button>
# <fieldset class="user-search-form">
# <form action="https://www.spnews.co.kr/news/articleList.html" class="d-flex align-center justify-center" method="get" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="기사검색" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="icon-search-thin"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# </div>
# <!--// 검색 -->
# </div>
# </nav>
# <!--// 메뉴바 -->
# </div>
# <!--// 메뉴 끝 -->
# <script>
# <!--
# //메뉴 스타일 불러옴 : 메뉴 /script/menubar.js 와 같이 사용되어야 함
# var menuIndexHold = true,
# menuOverHold = true,
# submenuStyle = "vertical",
# sizeMode = "full",
# subShow = "hold",
# submenuPosi = "center",
# effectSwitch = "on",
# subSlideSpeed = 150,
# subFadeSpeed = 150;
#
# $(document).ready(function(){
#
# 	var $headerWrap = $('#header-wrapper')
# 		, $userNav = $headerWrap.find('#user-nav')
# 		, $userSearch = $userNav.find('.user-search')
# 		, $searchBtn = $userSearch.find('.search-btn')
# 		, $searchForm = $userSearch.find('.user-search-form');
#
# 	$searchBtn.on('click', function(){
# 		$userSearch.toggleClass('on');
# 		$searchForm.slideToggle();
# 	});
#
# });
# //-->
# </script>
# </header>
# <main class="user-container" id="user-container">
# <div class="index-width" id="layer-popups"></div>
# <div class="position-relative index-width"><div class="view-aside left-wing" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="20" id="floating_banner_left">
# </div>
# <div class="view-aside right-wing" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="20" id="floating_banner_right">
# </div>
# </div>
# <div class="position-relative index-width" id="wingBanner">
# <div class="wing-banner-left">
# <!--기사뷰_좌측 날개//-->
# <style>#AD173068023121.ad-template { margin:auto; position:relative; display:block; clear:both; z-index:1; padding-top:0px; }
# #AD173068023121.ad-template .col { text-align:center; }
# #AD173068023121.ad-template .col .ad-view { position:relative; width:300px; }</style>
# <!-- AD Manager | AD173068023121 //-->
# <div class="ad-template wing-banner" data-direction="left" data-down-margin="15" data-duration="300" data-scroll="y" data-top-margin="15" id="AD173068023121">
# <div class="col"><div class="ad-view"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:좌측날개상단 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23209545071"></ins>
# </div></div>
# </div>
# <!--// AD Manager | AD173068023121 --> </div>
# <div class="wing-banner-right">
# </div>
# </div>
# <script src="https://cdn.spnews.co.kr/script/share.sns.js"></script>
# <script>
# 	var site_ismobile		= '';			// 현재 모바일접속 여부
# 	var kakaojavascriptkey	= '';	// 카카오앱 자바스크립트키
# 	var articleIdxno		= '101229';
# 	var snsKakaoSend		= function(sns, url, title, desc, img){		// kakao용 함수
# 								if(sns == "kakao") {
# 									sendKakaoTalk(url, title, desc, img);
# 								}else if(sns == "kakaostory") {
# 									shareStory(url, title, desc, img);
# 								}
# 							};
#
# 	$(document).ready(function(e) {
#
# 		$('button.sns-share-btns').on('click', function(e) {
# 			var sns		= $(this).data('sharesns');
# 			var title	= $(this).data('title');
# 			var desc	= $(this).data('desc');
# 			var url		= $(this).data('url');
# 			var img		= $(this).data('image');
#
# 			if(sns == "link") return true;
#
# 			// SNS 공유 통계 집계 (공유하기에 영향을 주지않도록 체크하지는 않음)
# 			snsShareStats(articleIdxno, sns);
#
# 			if($.inArray(sns, ["kakao","kakaostory"])>=0){
# 				// kakao가 이미 로딩 되었다면 실행 or not, url 로딩 시킴
# 				if("Kakao" in window) snsKakaoSend(sns, url, title, desc, img);
# 				else{
# 					var script=document.createElement("script");
# 					script.src="//developers.kakao.com/sdk/js/kakao.min.js";
# 					script.onload=function(e){
# 						if(kakaojavascriptkey){
# 							kakaoinit(kakaojavascriptkey);
# 							snsKakaoSend(sns, url, title, desc, img);
# 						}
# 					};
# 					script.onerror=function(e){};
#
# 					document.querySelector("head").appendChild(script);
# 				}
#
# 				return false;
# 			}
#
# 			if(sns == "band") {
# 				shareBand(url, title);
# 			}else if(sns == "telegram") {
#                 shareTelegram(url, title);
# 			}else{
# 				shareOtherSNS(sns, title, url, img);
# 			}
#
# 		});
# 	});
# </script>
# <style>
# /* edit skin css START */
# #article-view .article-view-content {display:table;width:100%;table-layout:fixed}
# #article-view .article-view-content > .grid {display:table-cell;width:100%;vertical-align:top}
# #article-view .article-view-content > .grid.side {width:364px;padding-left:64px}
# #article-view .grid.side .sticky {width:100%}
# #article-view .grid.side .sticky::after {content:'';display:table;clear:both}
# #article-view .sticky-article {display:block}
# #article-view .sticky-article::after {content:'';display:table;clear:both}
# #article-view .sticky-article .article-sns, #article-view .sticky-article .article-sns ~ .article-body {float:left}
# #article-view .sticky-article .article-sns {width:36px}
# #article-view .social-group {justify-content:center;margin-bottom:1.5rem}
# #article-view .sticky-article .article-sns ~ .article-body {width:calc(100% - 36px);padding-left:40px}
# #article-view .article-veiw-body {margin-bottom:5rem}
# @media screen and (max-width: 63.9375em) {
# 	.mobile #article-view .article-view-content, .mobile #article-view .article-view-content > .grid {display:block;width:auto}
# 	.mobile #article-view .article-view-content {table-layout:inherit}
# 	.mobile #article-view .article-view-content > .grid {vertical-align:inherit}
# 	.mobile #article-view .article-view-content > .grid.side {padding-left:0}
# 	.mobile #article-view .respons-edit > [class*="float-"] {float:none !important;width:auto !important;padding:0 !important}
# 	.mobile #article-view .respons-edit > .float-right {display:none !important}
# }
# @media screen and (max-width: 39.9375em) {
# 	.mobile #article-view .sticky-article .article-sns, .mobile #article-view .sticky-article .article-sns ~ .article-body {float:none;width:auto}
# 	.mobile #article-view .sticky-article .article-sns {margin-bottom:1.5rem}
# 	.mobile #article-view .sticky-article .article-sns ~ .article-body {padding-left:0}
# 	.mobile #article-view .social-group {justify-content:center}
# 	.mobile #article-view .grid.side {--nd-box-skin-margin:0 calc(var(--nd-user-padding-x, 0px) * -1);}
# 	.mobile .sticky-container {height:auto !important}
# 	.mobile .sticky {position:static !important;top:auto !important;bottom:auto !important;max-width:none !important;margin:0 !important}
# }
# /* edit skin css END */
# </style>
# <div id="article-view">
# <div class="wrapper index-max-width">
# <script>
# 	// 기사면 상단 네비게이션 호출
# 	articleHeader.setScroll();
#
# 	$(window).scroll(function() {
#         var currY = $(this).scrollTop();
#         var postHeight = $(this).height();
#         var scrollHeight = $('body').height();
#         var scrollPercent = (currY / (scrollHeight - postHeight)) * 100;
#         $('.aht-bar').css('width', scrollPercent +"%");
#     });
# </script>
# <!-- 기사면 상단 네비게이션 //-->
# <div id="sticky-header">
# <!-- 이전/다음 기사 버튼 //-->
# <button class="aht-btn prev" onclick="javascript:articleHeader.move(
# 				'prev',
# 				'embargo_date',
# 				'1762898404_101229',
# 				'S1N16',
# 				'S2N20',
# 				'');" tabindex="-1" title="이전기사" type="button"><i class="icon-angle-left-thin"></i><span class="show-for-sr">이전 기사보기</span></button>
# <button class="aht-btn next" onclick="javascript:articleHeader.move(
# 				'next',
# 				'embargo_date',
# 				'1762898404_101229',
# 				'S1N16',
# 				'S2N20',
# 				'');" tabindex="-1" title="다음기사" type="button"><i class="icon-angle-right-thin"></i><span class="show-for-sr">다음 기사보기</span></button>
# <!--// 이전/다음 기사 버튼 -->
# <!-- 상단 컨텐츠 //-->
# <div class="aht-wrapper width-1080">
# <div class="item logo"><a href="https://www.spnews.co.kr" tabindex="-1"><img alt="SPN 서울평양뉴스" src="https://cdn.spnews.co.kr/image/logo/printlogo_20240924032445.png"/></a></div>
# <div class="item titles"><span class="aht-title-view" tabindex="-1">[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공</span></div>
# <div class="item options">
# <div class="quick-tool">
# <button class="tool" data-tooltip="" onclick="articlePrint('101229')" tabindex="-1" title="인쇄" type="button"><i class="icon-print"><span class="show-for-sr">바로가기</span></i></button>
# <button class="tool sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-tooltip="" tabindex="-1" title="URL주소" type="button"><i class="icon-link"><span class="show-for-sr">복사하기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" tabindex="-1" title="본문글씨 줄이기" type="button" value="down"><i class="font-size down"><span class="show-for-sr">본문 글씨 줄이기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" tabindex="-1" title="본문글씨 키우기" type="button" value="up"><i class="font-size up"><span class="show-for-sr">본문 글씨 키우기</span></i></button>
# </div>
# </div>
# </div>
# <!--// 상단 컨텐츠 -->
# <!-- 스크롤 상태바 //-->
# <div class="aht-control">
# <div class="aht-bar user-border-top"><span class="show-for-sr">스크롤 이동 상태바</span></div>
# </div>
# <!--// 스크롤 상태바 -->
# </div>
# <!--// 기사면 상단 네비게이션 -->
# <!-- 기사본문 상단 //-->
# <header class="article-view-header">
# <!-- breadcrumbs //-->
# <nav role="navigation">
# <ul class="breadcrumbs">
# <li><a href="https://www.spnews.co.kr"><i class="icon-home"></i> 홈</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm">북한N</a></li>
# <li><a href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm">경제/산업</a></li>
# </ul>
# </nav>
# <h1 class="heading">[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공</h1>
# <!-- infomation  // -->
# <div class="info-group">
# <article class="item">
# <ul class="infomation">
# <li>
# <i class="icon-user-o"><span class="show-for-sr">기자명</span></i>
# 					안윤석 대기자				</li>
# <li><i class="icon-clock-o"></i> 입력 2025.11.12 07:00</li>
# <li><i class="icon-check-circle-o"></i> 수정 2025.11.12 07:11</li>
# <li><i class="icon-comment-o"></i> 댓글 0</li>
# </ul>
# </article>
# <article class="item">
# <div class="quick-tool">
# <button class="tool" data-tooltip="" onclick="articlePrint('101229')" title="인쇄" type="button"><i class="icon-print"><span class="show-for-sr">바로가기</span></i></button>
# <button class="tool sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-tooltip="" title="URL주소" type="button"><i class="icon-link"><span class="show-for-sr">복사하기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" title="본문글씨 줄이기" type="button" value="down"><i class="font-size down"><span class="show-for-sr">본문 글씨 줄이기</span></i></button>
# <button class="tool fontsise-btn" data-tooltip="" title="본문글씨 키우기" type="button" value="up"><i class="font-size up"><span class="show-for-sr">본문 글씨 키우기</span></i></button>
# </div>
# </article>
# </div>
# </header>
# <!--// 기사본문 상단 -->
# <section class="article-view-content" id="articleViewCon">
# <article class="grid body">
# <div class="sticky-article" id="snsAnchor">
# <aside class="article-sns" data-sticky-container="">
# <div class="sticky" data-anchor="snsAnchor" data-check-every="0" data-dynamic-height="false" data-margin-top="5" data-sticky="">
# <div class="social-group">
# <button aria-label="페이스북" class="sns sns-share-btns facebook" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="facebook" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="페이스북" type="button">
# <i class="icon-facebook"></i>
# </button>
# <button aria-label="트위터" class="sns sns-share-btns twitter" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="twitter" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="트위터" type="button">
# <i class="icon-twitter"></i>
# </button>
# <button aria-label="URL복사" class="sns sns-share-btns link sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="link" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="URL복사" type="button">
# <i class="icon-link"></i>
# </button>
# <button aria-label="이메일(으)로 기사보내기" class="sns mail" onclick="articleMail('101229')" title="이메일" type="button"><i class="icon-mail"></i></button>
# <button aria-label="다른공유찾기" class="sns share" data-open="article-sns" title="다른 공유" type="button"><i class="icon-share-alt"></i></button>
# <button aria-label="기사스크랩하기" class="sns bookmark scrap-btn user-bg" data-idxno="101229" title="기사스크랩" type="button"><i class="icon-bookmark"></i></button>
# <script>
# 					$(document).ready(function(e) {
# 						$('.scrap-btn').on('click', function(e) {
# 							var idxno = $(this).data('idxno');
#
# 							if(confirm("기사를 스크랩 하시겠습니까?")){
# 								$.ajax({
# 									type: 'post',
# 									dataType: 'json',
# 									url: '/news/articleScrap.ajax.php',
# 									data: {'tp':'A', 'idxno':idxno},
# 									success: function(data) {
# 										alert(data[1]);
# 									},
# 									error: function(error, request) {
# 										alert('error!!!');
# 										console.log("code:"+request.status+"\n"+"message:"+request.responseText+"\n"+"error:"+error);
# 									}
# 								});
# 							}
# 						});
# 					});
# 				</script>
# </div>
# </div>
# <div class="reveal" data-animation-in="fade-in" data-animation-out="fade-out" data-close-on-click="false" data-close-on-esc="false" data-reveal="" id="article-sns">
# <div class="reveal-header">
# <div class="reveal-title">이 기사를 공유합니다</div>
# </div>
# <section class="reveal-container">
# <div class="social-group for-other">
# <button aria-label="페이스북" class="sns sns-share-btns facebook" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="facebook" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="페이스북" type="button">
# <i class="icon-facebook"></i>
# </button>
# <button aria-label="트위터" class="sns sns-share-btns twitter" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="twitter" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="트위터" type="button">
# <i class="icon-twitter"></i>
# </button>
# <button aria-label="URL복사" class="sns sns-share-btns link sns_clipboard" data-clipboard-text="https://www.spnews.co.kr/news/articleView.html?idxno=101229" data-desc="%EB%B6%81%ED%95%9C%20%EA%B3%BC%EC%88%98%EC%9D%98%20%EA%B3%A0%ED%96%A5%EC%9D%B8%20%ED%95%A8%EA%B2%BD%EB%82%A8%EB%8F%84%20%EB%B6%81%EC%B2%AD%EA%B5%B0%EC%97%90%EC%84%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%EB%A5%BC%20%EB%A7%88%EB%AC%B4%EB%A6%AC%ED%96%88%EB%8B%A4.%EB%85%B8%EB%8F%99%EC%8B%A0%EB%AC%B8%EC%9D%80%2012%EC%9D%BC%20%5C%22%EC%88%98%EB%A7%8C%E3%8E%A1%EC%9D%98%20%EB%B6%80%EC%A7%80%EC%97%90%20%EC%97%B0%EA%B1%B4%EC%B6%95%EB%A9%B4%EC%A0%81%EC%9D%B4%201%EB%A7%8C%20%EC%88%98%EC%B2%9C%E3%8E%A1%EC%97%90%20%EC%9D%B4%EB%A5%B4%EB%8A%94%20%EC%82%AC%EB%AC%B4%EC%B2%AD%EC%82%AC%EC%99%80%20%EC%83%9D%EC%82%B0%EA%B1%B4%EB%AC%BC%EB%93%A4%EC%9D%84%20%EA%B0%9C%EA%B1%B4%ED%95%98%EA%B3%A0%20%EB%AA%A8%EB%93%A0%20%EA%B3%B5%EC%A0%95%EC%9D%B4%20%EC%9E%90%EB%8F%99%ED%99%94%2C%20%ED%9D%90%EB%A6%84%EC%84%A0%ED%99%94%EB%90%9C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%83%9D%EC%82%B0%EA%B8%B0%EC%A7%80%EB%A5%BC%20%EA%B1%B4%EC%84%A4%ED%96%88%EB%8B%A4%5C%22%EA%B3%A0%20%EB%B3%B4%EB%8F%84%ED%96%88%EB%8B%A4.%5C%22%EA%B3%B5%EC%9E%A5%EC%97%90%EC%84%9C%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EB%86%8D%EC%B6%95%EC%A6%99%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%BC%2C%20%EA%B3%BC%EC%9D%BC%EC%82%B4%EC%A6%99%EC%9D%8C%EB%A3%8C%2C%20%EB%A7%90%EB%A6%B0%EA%B3%BC%EC%9D%BC%2C%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EB%A3%A8%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EB%AC%B5%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EC%99%84%EA%B3%B5%ED%95%9C%EB%8D%B0%20%EC%9D%B4%EC%96%B4%20%EC%B5%9C%EA%B7%BC%20%EA%B3%BC%EC%9D%BC%ED%86%B5%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%8B%A8%EC%A1%B8%EC%9E%84%2C%20%EA%B3%BC%EC%9D%BC%EB%B0%9C%ED%9A%A8%EC%8B%9D%EC%B4%88%EC%83%9D%EC%82%B0%EA%B3%B5%EC%A0%95%EC%9D%84%20%EA%B0%84%EC%B6%B0%20%EC%B4%9D%209%EA%B0%80%EC%A7%80%EC%97%90%20%EB%8B%AC%ED%95%98%EB%8A%94%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%ED%92%88%EC%9D%84%20%EC%83%9D%EC%82%B0%ED%95%A0%20%EC%88%98%20%EC%9E%88%EB%8B%A4%5C%22%EA%B3%A0%20%EC%86%8C%EA%B0%9C%ED%96%88%EB%8B%A4.%EC%8B%A0%EB%AC%B8%EC%9D%80%20%EB%98%90%20%5C%22%ED%99%A9%ED%95%B4%EB%B6%81%EB%8F%84%EB%86%8D%EC%97%85%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C%EC%97%90%EC%84%9C%20%EC%A7%80%EC%97%AD%EC%9D%98%20%EA%B8%B0%EC%83%81%EA%B8%B0%ED%9B%84%EC%A0%81%20%ED%8A%B9%EC%84%B1%EC%97%90" data-image="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" data-sharesns="link" data-title="%5B%EB%B6%81%ED%95%9C%20%EA%B2%BD%EC%A0%9C%20%EB%8B%A8%EC%8B%A0%5D%20%ED%95%A8%EB%82%A8%20%EB%B6%81%EC%B2%AD%EA%B5%B0%20%EA%B3%BC%EC%9D%BC%EA%B0%80%EA%B3%B5%EA%B3%B5%EC%9E%A5%20%EA%B0%9C%EA%B1%B4%ED%98%84%EB%8C%80%ED%99%94%EA%B3%B5%EC%82%AC%20%EC%A4%80%EA%B3%B5" data-url="https%3A%2F%2Fwww.spnews.co.kr%2Fnews%2FarticleView.html%3Fidxno%3D101229" title="URL복사" type="button">
# <i class="icon-link"></i>
# </button>
# </div>
# </section>
# <!-- close //-->
# <button aria-label="Close modal" class="close-button" data-close="" type="button">
# <i class="icon-close-thin"><span class="show-for-sr">닫기</span></i>
# </button>
# <!--// close -->
# </div>
# </aside>
# <div class="article-body">
# <h2 class="subheading">"황해북도농업과학연구소, 기상기후적 특성에 맞는 두벌농사다수확재배기술 개발도입"</h2>
# <!-- contents //-->
# <article class="article-veiw-body view-page" id="article-view-content-div" itemprop="articleBody">
# <div style="text-align:center">
# <figure class="photo-layout image photo_101943 float-center" data-idxno="101943" data-type="photo" style="display:inline-block; max-width:600px"><div class="IMGFLOATING" style="position:relative;">
# <img alt="북한 함경남도 북청군 과수농장에서 사과를 수확하고 있다.(사진=노동신문/뉴스1)" height="371" loading="lazy" src="https://cdn.spnews.co.kr/news/photo/202511/101229_101943_843.jpg" width="600"/></div>
# <figcaption class="text-left">북한 함경남도 북청군 과수농장에서 사과를 수확하고 있다.(사진=노동신문/뉴스1)</figcaption>
# </figure>
# </div>
# <p style="text-align: justify;"><span style="font-size:18px;">북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.</span></p>
# <p style="text-align: justify;"><span style="font-size:18px;">노동신문은 12일  "수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생산건물들을 개건하고 모든 공정이 자동화, 흐름선화된 과일가공품생산기지를 건설했다"고 보도했다.</span></p>
# <p style="text-align: justify;"><span style="font-size:18px;">"공장에서는 과일농축즙, 과일단물, 과일살즙음료, 말린과일, 과일가루, 과일단묵생산공정을 완공한데 이어 최근 과일통졸임, 과일단졸임, 과일발효식초생산공정을 간춰 총 9가지에 달하는 과일가공품을 생산할 수 있다"고 소개했다.</span></p>
# <p style="text-align: justify;"><span style="font-size:18px;">신문은 또 "황해북도농업과학연구소에서 지역의 기상기후적 특성에 맞는 두벌농사다수확재배기술을 개발도입했다"고 전했다.</span></p><!--기사뷰_본문 50%//-->
# <style>#AD173068083778.ad-template { margin:auto; position:relative; display:block; clear:both; z-index:1; padding-bottom:20px; }
# #AD173068083778.ad-template .col { text-align:center; }
# #AD173068083778.ad-template .col .ad-view { position:relative; }</style>
# <!-- AD Manager | AD173068083778 //-->
# <div class="ad-template" id="AD173068083778">
# <div class="col"><div class="ad-view"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:본문내중단 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23209796428"></ins>
# </div></div>
# </div>
# <!--// AD Manager | AD173068083778 -->
# <p style="text-align: justify;"><span style="font-size:18px;">"연구소에서 올해 생육기일이 짧으면서도 가뭄견딜성이 강하고 불리한 토양조건에서도 수확고가 높은 다수확품종을 육종해 국가품종으로 등록되게 했으며, 재배기술을 확립했다"고 밝혔다.</span></p>
# <p style="text-align: justify;"><span style="font-size:18px;">"연구소에서는 새로 육종한 다수확품종을 도내 농촌에 확대도입하고 사리원시와 서흥군, 은파군 등 여러 지역에 연구사들을 파견해 재배기술을 보급일반화하는 사업을 진행했다"고 신문은 덧붙였다.@ </span></p><!--기사뷰_바이라인 상단//-->
# <style>#AD173068095021.ad-template { margin:auto; position:relative; display:block; clear:both; z-index:1; }
# #AD173068095021.ad-template .col { text-align:center; }
# #AD173068095021.ad-template .col .ad-view { position:relative; }</style>
# <!-- AD Manager | AD173068095021 //-->
# <div class="ad-template" id="AD173068095021">
# <div class="col"><div class="ad-view"><div>
# <span style="display:inline-block; margin-right:15px;"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:바이라인상단좌측 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23209796035"></ins>
# </span> <span style="display:inline-block;"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:바이라인상단우측 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23209877486"></ins></span>
# </div></div></div>
# </div>
# <!--// AD Manager | AD173068095021 -->
# <script>
# 	$(function() {
#         // 주소복사 이벤트 (v11-fl-v2 수정)
#                 Util.copyExec(".urlBtns, .sns_clipboard");
#
#         // 사진 lightBox 이벤트
#         if (typeof ImageViewer != "undefined") {
#             new ImageViewer(".photo-layout", 0);
#         }
# 	});
# </script> </article>
# <article class="writer">
# <div class="item">
# <div class="account">
# <em class="image" style="background-image:url('https://cdn.spnews.co.kr/image/newsroom/default-user.png')"></em>
# <a class="name" href="https://www.spnews.co.kr/news/articleList.html?sc_area=I&amp;sc_word=ysan777&amp;view_type=sm">안윤석 대기자</a>
# <a class="email" href="mailto:ysan777@spnews.co.kr">ysan777@spnews.co.kr</a>
# </div>
# </div>
# <div class="item text-right">
# <a class="article-more" href="https://www.spnews.co.kr/news/articleList.html?sc_area=I&amp;sc_word=ysan777&amp;view_type=sm">다른기사 보기</a> </div>
# </article>
# <article class="article-copy">저작권자 © SPN 서울평양뉴스 무단전재 및 재배포 금지</article>
# </div>
# </div>
# <!--기사뷰_바이라인 하단//-->
# <style>#AD173068101992.ad-template { margin:auto; position:relative; display:block; clear:both; z-index:1; }
# #AD173068101992.ad-template .col { text-align:center; }
# #AD173068101992.ad-template .col .ad-view { position:relative; }</style>
# <!-- AD Manager | AD173068101992 //-->
# <div class="ad-template" id="AD173068101992">
# <div class="col"><div class="ad-view"><!-- MEDIA_847_SPNEWS_CO_KR_GRP_DEVICE:PC#기사페이지#UNIT:바이라인하단1 -->
# <ins class="adsbyaiinad" data-aiinad-inv="23210836041"></ins>
# </div></div>
# </div>
# <!--// AD Manager | AD173068101992 -->
# <div class="clearfix respons-edit">
# <div class="float-left padright-40" style="width:calc(100% - 250px)">
# </div>
# <div class="float-right" style="width:250px">
# </div>
# </div>
# <!-- 댓글 //-->
# <article class="default" id="comment">
# <header class="cmt-header" id="reply">
# <div class="titles"><strong class="comment-count"></strong>개의 댓글</div>
# </header>
# <!-- write //-->
# <article class="comment-write">
# <form class="comment-form" method="POST" name="commentWriteForm">
# <input class="mode" name="mode" type="hidden" value="input">
# <input class="service-name" name="service_code" type="hidden" value="news">
# <input class="parent-idxno" name="parent_idxno" type="hidden" value="101229">
# <input class="reply-parent-idxno" name="reply_parent_idxno" type="hidden" value=""/>
# <input class="user-id" name="user_id" type="hidden" value=""/>
# <header class="wrt-header">
# <a class="user-name btn-comment-login" href="https://www.spnews.co.kr/member/login.html?backUrl=/news/articleView.html?idxno=101229#comment">회원로그인</a>
# <article id="comment-guest">
# <label class="show-for-sr" for="guestName">작성자</label>
# <input id="guestName" name="name" placeholder="작성자" title="작성자" type="text" value=""/>
# <label class="show-for-sr" for="guestPassword">비밀번호</label>
# <input id="guestPassword" name="password" placeholder="비밀번호" title="비밀번호" type="password" value=""/>
# </article>
# </header>
# <label class="show-for-sr" for="cmtContent">댓글 내용입력</label>
# <textarea class="comment-content" id="cmtContent" name="content" placeholder="권리침해, 욕설 및 특정 대상을 비하하는 내용을 게시할 경우 이용약관 및 관련법률에 의해 제재될 수 있습니다. 회원 로그인을 하시면 댓글 작성이 간편합니다." title="댓글 내용입력"></textarea>
# <div class="recaptcha-container"></div>
# <footer class="wrt-footer">
# <span class="cur--length"><strong class="comment-text-cur">0</strong> / 400</span>
# <button class="btn-comment-save user-bg" type="button">등록</button>
# </footer>
# </input></input></input></form>
# </article>
# <!--// write -->
# <!-- list //-->
# <article id="comment-list">
# <header class="list-sort">
# <div class="show-for-sr">댓글 정렬</div>
# <div class="option">
# <button class="btn-comment-orderby btn-comment-orderby-I" data-data="I" type="button">최신순</button>
# <button class="btn-comment-orderby btn-comment-orderby-C" data-data="C" type="button">추천순</button>
# <button class="btn-comment-orderby btn-comment-orderby-R" data-data="R" type="button">답글순</button>
# </div>
# <div class="explain">
# <div class="explain-btn" data-toggle="guide-panel" role="button"><i class="icon-info-o"></i> BEST댓글</div>
# <div class="guide" data-animate="fade-in fade-out" data-closable="" data-toggler="" id="guide-panel">
# <strong>BEST 댓글</strong>
# 					답글과 추천수를 합산하여 자동으로 노출됩니다.
# 					<button class="close-button" data-close=""><i class="icon-close-thin"><span class="show-for-sr">닫기</span></i></button>
# </div>
# </div>
# </header>
# <section class="best-content">
# <!-- BEST 댓글 -->
# </section>
# <section class="normal-content">
# <!-- 기본 댓글 -->
# </section>
# <button class="btn-comment-more" type="button"><span>더보기</span></button>
# </article>
# <!--// list -->
# </article>
# <!--// 댓글 -->
# <!-- 댓글삭제 //-->
# <form class="reveal comment-form" data-animation-in="fade-in" data-animation-out="fade-out" data-close-on-click="false" data-close-on-esc="false" data-reveal="" id="comment-reveal-delete" method="POST" name="commentDeleteForm">
# <input class="service-name" name="service_code" type="hidden" value="news"/>
# <input class="table-name" name="table_name" type="hidden" value="article_reply"/>
# <input class="parent-idxno" name="parent_idxno" type="hidden" value="101229"/>
# ...
# </ul>
# <div class="ndsoft">
# <a href="http://www.ndsoft.co.kr/" rel="nofollow sponsored ugc" target="_blank"><img alt="ND소프트" height="9" loading="lazy" src="https://cdn.spnews.co.kr/image/ndsoft.svg" width="72"/></a>
# </div>
# </address>
# </div>
# </div>
# </div>
# </footer>
# <div class="clearfix text-center">
# </div>
# <button aria-label="위로" class="back-to-top" id="back-to-top" type="button"></button>
# <a class="desktop-to-mobile hide" href="https://www.spnews.co.kr/news/articleView.html?idxno=101229" onclick="setCookie('view_pc', 'n', 1);">모바일버전</a>
# </div>
# </div>
# <div class="off-canvas position-left global-menu-wrapper" data-content-scroll="false" data-off-canvas="" data-transition="slide" id="offCanvas" tabindex="-1">
# <nav class="global-menu-container">
# <header class="global-menu-header">
# <a class="global-menu-title" href="https://www.spnews.co.kr" target="_top">SPN 서울평양뉴스</a>
# <button aria-label="close global menu" class="btn-close ms-auto" data-close="" type="button"></button>
# </header>
# <main class="global-menu-body">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link active" href="https://www.spnews.co.kr/news/articleList.html?view_type=sm" target="_top">전체기사</a>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N16" target="_top">북한N</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N16&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N17&amp;view_type=sm" target="_top">정치</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N18&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N19&amp;view_type=sm" target="_top">군사</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm" target="_top">경제/산업</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N21&amp;view_type=sm" target="_top">사회/문화/체육</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N42&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N17" target="_top">서울&amp;</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N17&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N22&amp;view_type=sm" target="_top">대통령실/총리실</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N23&amp;view_type=sm" target="_top">통일</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N24&amp;view_type=sm" target="_top">외교</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N25&amp;view_type=sm" target="_top">국방</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N26&amp;view_type=sm" target="_top">종합</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N6" target="_top">한반도W</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N6&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N12&amp;view_type=sm" target="_top">미주</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N13&amp;view_type=sm" target="_top">유럽,아프리카</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N14&amp;view_type=sm" target="_top">아시아,호주</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N16&amp;view_type=sm" target="_top">국제기구</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item" data-accordion-item="">
# <a class="global-menu-link" href="#S1N19" target="_top">이슈+</a>
# <div class="global-menu-content" data-tab-content="">
# <ul class="global-menu" data-accordion="" data-allow-all-closed="true">
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N19&amp;view_type=sm" target="_top">전체</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N38&amp;view_type=sm" target="_top">전문가분석</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N39&amp;view_type=sm" target="_top">노동신문 분석</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N32&amp;view_type=sm" target="_top">칼럼</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N33&amp;view_type=sm" target="_top">학술</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N34&amp;view_type=sm" target="_top">행사</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N35&amp;view_type=sm" target="_top">인터뷰/사람들</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N36&amp;view_type=sm" target="_top">미션/한민족</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N37&amp;view_type=sm" target="_top">인사/동정</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N40&amp;view_type=sm" target="_top">NK 리포트</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N41&amp;view_type=sm" target="_top">북한 경제산업 동향</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N43&amp;view_type=sm" target="_top">나의 길</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N10&amp;view_type=sm" target="_top">오늘의 북한</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N11&amp;view_type=sm" target="_top">SPN TV</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N20&amp;view_type=sm" target="_top">SPNGO</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N21&amp;view_type=sm" target="_top">평양 사이언스</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N22&amp;view_type=sm" target="_top">최일 함장의 잠수함 리얼리티</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N23&amp;view_type=sm" target="_top">노동신문 돋보기</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N24&amp;view_type=sm" target="_top">NK 농업</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N25&amp;view_type=sm" target="_top">NK 건설</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N26&amp;view_type=sm" target="_top">NK 위성포커스</a>
# </li>
# <li class="global-menu-item">
# <a class="global-menu-link" href="https://www.spnews.co.kr/news/articleList.html?sc_section_code=S1N27&amp;view_type=sm" target="_top">K-방산</a>
# </li>
# </ul>
# </main>
# </nav>
# </div>
# <script>
# const bannerpop = new Bannerpop();
# // Popup Json
# var ___popup = [];
# bannerpop.popup();
# </script>
# <script>
# // back to the top
# $(document).scroll(function(){
# 	var sDocumentHeight = $(document).height() - $(window).height();
# 	if($(document).scrollTop() > 0){
# 		$('#back-to-top').fadeIn();
# 	}else{
# 		$('#back-to-top').fadeOut();
# 	}
# });
#
# $('#back-to-top, a[href="#top"]').click(function(){
# 	$('html, body').animate( {scrollTop:0}, 100);
# });
#
# // 모바일버전 이동 버튼
# if (Util.isMobileDevice() === true) $(".desktop-to-mobile").removeClass("hide");
# </script>
# <!-- 구글 애드센스 S -->
# <script src="https://cdn.spnews.co.kr/adManager/js/lab.js"></script>
# <script>
# jQuery(function($) {
# 	setTimeout(function() {
# 		$LAB
# 		.script("//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js")
# 		.wait(function () {
# 			var adn = jQuery('.adsbygoogle').length;
# 			if (adn > 0) {
# 				for (var i = 0; i < adn; i++) {
# 					(adsbygoogle = window.adsbygoogle || []).push({});
# 				}
# 			}
# 		});
# 	}, 1000);
# });
# </script>
# <!-- 구글 애드센스 E -->
# <script>
# $(document).ready(function(){
# 	// 닫기 버튼 자동 노출
# 	$('.ad-template.ad-close .ad-view').each(function(){
# 		$(this).append('<div class="ad-close-btn"><i class="icon-close"></i></div>');
# 	})
#
# 	// 닫기 버튼 클릭 시 이벤트
# 	$('body').on('click', '.ad-close-btn', function(){
# 		$(this).closest('.ad-view').slideUp();
# 	})
#
# 	// isND
# 	var ____is_nd = getCookie('____is_nd');
# 	if(____is_nd) {
# 				// ND IP만 광고 ID 보이기
# 		$('.ad-template').each(function(){
# 			$(this).append('<div class="ad-code-id">'+$(this).attr('id')+'</div>');
# 		})
#
# 				// 광고 ID 자동 숨김 설정 시
# 		$('.ad-code-id').hide();
#
# 		$('.ad-template').mouseenter(function(){
# 			$(this).find('.ad-code-id').show();
# 		}).mouseleave(function(){
# 			$(this).find('.ad-code-id').hide();
# 		})
#
#
# 			}
# })
#
#
#
# /* ****************************************** */
# /* 날개배너 스크립트  */
# /* ****************************************** */
# $('#wingBanner .wing-banner-left .wing-banner').each(function(){
# 	if( $(this).data('scroll') == 'y' ) $(this).addClass('scroll-on');
# });
#
# $(window).scroll(function() {
# 	if( $('#wingBanner .wing-banner').length > 0 ){											// 날개배너가 있으면 작동
#
# 		var scrollingHeight_L = nonScrollingHeight_L = scrollingHeight_R = nonScrollingHeight_R = 0;
#
# 		$('#wingBanner .wing-banner').each(function(idx){
# 			var $_this		= $(this),														// 날개배너
# 				scroll		= $_this.data('scroll'),										// 날개배너 스크롤 여부
# 				topMargin	= $_this.data('top-margin'),									// 날개배너 상단여백
# 				downMargin	= $_this.data('down-margin'),									// 날개배너 하단여백
# 				duration	= $_this.data('duration'),										// 날개배너 스크롤 속도
# 				direction	= $_this.data('direction'),										// 날개배너 위치
# 				// bannerTop	= $_this.offset().top,											// 날개배너 상단 위치 (가변)
# 				bannderHeight = $_this.outerHeight();										// 날개배너 높이 (고정)
#
# 			var fixWingBannertop	= $('#wingBanner').offset().top;						// 날개배너 상단 위치 (고정)
#
# 			var articleTitleHeight	= $('#sticky-header.scroll').height();			// 날개배너 스크롤 시 상단 타이틀 높이 (기사 본문 시)
# 			if(!articleTitleHeight) articleTitleHeight = 0;
#
# 			var $_userFooter		= $('#user-footer'),									// 사이트 Footer
# 				userFooterHeight	= $_userFooter.outerHeight();							// 사이트 Footer 높이 (고정)
#
# 			var winScrollTop		= $(window).scrollTop(),								// 윈도우 스크롤 위치 (가변)
# 				winHeight			= $(window).height(),									// 윈도우 높이
# 				docHeight			= $(document).height();									// 페이지 높이
#
# 			switch (direction) {															// 날개 배너 위치 별
# 				case 'left':
# 					if(scroll == 'y') scrollingHeight_L += bannderHeight;					// 순서대로 노출되는 날개배너 중 스크롤 하는 배너의 높이값 (좌)
# 					else nonScrollingHeight_L += bannderHeight;								// 순서대로 노출되는 날개배너 중 스크롤 하지 않는 배너의 높이값 (좌)
# 					break;
#
# 				case 'right':
# 					if(scroll == 'y') scrollingHeight_R += bannderHeight;					// 순서대로 노출되는 날개배너 중 스크롤 하는 배너의 높이값 (우)
# 					else nonScrollingHeight_R += bannderHeight;								// 순서대로 노출되는 날개배너 중 스크롤 하지 않는 배너의 높이값 (우)
# 					break;
# 			}
#
# 			if(scroll == 'y') {																// 스크롤 배너만 움직임 처리
# 				var bannerAllHeight = siteAllHeight = 0;
#
# 				// 좌우측 각각 배너 스크롤 처리를 위해 나눠서 처리
# 				if(direction == 'left'){																			// 좌측 날개
# 					var wingBnTop_L = winScrollTop - fixWingBannertop + topMargin - nonScrollingHeight_L;			// 날개배너 스크롤 위치 (가변)
#
# 					if( articleTitleHeight ) wingBnTop_L += articleTitleHeight;										// 기사본문 시 상단 스크롤 타이틀이 나타나면 스크롤 타이틀 만큼 날개배너 위치 조정
#
# 					if((fixWingBannertop + nonScrollingHeight_L) < winScrollTop) {
#
# 						bannerAllHeight = articleTitleHeight + scrollingHeight_L + 1;								// 상단 타이틀 + 스크롤배너의 총 높이
# 						siteAllHeight = winHeight - userFooterHeight + downMargin;									// 윈도우 높이 + 사이트 Footer 높이
#
# 						if( (winScrollTop >= ((docHeight - userFooterHeight) - winHeight)) && (bannerAllHeight >= siteAllHeight) ) {					// 사이트 Footer 넘어가는 경우 처리
# 							wingBnTop_L -= ((userFooterHeight + downMargin) - (winHeight - (scrollingHeight_L + topMargin + articleTitleHeight)));
# 							$('#wingBanner .wing-banner-left .wing-banner.scroll-on').animate({top:wingBnTop_L+"px" },{queue: false, duration: duration});		// 마지막 배너 움직임 처리
# 						}
# 					} else {
# 						wingBnTop_L = 0;																			// 최상단 처리
# 					}
# 					$_this.animate({top:wingBnTop_L+"px" },{queue: false, duration: duration});
#
# 				} else {																							// 우측 날개
#
# 					var wingBnTop_R = winScrollTop - fixWingBannertop + topMargin - nonScrollingHeight_R;			// 날개배너 스크롤 위치 (가변)
#
# 					if( articleTitleHeight ) wingBnTop_R += articleTitleHeight;										// 기사본문 시 상단 스크롤 타이틀이 나타나면 스크롤 타이틀 만큼 날개배너 위치 조정
#
# 					if((fixWingBannertop + nonScrollingHeight_R) < winScrollTop) {
#
# 						bannerAllHeight = articleTitleHeight + scrollingHeight_R + 1;								// 상단 타이틀 + 스크롤배너의 총 높이
# 						siteAllHeight = winHeight - userFooterHeight + downMargin;									// 윈도우 높이 + 사이트 Footer 높이
#
# 						if( (winScrollTop >= ((docHeight - userFooterHeight) - winHeight)) && (bannerAllHeight >= siteAllHeight) ) {					// 사이트 Footer 넘어가는 경우 처리
# 							wingBnTop_R -= ((userFooterHeight + downMargin) - (winHeight - (scrollingHeight_R + topMargin + articleTitleHeight)));
# 							$('#wingBanner .wing-banner-right .wing-banner.scroll-on').animate({top:wingBnTop_R+"px" },{queue: false, duration: duration});		// 마지막 배너 움직임 처리
# 						}
# 					} else {
# 						wingBnTop_R = 0;																			// 최상단 처리
# 					}
# 					$_this.animate({top:wingBnTop_R+"px" },{queue: false, duration: duration});
# 				}
# 			}
# 		});
# 	}
#
# });
# </script>
# </body>

# %% [markdown]
# <p style="text-align: justify;">

# %%
article_body = soup.find("div", class_ = "")
article_body

# %% [markdown]
# **[URL]**

# %%
url = soup.find("meta", property = "og:url")
article_url = url["content"]
article_url
# Out:
# 'https://www.spnews.co.kr/news/articleView.html?idxno=101229'

# %% [markdown]
# **[Title]**

# %%
article_header = soup.find("h1", class_ = "heading")
article_header
# Out:
# <h1 class="heading">[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공</h1>

# %% [markdown]
# **[Author]**

# %%
tag = soup.find("i", class_="icon-user-o")
author = tag.parent.get_text(strip=True)  # '입력 2025.11.12 07:00'
author_clean = author.replace("기자명", "").strip()
author_clean
# Out:
# '안윤석 대기자'

# %% [markdown]
# **[Category]**

# %% [markdown]
# <a href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N19&amp;view_type=sm">군사</a>
# <a href="https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm">경제/산업</a>

# %%
a = soup.find("a", href = "https://www.spnews.co.kr/news/articleList.html?sc_sub_section_code=S2N20&amp;view_type=sm")
a

# %%
breadcrumb = soup.find("ul", class_="breadcrumbs")
category = None

for a in breadcrumb.find_all("a"):
    text = a.get_text(strip=True)
    if text in ["정치", "외교", "군사", "경제/산업", "사회/문화/체육"]:
        category = text
        break

print(category)
# Out:
# 경제/산업

# %% [markdown]
# **[Publish_date]**

# %%
tag = soup.find("i", class_="icon-clock-o")
publish_date = tag.parent.get_text(strip=True)  # '입력 2025.11.12 07:00'
publish_date_clean = publish_date.replace("입력", "").strip()
publish_date_clean
# Out:
# '2025.11.12 07:00'

# %% [markdown]
# **[Contents]**

# %%
article_body = soup.find_all("span", style = "font-size:18px;")
article_body
# Out:
# [<span style="font-size:18px;">북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.</span>,
#  <span style="font-size:18px;">노동신문은 12일  "수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생산건물들을 개건하고 모든 공정이 자동화, 흐름선화된 과일가공품생산기지를 건설했다"고 보도했다.</span>,
#  <span style="font-size:18px;">"공장에서는 과일농축즙, 과일단물, 과일살즙음료, 말린과일, 과일가루, 과일단묵생산공정을 완공한데 이어 최근 과일통졸임, 과일단졸임, 과일발효식초생산공정을 간춰 총 9가지에 달하는 과일가공품을 생산할 수 있다"고 소개했다.</span>,
#  <span style="font-size:18px;">신문은 또 "황해북도농업과학연구소에서 지역의 기상기후적 특성에 맞는 두벌농사다수확재배기술을 개발도입했다"고 전했다.</span>,
#  <span style="font-size:18px;">"연구소에서 올해 생육기일이 짧으면서도 가뭄견딜성이 강하고 불리한 토양조건에서도 수확고가 높은 다수확품종을 육종해 국가품종으로 등록되게 했으며, 재배기술을 확립했다"고 밝혔다.</span>,
#  <span style="font-size:18px;">"연구소에서는 새로 육종한 다수확품종을 도내 농촌에 확대도입하고 사리원시와 서흥군, 은파군 등 여러 지역에 연구사들을 파견해 재배기술을 보급일반화하는 사업을 진행했다"고 신문은 덧붙였다.@ </span>]

# %%
contents = "\n".join(i.get_text(strip = True) for i in article_body)
contents_clean = contents.rstrip("@")
contents_clean
# Out:
# '북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.\n노동신문은 12일\xa0\xa0"수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생산건물들을 개건하고 모든 공정이 자동화, 흐름선화된 과일가공품생산기지를 건설했다"고 보도했다.\n"공장에서는\xa0과일농축즙, 과일단물, 과일살즙음료, 말린과일, 과일가루, 과일단묵생산공정을 완공한데 이어 최근 과일통졸임, 과일단졸임, 과일발효식초생산공정을 간춰 총 9가지에 달하는 과일가공품을 생산할 수 있다"고 소개했다.\n신문은 또 "황해북도농업과학연구소에서 지역의 기상기후적 특성에 맞는 두벌농사다수확재배기술을 개발도입했다"고 전했다.\n"연구소에서 올해 생육기일이 짧으면서도 가뭄견딜성이 강하고 불리한 토양조건에서도 수확고가 높은 다수확품종을 육종해 국가품종으로 등록되게 했으며, 재배기술을 확립했다"고 밝혔다.\n"연구소에서는 새로 육종한 다수확품종을 도내 농촌에 확대도입하고 사리원시와 서흥군, 은파군 등 여러 지역에 연구사들을 파견해 재배기술을 보급일반화하는 사업을 진행했다"고 신문은 덧붙였다.'

# %% [markdown]
# ### **[Crawler Ver1]**

# %%
class ArticleCrawling:

    def __init__(self, url):
        self.url = url
        self.soup = self._get_soup()

    def _get_soup(self):
        response = requests.get(self.url)
        return BeautifulSoup(response.text, 'html.parser')
    
    def get_article_url(self):
        meta_tag = self.soup.find("meta", property = "og:url")
        return meta_tag["content"] if meta_tag else None
    
    def get_id(self):
        url = self.get_article_url()    # https://www.spnews.co.kr/news/articleView.html?idxno=101049

        # source(spnew, ytn 등등)
        source = url.split("//")[1]
        source = source.split("/")[0]
        source = source.replace("www.", "").split(".")[0].lower()

        # id
        if "idxno" not in url:
            return None
        idx = url.split("idxno=")[1]
        return f"{source}_{idx}"
    
    def get_source(self):
        url = self.get_article_url()
        if not url:
            return None

        source = url.split("//")[1]
        source = source.split("/")[0]
        source = source.replace("www.", "").split(".")[0].lower()
        return source
    
    def get_title(self):
        header = self.soup.find("h1", class_ = "heading")
        return header.get_text(strip = True) if header else None
      
    def get_author(self):
        tag = self.soup.find("i", class_ = "icon-user-o")
        if tag:
            author = tag.parent.get_text(strip = True)
            return author.replace("기자명", "").strip()
        
    def get_section(self):
        breadcrumb = self.soup.find("ul", class_="breadcrumbs")
        if breadcrumb:
            for a in breadcrumb.find_all("a"):
                text = a.get_text(strip = True)
                if text in ["북한N", "서울&", "한반도W", "이슈+"]:   
                    return text
        return None
              
    def get_category(self):
        breadcrumb = self.soup.find("ul", class_ = "breadcrumbs")
        if breadcrumb:
            for a in breadcrumb.find_all("a"):
                text = a.get_text(strip = True)
                if text in ["정치", "외교", "군사", "경제/산업", "사회/문화/체육"]:
                    return text
    
    def get_publish_date(self):
        tag = self.soup.find("i", class_ = "icon-clock-o")
        if tag:
            raw = tag.parent.get_text(strip = True)
            raw = raw.replace("입력", "").strip()
            date = datetime.strptime(raw, "%Y.%m.%d %H:%M")  # 2025.11.17 07:47
            return date.strftime("%Y-%m-%d")
        
    def get_contents(self):
        article_body = self.soup.find_all("span", style = "font-size:18px;")
        contents = "\n".join(i.get_text(strip = True) for i in article_body)
        # return contents.rstrip("@") 
        return contents.split('@')[0].strip()
    
    def to_dict(self):
        return {
        
        "id": self.get_id(),
        "title": self.get_title(),
        "contents": self.get_contents(),
        "source": self.get_source(),
        "section": self.get_section(),
        "author": self.get_author(),
        "publish_date": self.get_publish_date(),
        "url": self.get_article_url(),
        "category": self.get_category(),

        
            # {
            #     "summary": ,
            #     "vector": ,
            #     "keywords": ,     >> 별개의 db로?
            # }
        }
    
    def __str__(self):
        data = self.to_dict()
        return "\n".join(f"{k}: {v}" for k, v in data.items())

# %% [markdown]
# ### **[Crawler Ver2]**

# %%
class ArticleCrawling2:

    def __init__(self, url):
        self.url = url
        self.soup = self._get_soup()

    def _get_soup(self):
        response = requests.get(self.url)
        return BeautifulSoup(response.text, 'html.parser')
    
    def get_article_url(self):
        meta_tag = self.soup.find("meta", property = "og:url")
        return meta_tag["content"] if meta_tag else None
    
    def get_id(self):
        url = self.get_article_url()    # https://www.spnews.co.kr/news/articleView.html?idxno=101049

        # source(spnew, ytn 등등)
        source = url.split("//")[1]
        source = source.split("/")[0]
        source = source.replace("www.", "").split(".")[0].lower()

        # id
        if "idxno" not in url:
            return None
        idx = url.split("idxno=")[1]
        return f"{source}_{idx}"
    
    def get_source(self):
        url = self.get_article_url()
        if not url:
            return None

        source = url.split("//")[1]
        source = source.split("/")[0]
        source = source.replace("www.", "").split(".")[0].lower()
        return source
    
    def get_title(self):
        header = self.soup.find("h1", class_ = "heading")
        return header.get_text(strip = True) if header else None
      
    def get_author(self):
        tag = self.soup.find("i", class_ = "icon-user-o")
        if tag:
            author = tag.parent.get_text(strip = True)
            return author.replace("기자명", "").strip()
        
    def get_section(self):
        breadcrumb = self.soup.find("ul", class_="breadcrumbs")
        if breadcrumb:
            for a in breadcrumb.find_all("a"):
                text = a.get_text(strip = True)
                if text in ["북한N", "서울&", "한반도W", "이슈+"]:   
                    return text
        return None
              
    def get_category(self):
        breadcrumb = self.soup.find("ul", class_ = "breadcrumbs")
        if breadcrumb:
            for a in breadcrumb.find_all("a"):
                text = a.get_text(strip = True)
                if text in ["정치", "외교", "군사", "경제/산업", "사회/문화/체육"]:
                    return text
    
    def get_publish_date(self):
        tag = self.soup.find("i", class_ = "icon-clock-o")
        if tag:
            raw = tag.parent.get_text(strip = True)
            raw = raw.replace("입력", "").strip()
            date = datetime.strptime(raw, "%Y.%m.%d %H:%M")  # 2025.11.17 07:47
            return date.strftime("%Y-%m-%d")
        
    def get_contents(self):
        spans = self.soup.find_all("span", style = "font-size:18px;")
        if spans:
            contents = "\n".join(i.get_text(strip = True) for i in spans)
            return contents.split('@')[0].strip()
        
        articles = self.soup.find("article", id = "article-view-content-div")
        if articles:
            ps = articles.find_all("p")
            if ps:
                contents = "\n".join(p.get_text(strip=True) for p in ps)
                return contents.split("@")[0].strip()
                
        justify_ps = self.soup.find_all("p", style=lambda v: v and "text-align: justify" in v)
        if justify_ps:
            contents = "\n".join(p.get_text(strip=True) for p in justify_ps)
            return contents.split("@")[0].strip()
    
        return None
            
    def to_dict(self):
        return {
        
        "id": self.get_id(),
        "title": self.get_title(),
        "contents": self.get_contents(),
        "source": self.get_source(),
        "section": self.get_section(),
        "author": self.get_author(),
        "publish_date": self.get_publish_date(),
        "url": self.get_article_url(),
        "category": self.get_category(),

        
            # {
            #     "summary": ,
            #     "vector": ,
            #     "keywords": ,     >> 별개의 db로?
            # }
        }
    
    def __str__(self):
        data = self.to_dict()
        return "\n".join(f"{k}: {v}" for k, v in data.items())

# %% [markdown]
# ### **[Crawler Test]**

# %%
test1 = ArticleCrawling("https://www.spnews.co.kr/news/articleView.html?idxno=101049")

# %%
print(test1)
# Out:
# id: spnews_101049
# title: 北, 김영남 상임위원장 영결식...김정은 참석
# contents: 고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로 치뤄졌다.
# 노동신문은 6일 김영남 전 상임위원장 장례소식을 전하면서 "고인의 영구가 안치된 서장회관은 특출한 공적을 남긴 노세대혁명가를 잃은 커다란 비애에 휩싸여있었다"고 보도했다.
# "국가장의식에는 당 정치국 상무위원과 국가장의위원회 위원, 당중앙위원회와 최고인민회의 상임위원회, 내각, 성, 중앙기관, 무력기관의 일꾼, 고인의 유가족 등이 참석했다"고 전했다.
# "추도곡이 울리는 가운데 고 김영남 상임위원장의 영구를 발인하는 의식이 진행됐으며, 수많은 평양시민들이 신미리애국열사릉으로 향한 연도마다에서 영구차에 조의를 표시했다"고 덧붙였다.
# 영결식은 신미리애국렬사릉에서 김정은 총비서가 참석한 가운데 열렸다.
# "김 총비서는 당과 정부의 지도간부들과 열사릉 입구에서 고 김영남 동지의 영구를 맞이했다"고 신문은 전했다.
# 박태성 내각총리는 애도사에서 "김 상임위원장은 80여 성상 당을 따르고 당과 함께 영광의 일대기를 새겨오면서 국가의 정치사상적 위력과 권익을 수호하는데 뚜렷한 자욱을 새겨온 조선인민이 낳은 우수하고 열렬한 혁명가, 참다운 애국자의 한사람이었다"고 추모했다.
# "김 총비서는 애국열사릉의 추모비 앞에서 전체 열사들에게 경의를 표시했다"고 신문은 덧붙였다.
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-11-06
# url: https://www.spnews.co.kr/news/articleView.html?idxno=101049
# category: 정치

# %%
test1_2 = ArticleCrawling2("https://www.spnews.co.kr/news/articleView.html?idxno=101049")

# %%
print(test1_2)
# Out:
# id: spnews_101049
# title: 北, 김영남 상임위원장 영결식...김정은 참석
# contents: 고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로 치뤄졌다.
# 노동신문은 6일 김영남 전 상임위원장 장례소식을 전하면서 "고인의 영구가 안치된 서장회관은 특출한 공적을 남긴 노세대혁명가를 잃은 커다란 비애에 휩싸여있었다"고 보도했다.
# "국가장의식에는 당 정치국 상무위원과 국가장의위원회 위원, 당중앙위원회와 최고인민회의 상임위원회, 내각, 성, 중앙기관, 무력기관의 일꾼, 고인의 유가족 등이 참석했다"고 전했다.
# "추도곡이 울리는 가운데 고 김영남 상임위원장의 영구를 발인하는 의식이 진행됐으며, 수많은 평양시민들이 신미리애국열사릉으로 향한 연도마다에서 영구차에 조의를 표시했다"고 덧붙였다.
# 영결식은 신미리애국렬사릉에서 김정은 총비서가 참석한 가운데 열렸다.
# "김 총비서는 당과 정부의 지도간부들과 열사릉 입구에서 고 김영남 동지의 영구를 맞이했다"고 신문은 전했다.
# 박태성 내각총리는 애도사에서 "김 상임위원장은 80여 성상 당을 따르고 당과 함께 영광의 일대기를 새겨오면서 국가의 정치사상적 위력과 권익을 수호하는데 뚜렷한 자욱을 새겨온 조선인민이 낳은 우수하고 열렬한 혁명가, 참다운 애국자의 한사람이었다"고 추모했다.
# "김 총비서는 애국열사릉의 추모비 앞에서 전체 열사들에게 경의를 표시했다"고 신문은 덧붙였다.
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-11-06
# url: https://www.spnews.co.kr/news/articleView.html?idxno=101049
# category: 정치

# %%
test2 = ArticleCrawling("https://www.spnews.co.kr/news/articleView.html?idxno=95970")

# %%
print(test2)
# Out:
# id: spnews_95970
# title: 北, 이재명 대통령 당선 첫 보도...노동신문 통해 주민들에게 알려
# contents:
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-06-05
# url: https://www.spnews.co.kr/news/articleView.html?idxno=95970
# category: 정치

# %%
test2_2 = ArticleCrawling2("https://www.spnews.co.kr/news/articleView.html?idxno=95970")

# %%
print(test2_2)
# Out:
# id: spnews_95970
# title: 北, 이재명 대통령 당선 첫 보도...노동신문 통해 주민들에게 알려
# contents: 북한이 이재명 대통령이 제21대 대통령으로 당선된 사실을 주민들에게 알렸다.
# 노동신문은 5일 "한국에서 지난해 '12.3비상계엄사태'로 대통령이 탄핵된 후 두 달 만인 6월 3일 대통령 선거가 진행됐다"며 이같이 보도했다.
# 이어 "선거에서는 더불어민주당 후보 리재명이 21대 대통령으로 당선됐다"고 덧붙였다.
# 신문은 6면에 관련 소식을 이렇게만 전하면서 특별한 논평은 하지 않았다.
# 북한이 21대 대통령선거에 대해 언급한 것은 이번이 처음이다.
# 북한은 2022년 제20대 대선 때는 선거 이틀 만에 "보수야당인 국민의힘의 후보 윤석열이 당선됐다"고 전했다.
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-06-05
# url: https://www.spnews.co.kr/news/articleView.html?idxno=95970
# category: 정치

# %%
test3 = ArticleCrawling("https://www.spnews.co.kr/news/articleView.html?idxno=94372")

# %%
print(test3)
# Out:
# id: spnews_94372
# title: [오늘의 북한 날씨] 전 지역 가끔 구름많음
# contents:
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-04-16
# url: https://www.spnews.co.kr/news/articleView.html?idxno=94372
# category: 사회/문화/체육

# %%
test3_2 = ArticleCrawling2("https://www.spnews.co.kr/news/articleView.html?idxno=94372")

# %%
print(test3_2)
# Out:
# id: spnews_94372
# title: [오늘의 북한 날씨] 전 지역 가끔 구름많음
# contents: [기상청 발표 4월 16일(수) 북한 날씨]
# □ 전 지역 가끔 구름많음.
# □ 아침최저 평양 5도, 양강도 삼지연 -2도 예상.
# source: spnews
# section: 북한N
# author: 안윤석 대기자
# publish_date: 2025-04-16
# url: https://www.spnews.co.kr/news/articleView.html?idxno=94372
# category: 사회/문화/체육

# %% [markdown]
# ### **[Auto Crawler]**

# %%
base_url = "https://www.spnews.co.kr"

# %%
BASE_URL = "https://www.spnews.co.kr/news/articleView.html?idxno={}"

class SPNCrawler:
    def __init__(self, start:101404, end, filename):
        self.start = start
        self.end = end
        self.filename = filename
        self.results = []

    def crawling_range(self):

        for i in range(self.start, self.end -1, -1):
            url = BASE_URL.format(i)

            try:
                crawler = ArticleCrawling(url)
                data = crawler.to_dict()

                if data.get("section") != "북한N":
                    continue
                
                self.results.append(data)

            except Exception as e:
                print(f"idx {i} 에서 에러 발생: {e}")
        
        return self.results

    def save_csv(self):
        data = self.results

        if not data:
            print("저장 데이터 없음")
            return
        
        keys = data[0].keys()

        with open(self.filename, "w", newline = "", encoding = "utf-8-sig") as f:
            writer = csv.DictWriter(f, fieldnames = keys)
            writer.writeheader()
            writer.writerows(data)

        print(f"{self.filename} 저장 완료.")

    def run(self):
        self.crawling_range()
        self.save_csv()
        return self.results

# %%
BASE_URL = "https://www.spnews.co.kr/news/articleView.html?idxno={}"

class SPNAllCrawler:
    def __init__(self, start, end, filename, section, sleep_min=0.5, sleep_max=1.0):
        self.start = start
        self.end = end
        self.filename = filename
        self.section = section
        self.sleep_min = sleep_min
        self.sleep_max = sleep_max
        self.existing_ids = self._load_existing_ids()

    def _load_existing_ids(self):
        ids = set()
        if os.path.exists(self.filename):
            with open(self.filename, "r", encoding="utf-8-sig", newline="") as f:
                reader = csv.DictReader(f)
                for row in reader:
                    if "id" in row and row["id"]:
                        ids.add(row["id"])
        return ids

    def _open_writer(self):
        file_exists = os.path.exists(self.filename)
        f = open(self.filename, "a", encoding="utf-8-sig", newline="")
        fieldnames = [
            "id",
            "title",
            "contents",
            "source",
            "section",
            "author",
            "publish_date",
            "url",       
            "category",            
        ]
        writer = csv.DictWriter(f, fieldnames=fieldnames)

        if not file_exists:
            writer.writeheader()

        return f, writer

    def run(self):
        f, writer = self._open_writer()

        try:
            for i in range(self.start, self.end - 1, -1):
                url = BASE_URL.format(i)

                try:
                    crawler = ArticleCrawling2(url)
                    data = crawler.to_dict()

                    # id 없으면 스킵
                    article_id = data.get("id")
                    if not article_id:
                        print(f"[SKIP] idx {i}: id 없음")
                        continue

                    # 이미 저장된 id면 스킵 (재실행 대비)
                    if article_id in self.existing_ids:
                        print(f"[SKIP] idx {i}: 이미 저장된 기사 ({article_id})")
                        continue

                    if self.section and data.get("section") != self.section:
                        print(f"[SKIP] idx {i}: section={data.get('section')}")
                        continue

                    # CSV 추가
                    writer.writerow(data)
                    f.flush()  
                    self.existing_ids.add(article_id)

                    print(f"[SAVE] idx {i}: {article_id} 저장 완료")

                except Exception as e:
                    print(f"[ERROR] idx {i} 에러 발생: {e}")

                # 서버 부하/차단 방지를 위한 랜덤 슬립
                time.sleep(random.uniform(self.sleep_min, self.sleep_max))

        finally:
            f.close()

# %%
# %%time

crawler = SPNAllCrawler(
    start = 101404,
    end = 1,                        
    filename = "spnews_ver2.csv",
    section = "북한N",          
    sleep_min = 0.7,
    sleep_max = 1.5                   # 조금 여유롭게
)

crawler.run()
# Out:
# [SAVE] idx 101404: spnews_101404 저장 완료
# [SAVE] idx 101403: spnews_101403 저장 완료
# [SAVE] idx 101402: spnews_101402 저장 완료
# [SKIP] idx 101401: section=이슈+
# [SKIP] idx 101400: section=서울&
# [SKIP] idx 101399: section=서울&
# [SKIP] idx 101398: section=서울&
# [ERROR] idx 101397 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101396: section=서울&
# [ERROR] idx 101395 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101394: spnews_101394 저장 완료
# [ERROR] idx 101393 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101392: spnews_101392 저장 완료
# [SAVE] idx 101391: spnews_101391 저장 완료
# [SAVE] idx 101390: spnews_101390 저장 완료
# [SAVE] idx 101389: spnews_101389 저장 완료
# [SKIP] idx 101388: section=서울&
# [ERROR] idx 101387 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101386: section=서울&
# [ERROR] idx 101385 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101384: section=서울&
# [SAVE] idx 101383: spnews_101383 저장 완료
# [SKIP] idx 101382: section=서울&
# [SKIP] idx 101381: section=서울&
# [ERROR] idx 101380 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101379: section=서울&
# [ERROR] idx 101378 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101377: spnews_101377 저장 완료
# [SAVE] idx 101376: spnews_101376 저장 완료
# [SKIP] idx 101375: section=한반도W
# [SAVE] idx 101374: spnews_101374 저장 완료
# [SAVE] idx 101373: spnews_101373 저장 완료
# [ERROR] idx 101372 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101371: section=이슈+
# [SKIP] idx 101370: section=None
# [SAVE] idx 101369: spnews_101369 저장 완료
# [SAVE] idx 101368: spnews_101368 저장 완료
# [SAVE] idx 101367: spnews_101367 저장 완료
# [SAVE] idx 101366: spnews_101366 저장 완료
# [SKIP] idx 101365: section=서울&
# [ERROR] idx 101364 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101363: section=한반도W
# [SAVE] idx 101362: spnews_101362 저장 완료
# [SKIP] idx 101361: section=서울&
# [ERROR] idx 101360 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101359: section=한반도W
# [SKIP] idx 101358: section=서울&
# [SKIP] idx 101357: section=서울&
# [SKIP] idx 101356: section=서울&
# [SKIP] idx 101355: section=서울&
# [SKIP] idx 101354: section=한반도W
# [ERROR] idx 101353 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101352 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101351: section=한반도W
# [SAVE] idx 101350: spnews_101350 저장 완료
# [SAVE] idx 101349: spnews_101349 저장 완료
# [SKIP] idx 101348: section=한반도W
# [SAVE] idx 101347: spnews_101347 저장 완료
# [SKIP] idx 101346: section=한반도W
# [SAVE] idx 101345: spnews_101345 저장 완료
# [ERROR] idx 101344 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101343: section=이슈+
# [SKIP] idx 101342: section=서울&
# [ERROR] idx 101341 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101340: section=이슈+
# [SKIP] idx 101339: section=이슈+
# [SKIP] idx 101338: section=서울&
# [ERROR] idx 101337 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101336: section=이슈+
# [SKIP] idx 101335: section=이슈+
# [SKIP] idx 101334: section=이슈+
# [ERROR] idx 101333 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101332: section=서울&
# [SKIP] idx 101331: section=이슈+
# [SKIP] idx 101330: section=이슈+
# [SKIP] idx 101329: section=서울&
# [ERROR] idx 101328 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101327: section=이슈+
# [SKIP] idx 101326: section=서울&
# [SKIP] idx 101325: section=서울&
# [SKIP] idx 101324: section=서울&
# [SKIP] idx 101323: section=서울&
# [SKIP] idx 101322: section=서울&
# [SKIP] idx 101321: section=서울&
# [SKIP] idx 101320: section=서울&
# [SKIP] idx 101319: section=이슈+
# [ERROR] idx 101318 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101317: section=서울&
# [SKIP] idx 101316: section=이슈+
# [SKIP] idx 101315: section=서울&
# [SKIP] idx 101314: section=서울&
# [SAVE] idx 101313: spnews_101313 저장 완료
# [SAVE] idx 101312: spnews_101312 저장 완료
# [SKIP] idx 101311: section=한반도W
# [SKIP] idx 101310: section=한반도W
# [ERROR] idx 101309 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101308: section=한반도W
# [SAVE] idx 101307: spnews_101307 저장 완료
# [SAVE] idx 101306: spnews_101306 저장 완료
# [SKIP] idx 101305: section=서울&
# [SKIP] idx 101304: section=서울&
# [SAVE] idx 101303: spnews_101303 저장 완료
# [SKIP] idx 101302: section=서울&
# [SKIP] idx 101301: section=서울&
# [SKIP] idx 101300: section=None
# [SKIP] idx 101299: section=한반도W
# [SKIP] idx 101298: section=이슈+
# [ERROR] idx 101297 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101296: section=이슈+
# [SKIP] idx 101295: section=이슈+
# [ERROR] idx 101294 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101293 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101292 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101291 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101290: section=서울&
# [SKIP] idx 101289: section=서울&
# [SKIP] idx 101288: section=서울&
# [SKIP] idx 101287: section=서울&
# [SKIP] idx 101286: section=이슈+
# [SKIP] idx 101285: section=이슈+
# [SKIP] idx 101284: section=서울&
# [SKIP] idx 101283: section=서울&
# [SKIP] idx 101282: section=서울&
# [SKIP] idx 101281: section=서울&
# [ERROR] idx 101280 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101279: section=서울&
# [SKIP] idx 101278: section=서울&
# [SKIP] idx 101277: section=서울&
# [SKIP] idx 101276: section=서울&
# [SKIP] idx 101275: section=서울&
# [SKIP] idx 101274: section=서울&
# [SAVE] idx 101273: spnews_101273 저장 완료
# [SAVE] idx 101272: spnews_101272 저장 완료
# [SAVE] idx 101271: spnews_101271 저장 완료
# [SAVE] idx 101270: spnews_101270 저장 완료
# [SAVE] idx 101269: spnews_101269 저장 완료
# [SAVE] idx 101268: spnews_101268 저장 완료
# [SKIP] idx 101267: section=한반도W
# [SKIP] idx 101266: section=한반도W
# [SKIP] idx 101265: section=한반도W
# [SAVE] idx 101264: spnews_101264 저장 완료
# [SAVE] idx 101263: spnews_101263 저장 완료
# [SKIP] idx 101262: section=서울&
# [SKIP] idx 101261: section=None
# [ERROR] idx 101260 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101259 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101258: spnews_101258 저장 완료
# [SAVE] idx 101257: spnews_101257 저장 완료
# [SKIP] idx 101256: section=이슈+
# [SKIP] idx 101255: section=서울&
# [SKIP] idx 101254: section=서울&
# [ERROR] idx 101253 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101252: section=서울&
# [SKIP] idx 101251: section=서울&
# [ERROR] idx 101250 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101249: section=서울&
# [SKIP] idx 101248: section=서울&
# [SKIP] idx 101247: section=이슈+
# [SKIP] idx 101246: section=이슈+
# [SKIP] idx 101245: section=이슈+
# [SKIP] idx 101244: section=이슈+
# [SKIP] idx 101243: section=서울&
# [SKIP] idx 101242: section=서울&
# [SKIP] idx 101241: section=서울&
# [SKIP] idx 101240: section=서울&
# [SKIP] idx 101239: section=이슈+
# [SKIP] idx 101238: section=이슈+
# [SKIP] idx 101237: section=이슈+
# [SKIP] idx 101236: section=서울&
# [ERROR] idx 101235 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101234: section=서울&
# [ERROR] idx 101233 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101232: section=서울&
# [SAVE] idx 101231: spnews_101231 저장 완료
# [SAVE] idx 101230: spnews_101230 저장 완료
# [SAVE] idx 101229: spnews_101229 저장 완료
# [SAVE] idx 101228: spnews_101228 저장 완료
# [SKIP] idx 101227: section=한반도W
# [SKIP] idx 101226: section=한반도W
# [SAVE] idx 101225: spnews_101225 저장 완료
# [ERROR] idx 101224 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101223: spnews_101223 저장 완료
# [SAVE] idx 101222: spnews_101222 저장 완료
# [SKIP] idx 101221: section=서울&
# [SKIP] idx 101220: section=서울&
# [SKIP] idx 101219: section=이슈+
# [SKIP] idx 101218: section=이슈+
# [SKIP] idx 101217: section=서울&
# [SKIP] idx 101216: section=이슈+
# [SAVE] idx 101215: spnews_101215 저장 완료
# [ERROR] idx 101214 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101213 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101212: section=서울&
# [ERROR] idx 101211 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101210: section=서울&
# [SKIP] idx 101209: section=이슈+
# [SKIP] idx 101208: section=이슈+
# [SKIP] idx 101207: section=None
# [SKIP] idx 101206: section=이슈+
# [ERROR] idx 101205 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101204: section=이슈+
# [SKIP] idx 101203: section=서울&
# [SKIP] idx 101202: section=서울&
# [SKIP] idx 101201: section=이슈+
# [SKIP] idx 101200: section=서울&
# [SKIP] idx 101199: section=서울&
# [SKIP] idx 101198: section=서울&
# [SAVE] idx 101197: spnews_101197 저장 완료
# [SKIP] idx 101196: section=서울&
# [ERROR] idx 101195 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101194: spnews_101194 저장 완료
# [SAVE] idx 101193: spnews_101193 저장 완료
# [SAVE] idx 101192: spnews_101192 저장 완료
# [SKIP] idx 101191: section=한반도W
# [SKIP] idx 101190: section=한반도W
# [SKIP] idx 101189: section=한반도W
# [SAVE] idx 101188: spnews_101188 저장 완료
# [SAVE] idx 101187: spnews_101187 저장 완료
# [SKIP] idx 101186: section=서울&
# [SKIP] idx 101185: section=서울&
# [SKIP] idx 101184: section=서울&
# [SKIP] idx 101183: section=서울&
# [SKIP] idx 101182: section=서울&
# [SKIP] idx 101181: section=서울&
# [SKIP] idx 101180: section=이슈+
# [ERROR] idx 101179 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101178: section=이슈+
# [SKIP] idx 101177: section=이슈+
# [SKIP] idx 101176: section=이슈+
# [SKIP] idx 101175: section=이슈+
# [ERROR] idx 101174 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101173: spnews_101173 저장 완료
# [SAVE] idx 101172: spnews_101172 저장 완료
# [SKIP] idx 101171: section=서울&
# [SKIP] idx 101170: section=서울&
# [ERROR] idx 101169 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101168: section=서울&
# [SKIP] idx 101167: section=서울&
# [SKIP] idx 101166: section=서울&
# [SKIP] idx 101165: section=이슈+
# [ERROR] idx 101164 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101163: section=None
# [ERROR] idx 101162 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101161: section=None
# [SKIP] idx 101160: section=서울&
# [SKIP] idx 101159: section=이슈+
# [SKIP] idx 101158: section=서울&
# [SKIP] idx 101157: section=이슈+
# [SKIP] idx 101156: section=서울&
# [SKIP] idx 101155: section=한반도W
# [SKIP] idx 101154: section=서울&
# [SAVE] idx 101153: spnews_101153 저장 완료
# [SKIP] idx 101152: section=서울&
# [SAVE] idx 101151: spnews_101151 저장 완료
# [SAVE] idx 101150: spnews_101150 저장 완료
# [SAVE] idx 101149: spnews_101149 저장 완료
# [SAVE] idx 101148: spnews_101148 저장 완료
# [SAVE] idx 101147: spnews_101147 저장 완료
# [SAVE] idx 101146: spnews_101146 저장 완료
# [ERROR] idx 101145 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101144: spnews_101144 저장 완료
# [ERROR] idx 101143 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101142 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101141: section=서울&
# [SAVE] idx 101140: spnews_101140 저장 완료
# [SAVE] idx 101139: spnews_101139 저장 완료
# [SKIP] idx 101138: section=서울&
# [SAVE] idx 101137: spnews_101137 저장 완료
# [SAVE] idx 101136: spnews_101136 저장 완료
# [SKIP] idx 101135: section=서울&
# [SKIP] idx 101134: section=이슈+
# [SAVE] idx 101133: spnews_101133 저장 완료
# [ERROR] idx 101132 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101131 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101130 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101129: spnews_101129 저장 완료
# [SKIP] idx 101128: section=서울&
# [SAVE] idx 101127: spnews_101127 저장 완료
# [SAVE] idx 101126: spnews_101126 저장 완료
# [SKIP] idx 101125: section=한반도W
# [SAVE] idx 101124: spnews_101124 저장 완료
# [SAVE] idx 101123: spnews_101123 저장 완료
# [SKIP] idx 101122: section=한반도W
# [SAVE] idx 101121: spnews_101121 저장 완료
# [SKIP] idx 101120: section=한반도W
# [ERROR] idx 101119 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101118: section=한반도W
# [SAVE] idx 101117: spnews_101117 저장 완료
# [SAVE] idx 101116: spnews_101116 저장 완료
# [SKIP] idx 101115: section=서울&
# [SKIP] idx 101114: section=서울&
# [SKIP] idx 101113: section=서울&
# [SKIP] idx 101112: section=서울&
# [SKIP] idx 101111: section=서울&
# [SKIP] idx 101110: section=이슈+
# [SKIP] idx 101109: section=이슈+
# [SKIP] idx 101108: section=이슈+
# [SKIP] idx 101107: section=이슈+
# [ERROR] idx 101106 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101105: section=이슈+
# [SKIP] idx 101104: section=이슈+
# [SKIP] idx 101103: section=서울&
# [ERROR] idx 101102 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101101 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101100 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101099: section=서울&
# [SKIP] idx 101098: section=서울&
# [SAVE] idx 101097: spnews_101097 저장 완료
# [SKIP] idx 101096: section=서울&
# [SKIP] idx 101095: section=이슈+
# [ERROR] idx 101094 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101093: section=서울&
# [SKIP] idx 101092: section=서울&
# [SKIP] idx 101091: section=None
# [SAVE] idx 101090: spnews_101090 저장 완료
# [SKIP] idx 101089: section=이슈+
# [SAVE] idx 101088: spnews_101088 저장 완료
# [SKIP] idx 101087: section=한반도W
# [SKIP] idx 101086: section=한반도W
# [SKIP] idx 101085: section=한반도W
# [SAVE] idx 101084: spnews_101084 저장 완료
# [SKIP] idx 101083: section=서울&
# [ERROR] idx 101082 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101081: section=서울&
# [ERROR] idx 101080 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101079: section=이슈+
# [ERROR] idx 101078 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101077: spnews_101077 저장 완료
# [SKIP] idx 101076: section=서울&
# [SKIP] idx 101075: section=서울&
# [SKIP] idx 101074: section=서울&
# [SKIP] idx 101073: section=None
# [SKIP] idx 101072: section=이슈+
# [SKIP] idx 101071: section=이슈+
# [SKIP] idx 101070: section=이슈+
# [SKIP] idx 101069: section=이슈+
# [SAVE] idx 101068: spnews_101068 저장 완료
# [SKIP] idx 101067: section=서울&
# [SAVE] idx 101066: spnews_101066 저장 완료
# [SAVE] idx 101065: spnews_101065 저장 완료
# [ERROR] idx 101064 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101063: section=서울&
# [SKIP] idx 101062: section=서울&
# [SKIP] idx 101061: section=서울&
# [SKIP] idx 101060: section=서울&
# [SKIP] idx 101059: section=이슈+
# [SKIP] idx 101058: section=서울&
# [SKIP] idx 101057: section=이슈+
# [ERROR] idx 101056 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101055: section=서울&
# [SKIP] idx 101054: section=서울&
# [ERROR] idx 101053 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101052: spnews_101052 저장 완료
# [ERROR] idx 101051 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 101050: spnews_101050 저장 완료
# [SAVE] idx 101049: spnews_101049 저장 완료
# [SAVE] idx 101048: spnews_101048 저장 완료
# [SKIP] idx 101047: section=한반도W
# [SKIP] idx 101046: section=한반도W
# [SKIP] idx 101045: section=서울&
# [SKIP] idx 101044: section=서울&
# [SKIP] idx 101043: section=서울&
# [SKIP] idx 101042: section=서울&
# [SKIP] idx 101041: section=서울&
# [SAVE] idx 101040: spnews_101040 저장 완료
# [SKIP] idx 101039: section=서울&
# [ERROR] idx 101038 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101037: section=서울&
# [SKIP] idx 101036: section=이슈+
# [SKIP] idx 101035: section=이슈+
# [SKIP] idx 101034: section=이슈+
# [SKIP] idx 101033: section=None
# [SKIP] idx 101032: section=이슈+
# [SKIP] idx 101031: section=이슈+
# [SKIP] idx 101030: section=이슈+
# [ERROR] idx 101029 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101028: section=서울&
# [SKIP] idx 101027: section=서울&
# [SKIP] idx 101026: section=서울&
# [SKIP] idx 101025: section=서울&
# [SKIP] idx 101024: section=서울&
# [SAVE] idx 101023: spnews_101023 저장 완료
# [SKIP] idx 101022: section=서울&
# [SKIP] idx 101021: section=서울&
# [SKIP] idx 101020: section=서울&
# [SKIP] idx 101019: section=서울&
# [ERROR] idx 101018 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 101017 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101016: section=이슈+
# [SAVE] idx 101015: spnews_101015 저장 완료
# [SAVE] idx 101014: spnews_101014 저장 완료
# [SAVE] idx 101013: spnews_101013 저장 완료
# [SAVE] idx 101012: spnews_101012 저장 완료
# [SAVE] idx 101011: spnews_101011 저장 완료
# [SAVE] idx 101010: spnews_101010 저장 완료
# [SAVE] idx 101009: spnews_101009 저장 완료
# [SKIP] idx 101008: section=한반도W
# [SKIP] idx 101007: section=한반도W
# [SKIP] idx 101006: section=한반도W
# [SKIP] idx 101005: section=서울&
# [ERROR] idx 101004 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 101003: section=서울&
# [SKIP] idx 101002: section=서울&
# [SAVE] idx 101001: spnews_101001 저장 완료
# [SKIP] idx 101000: section=서울&
# [ERROR] idx 100999 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100998: section=None
# [ERROR] idx 100997 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100996: section=이슈+
# [SKIP] idx 100995: section=이슈+
# [SKIP] idx 100994: section=서울&
# [SKIP] idx 100993: section=이슈+
# [SKIP] idx 100992: section=이슈+
# [SKIP] idx 100991: section=이슈+
# [SKIP] idx 100990: section=이슈+
# [SKIP] idx 100989: section=이슈+
# [SKIP] idx 100988: section=이슈+
# [ERROR] idx 100987 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100986: section=이슈+
# [SKIP] idx 100985: section=서울&
# [SKIP] idx 100984: section=서울&
# [SKIP] idx 100983: section=서울&
# [SKIP] idx 100982: section=서울&
# [SKIP] idx 100981: section=서울&
# [SKIP] idx 100980: section=이슈+
# [SKIP] idx 100979: section=서울&
# [SKIP] idx 100978: section=서울&
# [ERROR] idx 100977 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100976: section=서울&
# [SKIP] idx 100975: section=서울&
# [ERROR] idx 100974 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100973: section=서울&
# [SKIP] idx 100972: section=서울&
# [SAVE] idx 100971: spnews_100971 저장 완료
# [SAVE] idx 100970: spnews_100970 저장 완료
# [SAVE] idx 100969: spnews_100969 저장 완료
# [SKIP] idx 100968: section=한반도W
# [SKIP] idx 100967: section=한반도W
# [SAVE] idx 100966: spnews_100966 저장 완료
# [ERROR] idx 100965 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100964 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100963: spnews_100963 저장 완료
# [SAVE] idx 100962: spnews_100962 저장 완료
# [SKIP] idx 100961: section=서울&
# [ERROR] idx 100960 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100959 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100958 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100957 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100956: spnews_100956 저장 완료
# [SKIP] idx 100955: section=서울&
# [SKIP] idx 100954: section=None
# [ERROR] idx 100953 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100952: section=한반도W
# [SKIP] idx 100951: section=서울&
# [SKIP] idx 100950: section=이슈+
# [ERROR] idx 100949 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100948: section=이슈+
# [ERROR] idx 100947 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100946: section=서울&
# [SKIP] idx 100945: section=서울&
# [SKIP] idx 100944: section=서울&
# [ERROR] idx 100943 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100942 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100941: section=서울&
# [SKIP] idx 100940: section=서울&
# [SKIP] idx 100939: section=서울&
# [SKIP] idx 100938: section=서울&
# [SKIP] idx 100937: section=서울&
# [SKIP] idx 100936: section=이슈+
# [SKIP] idx 100935: section=이슈+
# [SKIP] idx 100934: section=서울&
# [SKIP] idx 100933: section=서울&
# [SKIP] idx 100932: section=서울&
# [SKIP] idx 100931: section=서울&
# [SKIP] idx 100930: section=서울&
# [SKIP] idx 100929: section=서울&
# [SAVE] idx 100928: spnews_100928 저장 완료
# [SAVE] idx 100927: spnews_100927 저장 완료
# [SAVE] idx 100926: spnews_100926 저장 완료
# [SKIP] idx 100925: section=None
# [SAVE] idx 100924: spnews_100924 저장 완료
# [SKIP] idx 100923: section=서울&
# [SAVE] idx 100922: spnews_100922 저장 완료
# [SKIP] idx 100921: section=서울&
# [ERROR] idx 100920 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100919 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100918: section=이슈+
# [SKIP] idx 100917: section=이슈+
# [SKIP] idx 100916: section=이슈+
# [SKIP] idx 100915: section=이슈+
# [SKIP] idx 100914: section=이슈+
# [ERROR] idx 100913 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100912: spnews_100912 저장 완료
# [SAVE] idx 100911: spnews_100911 저장 완료
# [SAVE] idx 100910: spnews_100910 저장 완료
# [SAVE] idx 100909: spnews_100909 저장 완료
# [SKIP] idx 100908: section=서울&
# [ERROR] idx 100907 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100906: spnews_100906 저장 완료
# [ERROR] idx 100905 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100904: section=서울&
# [SAVE] idx 100903: spnews_100903 저장 완료
# [SKIP] idx 100902: section=서울&
# [ERROR] idx 100901 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100900: section=서울&
# [SKIP] idx 100899: section=서울&
# [SKIP] idx 100898: section=서울&
# [SKIP] idx 100897: section=서울&
# [ERROR] idx 100896 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100895: section=서울&
# [ERROR] idx 100894 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100893 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100892 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100891: section=서울&
# [SAVE] idx 100890: spnews_100890 저장 완료
# [SAVE] idx 100889: spnews_100889 저장 완료
# [SKIP] idx 100888: section=한반도W
# [SAVE] idx 100887: spnews_100887 저장 완료
# [SAVE] idx 100886: spnews_100886 저장 완료
# [SKIP] idx 100885: section=한반도W
# [SKIP] idx 100884: section=서울&
# [SKIP] idx 100883: section=서울&
# [SAVE] idx 100882: spnews_100882 저장 완료
# [ERROR] idx 100881 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100880 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100879: section=서울&
# [ERROR] idx 100878 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100877 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100876: section=서울&
# [ERROR] idx 100875 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100874 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100873: section=서울&
# [ERROR] idx 100872 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100871: section=서울&
# [SKIP] idx 100870: section=서울&
# [SKIP] idx 100869: section=서울&
# [SKIP] idx 100868: section=이슈+
# [SKIP] idx 100867: section=서울&
# [SKIP] idx 100866: section=이슈+
# [SKIP] idx 100865: section=이슈+
# [SKIP] idx 100864: section=서울&
# [SKIP] idx 100863: section=이슈+
# [SKIP] idx 100862: section=서울&
# [SKIP] idx 100861: section=서울&
# [SAVE] idx 100860: spnews_100860 저장 완료
# [SKIP] idx 100859: section=None
# [SKIP] idx 100858: section=서울&
# [SKIP] idx 100857: section=서울&
# [ERROR] idx 100856 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100855: section=서울&
# [SKIP] idx 100854: section=서울&
# [ERROR] idx 100853 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100852: section=이슈+
# [ERROR] idx 100851 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100850: section=서울&
# [SKIP] idx 100849: section=서울&
# [SKIP] idx 100848: section=서울&
# [ERROR] idx 100847 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100846: spnews_100846 저장 완료
# [SAVE] idx 100845: spnews_100845 저장 완료
# [SAVE] idx 100844: spnews_100844 저장 완료
# [ERROR] idx 100843 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100842 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100841: section=서울&
# [ERROR] idx 100840 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100839: spnews_100839 저장 완료
# [SAVE] idx 100838: spnews_100838 저장 완료
# [ERROR] idx 100837 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100836: section=한반도W
# [SKIP] idx 100835: section=한반도W
# [SKIP] idx 100834: section=한반도W
# [SKIP] idx 100833: section=한반도W
# [SKIP] idx 100832: section=서울&
# [ERROR] idx 100831 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100830 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100829: section=서울&
# [ERROR] idx 100828 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100827: spnews_100827 저장 완료
# [SKIP] idx 100826: section=서울&
# [ERROR] idx 100825 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100824: section=서울&
# [SKIP] idx 100823: section=서울&
# [SKIP] idx 100822: section=서울&
# [SKIP] idx 100821: section=이슈+
# [SKIP] idx 100820: section=이슈+
# [SKIP] idx 100819: section=이슈+
# [SKIP] idx 100818: section=이슈+
# [SKIP] idx 100817: section=이슈+
# [SKIP] idx 100816: section=서울&
# [ERROR] idx 100815 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100814: section=서울&
# [ERROR] idx 100813 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100812 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100811: section=서울&
# [ERROR] idx 100810 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100809: section=서울&
# [SKIP] idx 100808: section=서울&
# [ERROR] idx 100807 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100806 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100805: section=서울&
# [SKIP] idx 100804: section=서울&
# [SKIP] idx 100803: section=서울&
# [ERROR] idx 100802 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100801 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100800: spnews_100800 저장 완료
# [SAVE] idx 100799: spnews_100799 저장 완료
# [SAVE] idx 100798: spnews_100798 저장 완료
# [SKIP] idx 100797: section=서울&
# [SKIP] idx 100796: section=서울&
# [SKIP] idx 100795: section=서울&
# [SKIP] idx 100794: section=서울&
# [SKIP] idx 100793: section=한반도W
# [ERROR] idx 100792 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100791 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100790 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100789: spnews_100789 저장 완료
# [SAVE] idx 100788: spnews_100788 저장 완료
# [SAVE] idx 100787: spnews_100787 저장 완료
# [SKIP] idx 100786: section=한반도W
# [SKIP] idx 100785: section=한반도W
# [SKIP] idx 100784: section=한반도W
# [SKIP] idx 100783: section=한반도W
# [SKIP] idx 100782: section=서울&
# [ERROR] idx 100781 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100780: section=서울&
# [SKIP] idx 100779: section=서울&
# [SAVE] idx 100778: spnews_100778 저장 완료
# [SKIP] idx 100777: section=서울&
# [SKIP] idx 100776: section=서울&
# [SKIP] idx 100775: section=이슈+
# [SKIP] idx 100774: section=이슈+
# [SKIP] idx 100773: section=서울&
# [ERROR] idx 100772 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100771: section=서울&
# [ERROR] idx 100770 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100769 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100768: section=서울&
# [SKIP] idx 100767: section=서울&
# [ERROR] idx 100766 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100765 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100764 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100763: spnews_100763 저장 완료
# [SAVE] idx 100762: spnews_100762 저장 완료
# [SAVE] idx 100761: spnews_100761 저장 완료
# [SAVE] idx 100760: spnews_100760 저장 완료
# [ERROR] idx 100759 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100758: section=서울&
# [SKIP] idx 100757: section=이슈+
# [SKIP] idx 100756: section=서울&
# [SKIP] idx 100755: section=이슈+
# [SKIP] idx 100754: section=서울&
# [SKIP] idx 100753: section=서울&
# [SKIP] idx 100752: section=서울&
# [SKIP] idx 100751: section=서울&
# [ERROR] idx 100750 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100749: section=이슈+
# [SKIP] idx 100748: section=이슈+
# [SKIP] idx 100747: section=이슈+
# [SKIP] idx 100746: section=이슈+
# [SKIP] idx 100745: section=서울&
# [SAVE] idx 100744: spnews_100744 저장 완료
# [ERROR] idx 100743 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100742: spnews_100742 저장 완료
# [ERROR] idx 100741 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100740: spnews_100740 저장 완료
# [SKIP] idx 100739: section=한반도W
# [SKIP] idx 100738: section=한반도W
# [SKIP] idx 100737: section=한반도W
# [SKIP] idx 100736: section=한반도W
# [SKIP] idx 100735: section=서울&
# [SAVE] idx 100734: spnews_100734 저장 완료
# [ERROR] idx 100733 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100732: section=서울&
# [SAVE] idx 100731: spnews_100731 저장 완료
# [SKIP] idx 100730: section=서울&
# [ERROR] idx 100729 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100728 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100727: section=서울&
# [ERROR] idx 100726 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100725: section=서울&
# [ERROR] idx 100724 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100723 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100722: section=이슈+
# [SKIP] idx 100721: section=서울&
# [SKIP] idx 100720: section=서울&
# [SKIP] idx 100719: section=서울&
# [SKIP] idx 100718: section=서울&
# [ERROR] idx 100717 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100716: section=이슈+
# [SKIP] idx 100715: section=서울&
# [SKIP] idx 100714: section=서울&
# [SKIP] idx 100713: section=서울&
# [ERROR] idx 100712 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100711: section=서울&
# [ERROR] idx 100710 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100709: section=서울&
# [SKIP] idx 100708: section=서울&
# [SKIP] idx 100707: section=서울&
# [SAVE] idx 100706: spnews_100706 저장 완료
# [SAVE] idx 100705: spnews_100705 저장 완료
# [ERROR] idx 100704 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100703: spnews_100703 저장 완료
# [SAVE] idx 100702: spnews_100702 저장 완료
# [SKIP] idx 100701: section=None
# [SAVE] idx 100700: spnews_100700 저장 완료
# [SKIP] idx 100699: section=한반도W
# [SKIP] idx 100698: section=이슈+
# [SAVE] idx 100697: spnews_100697 저장 완료
# [SKIP] idx 100696: section=한반도W
# [SKIP] idx 100695: section=한반도W
# [SKIP] idx 100694: section=한반도W
# [SKIP] idx 100693: section=한반도W
# [SAVE] idx 100692: spnews_100692 저장 완료
# [SKIP] idx 100691: section=서울&
# [ERROR] idx 100690 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100689 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100688: section=서울&
# [SKIP] idx 100687: section=서울&
# [SAVE] idx 100686: spnews_100686 저장 완료
# [SKIP] idx 100685: section=서울&
# [ERROR] idx 100684 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100683: section=서울&
# [SKIP] idx 100682: section=이슈+
# [SKIP] idx 100681: section=이슈+
# [SKIP] idx 100680: section=이슈+
# [ERROR] idx 100679 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100678: section=서울&
# [SKIP] idx 100677: section=서울&
# [ERROR] idx 100676 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100675 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100674: section=서울&
# [ERROR] idx 100673 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100672: section=None
# [SKIP] idx 100671: section=서울&
# [SKIP] idx 100670: section=이슈+
# [ERROR] idx 100669 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100668: section=서울&
# [SKIP] idx 100667: section=서울&
# [SKIP] idx 100666: section=서울&
# [SKIP] idx 100665: section=이슈+
# [SAVE] idx 100664: spnews_100664 저장 완료
# [ERROR] idx 100663 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100662 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100661: section=None
# [ERROR] idx 100660 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100659: section=None
# [ERROR] idx 100658 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100657 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100656: section=서울&
# [SKIP] idx 100655: section=서울&
# [SAVE] idx 100654: spnews_100654 저장 완료
# [SKIP] idx 100653: section=None
# [SAVE] idx 100652: spnews_100652 저장 완료
# [ERROR] idx 100651 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100650 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100649: section=서울&
# [SKIP] idx 100648: section=서울&
# [ERROR] idx 100647 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100646: section=서울&
# [ERROR] idx 100645 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100644 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100643: section=서울&
# [ERROR] idx 100642 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100641: spnews_100641 저장 완료
# [SKIP] idx 100640: section=서울&
# [SKIP] idx 100639: section=서울&
# [SKIP] idx 100638: section=서울&
# [ERROR] idx 100637 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100636: spnews_100636 저장 완료
# [SKIP] idx 100635: section=None
# [ERROR] idx 100634 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100633: section=서울&
# [SKIP] idx 100632: section=서울&
# [SAVE] idx 100631: spnews_100631 저장 완료
# [SAVE] idx 100630: spnews_100630 저장 완료
# [ERROR] idx 100629 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100628: spnews_100628 저장 완료
# [SAVE] idx 100627: spnews_100627 저장 완료
# [SAVE] idx 100626: spnews_100626 저장 완료
# [ERROR] idx 100625 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100624: spnews_100624 저장 완료
# [SAVE] idx 100623: spnews_100623 저장 완료
# [SKIP] idx 100622: section=서울&
# [SKIP] idx 100621: section=한반도W
# [SAVE] idx 100620: spnews_100620 저장 완료
# [SKIP] idx 100619: section=서울&
# [ERROR] idx 100618 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100617: section=서울&
# [ERROR] idx 100616 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100615: spnews_100615 저장 완료
# [SAVE] idx 100614: spnews_100614 저장 완료
# [SAVE] idx 100613: spnews_100613 저장 완료
# [SKIP] idx 100612: section=한반도W
# [SAVE] idx 100611: spnews_100611 저장 완료
# [SAVE] idx 100610: spnews_100610 저장 완료
# [SAVE] idx 100609: spnews_100609 저장 완료
# [SKIP] idx 100608: section=한반도W
# [SKIP] idx 100607: section=이슈+
# [SKIP] idx 100606: section=이슈+
# [SKIP] idx 100605: section=이슈+
# [SKIP] idx 100604: section=서울&
# [ERROR] idx 100603 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100602: spnews_100602 저장 완료
# [SKIP] idx 100601: section=None
# [SKIP] idx 100600: section=None
# [SKIP] idx 100599: section=서울&
# [SKIP] idx 100598: section=서울&
# [ERROR] idx 100597 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100596: section=서울&
# [SKIP] idx 100595: section=서울&
# [SKIP] idx 100594: section=이슈+
# [SKIP] idx 100593: section=이슈+
# [SKIP] idx 100592: section=이슈+
# [SKIP] idx 100591: section=서울&
# [SKIP] idx 100590: section=이슈+
# [SKIP] idx 100589: section=이슈+
# [SKIP] idx 100588: section=이슈+
# [SKIP] idx 100587: section=이슈+
# [SKIP] idx 100586: section=이슈+
# [SKIP] idx 100585: section=서울&
# [SKIP] idx 100584: section=이슈+
# [SKIP] idx 100583: section=이슈+
# [SKIP] idx 100582: section=서울&
# [SKIP] idx 100581: section=이슈+
# [SKIP] idx 100580: section=서울&
# [ERROR] idx 100579 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100578: section=서울&
# [SKIP] idx 100577: section=서울&
# [SKIP] idx 100576: section=서울&
# [SKIP] idx 100575: section=서울&
# [SKIP] idx 100574: section=서울&
# [SKIP] idx 100573: section=서울&
# [SKIP] idx 100572: section=서울&
# [ERROR] idx 100571 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100570 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100569: section=서울&
# [SKIP] idx 100568: section=서울&
# [SKIP] idx 100567: section=서울&
# [SKIP] idx 100566: section=서울&
# [ERROR] idx 100565 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100564 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100563: section=서울&
# [ERROR] idx 100562 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100561: section=서울&
# [SAVE] idx 100560: spnews_100560 저장 완료
# [SAVE] idx 100559: spnews_100559 저장 완료
# [SAVE] idx 100558: spnews_100558 저장 완료
# [SAVE] idx 100557: spnews_100557 저장 완료
# [SKIP] idx 100556: section=한반도W
# [SKIP] idx 100555: section=한반도W
# [SKIP] idx 100554: section=한반도W
# [SAVE] idx 100553: spnews_100553 저장 완료
# [ERROR] idx 100552 에러 발생: HTTPSConnectionPool(host='www.spnews.co.kr', port=443): Max retries exceeded with url: /news/articleView.html?idxno=100552 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)')))
# [SKIP] idx 100551: section=서울&
# [ERROR] idx 100550 에러 발생: HTTPSConnectionPool(host='www.spnews.co.kr', port=443): Max retries exceeded with url: /news/articleView.html?idxno=100550 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)')))
# [SKIP] idx 100549: section=None
# [ERROR] idx 100548 에러 발생: HTTPSConnectionPool(host='www.spnews.co.kr', port=443): Max retries exceeded with url: /news/articleView.html?idxno=100548 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)')))
# [ERROR] idx 100547 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100546: section=서울&
# [ERROR] idx 100545 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100544: section=서울&
# [ERROR] idx 100543 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100542 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100541: section=서울&
# [SKIP] idx 100540: section=서울&
# [SKIP] idx 100539: section=서울&
# [SKIP] idx 100538: section=이슈+
# [SKIP] idx 100537: section=이슈+
# [SKIP] idx 100536: section=이슈+
# [SKIP] idx 100535: section=서울&
# [ERROR] idx 100534 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100533: section=서울&
# [SKIP] idx 100532: section=서울&
# [SKIP] idx 100531: section=서울&
# [ERROR] idx 100530 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100529 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100528: section=서울&
# [SKIP] idx 100527: section=서울&
# [SKIP] idx 100526: section=서울&
# [SKIP] idx 100525: section=서울&
# [ERROR] idx 100524 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100523: section=서울&
# [SKIP] idx 100522: section=서울&
# [ERROR] idx 100521 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100520: section=한반도W
# [ERROR] idx 100519 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100518: section=서울&
# [SAVE] idx 100517: spnews_100517 저장 완료
# [SAVE] idx 100516: spnews_100516 저장 완료
# [SAVE] idx 100515: spnews_100515 저장 완료
# [SAVE] idx 100514: spnews_100514 저장 완료
# [SAVE] idx 100513: spnews_100513 저장 완료
# [ERROR] idx 100512 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100511 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100510: section=한반도W
# [SKIP] idx 100509: section=한반도W
# [SAVE] idx 100508: spnews_100508 저장 완료
# [ERROR] idx 100507 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100506 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100505 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100504 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100503 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100502: spnews_100502 저장 완료
# [SKIP] idx 100501: section=서울&
# [SKIP] idx 100500: section=서울&
# [SKIP] idx 100499: section=서울&
# [SKIP] idx 100498: section=서울&
# [SKIP] idx 100497: section=서울&
# [SKIP] idx 100496: section=이슈+
# [SKIP] idx 100495: section=서울&
# [SKIP] idx 100494: section=서울&
# [SAVE] idx 100493: spnews_100493 저장 완료
# [SKIP] idx 100492: section=서울&
# [SKIP] idx 100491: section=서울&
# [ERROR] idx 100490 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100489: section=서울&
# [SKIP] idx 100488: section=서울&
# [SKIP] idx 100487: section=서울&
# [ERROR] idx 100486 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100485: section=이슈+
# [SKIP] idx 100484: section=서울&
# [ERROR] idx 100483 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100482: section=서울&
# [SAVE] idx 100481: spnews_100481 저장 완료
# [ERROR] idx 100480 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100479: spnews_100479 저장 완료
# [ERROR] idx 100478 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100477 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100476: section=서울&
# [SAVE] idx 100475: spnews_100475 저장 완료
# [SAVE] idx 100474: spnews_100474 저장 완료
# [ERROR] idx 100473 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100472: spnews_100472 저장 완료
# [SAVE] idx 100471: spnews_100471 저장 완료
# [SKIP] idx 100470: section=한반도W
# [SKIP] idx 100469: section=한반도W
# [SKIP] idx 100468: section=한반도W
# [SKIP] idx 100467: section=한반도W
# [SAVE] idx 100466: spnews_100466 저장 완료
# [SKIP] idx 100465: section=한반도W
# [SAVE] idx 100464: spnews_100464 저장 완료
# [SKIP] idx 100463: section=서울&
# [SKIP] idx 100462: section=이슈+
# [SKIP] idx 100461: section=서울&
# [SKIP] idx 100460: section=서울&
# [SAVE] idx 100459: spnews_100459 저장 완료
# [SKIP] idx 100458: section=서울&
# [SKIP] idx 100457: section=한반도W
# [SKIP] idx 100456: section=이슈+
# [SKIP] idx 100455: section=이슈+
# [SKIP] idx 100454: section=서울&
# [SKIP] idx 100453: section=이슈+
# [SKIP] idx 100452: section=이슈+
# [SKIP] idx 100451: section=서울&
# [SKIP] idx 100450: section=이슈+
# [SKIP] idx 100449: section=서울&
# [SKIP] idx 100448: section=이슈+
# [SKIP] idx 100447: section=이슈+
# [SKIP] idx 100446: section=서울&
# [ERROR] idx 100445 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100444: section=이슈+
# [ERROR] idx 100443 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100442: section=서울&
# [SKIP] idx 100441: section=서울&
# [SKIP] idx 100440: section=서울&
# [SKIP] idx 100439: section=서울&
# [ERROR] idx 100438 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100437: section=서울&
# [SKIP] idx 100436: section=서울&
# [SKIP] idx 100435: section=서울&
# [SKIP] idx 100434: section=서울&
# [SKIP] idx 100433: section=서울&
# [ERROR] idx 100432 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100431: spnews_100431 저장 완료
# [SKIP] idx 100430: section=한반도W
# [SKIP] idx 100429: section=서울&
# [ERROR] idx 100428 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100427: section=서울&
# [SAVE] idx 100426: spnews_100426 저장 완료
# [SAVE] idx 100425: spnews_100425 저장 완료
# [SAVE] idx 100424: spnews_100424 저장 완료
# [SKIP] idx 100423: section=한반도W
# [SKIP] idx 100422: section=한반도W
# [SKIP] idx 100421: section=한반도W
# [SAVE] idx 100420: spnews_100420 저장 완료
# [SKIP] idx 100419: section=서울&
# [SAVE] idx 100418: spnews_100418 저장 완료
# [SKIP] idx 100417: section=서울&
# [SKIP] idx 100416: section=이슈+
# [SKIP] idx 100415: section=서울&
# [SKIP] idx 100414: section=서울&
# [ERROR] idx 100413 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100412: section=이슈+
# [SKIP] idx 100411: section=이슈+
# [SKIP] idx 100410: section=서울&
# [SKIP] idx 100409: section=이슈+
# [SKIP] idx 100408: section=이슈+
# [SKIP] idx 100407: section=이슈+
# [SKIP] idx 100406: section=이슈+
# [SAVE] idx 100405: spnews_100405 저장 완료
# [SAVE] idx 100404: spnews_100404 저장 완료
# [ERROR] idx 100403 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100402 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100401: section=None
# [ERROR] idx 100400 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100399: section=서울&
# [SKIP] idx 100398: section=서울&
# [SKIP] idx 100397: section=서울&
# [SKIP] idx 100396: section=서울&
# [SKIP] idx 100395: section=서울&
# [SKIP] idx 100394: section=이슈+
# [SKIP] idx 100393: section=서울&
# [SKIP] idx 100392: section=서울&
# [SKIP] idx 100391: section=서울&
# [ERROR] idx 100390 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100389: section=한반도W
# [SKIP] idx 100388: section=한반도W
# [SAVE] idx 100387: spnews_100387 저장 완료
# [SKIP] idx 100386: section=서울&
# [SAVE] idx 100385: spnews_100385 저장 완료
# [SAVE] idx 100384: spnews_100384 저장 완료
# [SAVE] idx 100383: spnews_100383 저장 완료
# [ERROR] idx 100382 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100381: spnews_100381 저장 완료
# [SKIP] idx 100380: section=서울&
# [ERROR] idx 100379 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100378: spnews_100378 저장 완료
# [SAVE] idx 100377: spnews_100377 저장 완료
# [SKIP] idx 100376: section=서울&
# [SKIP] idx 100375: section=서울&
# [ERROR] idx 100374 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100373: section=서울&
# [SKIP] idx 100372: section=서울&
# [SAVE] idx 100371: spnews_100371 저장 완료
# [SKIP] idx 100370: section=서울&
# [SAVE] idx 100369: spnews_100369 저장 완료
# [SAVE] idx 100368: spnews_100368 저장 완료
# [SAVE] idx 100367: spnews_100367 저장 완료
# [SAVE] idx 100366: spnews_100366 저장 완료
# [SAVE] idx 100365: spnews_100365 저장 완료
# [SAVE] idx 100364: spnews_100364 저장 완료
# [SKIP] idx 100363: section=이슈+
# [ERROR] idx 100362 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100361: section=한반도W
# [ERROR] idx 100360 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100359 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100358 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100357: section=서울&
# [SAVE] idx 100356: spnews_100356 저장 완료
# [SAVE] idx 100355: spnews_100355 저장 완료
# [SKIP] idx 100354: section=한반도W
# [SAVE] idx 100353: spnews_100353 저장 완료
# [SAVE] idx 100352: spnews_100352 저장 완료
# [SAVE] idx 100351: spnews_100351 저장 완료
# [SAVE] idx 100350: spnews_100350 저장 완료
# [SAVE] idx 100349: spnews_100349 저장 완료
# [SKIP] idx 100348: section=한반도W
# [SKIP] idx 100347: section=한반도W
# [SKIP] idx 100346: section=한반도W
# [SAVE] idx 100345: spnews_100345 저장 완료
# [SAVE] idx 100344: spnews_100344 저장 완료
# [SKIP] idx 100343: section=서울&
# [SKIP] idx 100342: section=서울&
# [SKIP] idx 100341: section=서울&
# [SKIP] idx 100340: section=서울&
# [SKIP] idx 100339: section=이슈+
# [SKIP] idx 100338: section=이슈+
# [SKIP] idx 100337: section=이슈+
# [SKIP] idx 100336: section=이슈+
# [SKIP] idx 100335: section=서울&
# [SKIP] idx 100334: section=서울&
# [SAVE] idx 100333: spnews_100333 저장 완료
# [SKIP] idx 100332: section=서울&
# [SKIP] idx 100331: section=이슈+
# [SKIP] idx 100330: section=서울&
# [ERROR] idx 100329 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100328 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100327: section=서울&
# [SKIP] idx 100326: section=서울&
# [SKIP] idx 100325: section=서울&
# [SKIP] idx 100324: section=서울&
# [SKIP] idx 100323: section=한반도W
# [SKIP] idx 100322: section=서울&
# [ERROR] idx 100321 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100320: section=서울&
# [SKIP] idx 100319: section=서울&
# [SAVE] idx 100318: spnews_100318 저장 완료
# [SAVE] idx 100317: spnews_100317 저장 완료
# [SAVE] idx 100316: spnews_100316 저장 완료
# [SAVE] idx 100315: spnews_100315 저장 완료
# [SKIP] idx 100314: section=한반도W
# [SKIP] idx 100313: section=한반도W
# [SKIP] idx 100312: section=한반도W
# [SAVE] idx 100311: spnews_100311 저장 완료
# [ERROR] idx 100310 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100309 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100308 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100307: spnews_100307 저장 완료
# [SKIP] idx 100306: section=이슈+
# [SKIP] idx 100305: section=이슈+
# [SKIP] idx 100304: section=이슈+
# [SKIP] idx 100303: section=이슈+
# [SAVE] idx 100302: spnews_100302 저장 완료
# [SKIP] idx 100301: section=서울&
# [ERROR] idx 100300 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100299 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100298 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100297 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100296: section=서울&
# [ERROR] idx 100295 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100294: section=서울&
# [SKIP] idx 100293: section=서울&
# [SKIP] idx 100292: section=서울&
# [SKIP] idx 100291: section=서울&
# [SKIP] idx 100290: section=이슈+
# [SKIP] idx 100289: section=이슈+
# [ERROR] idx 100288 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100287 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100286: spnews_100286 저장 완료
# [SKIP] idx 100285: section=None
# [SAVE] idx 100284: spnews_100284 저장 완료
# [ERROR] idx 100283 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100282 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100281 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 100280 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100279: section=서울&
# [SKIP] idx 100278: section=이슈+
# [SKIP] idx 100277: section=이슈+
# [SKIP] idx 100276: section=서울&
# [SKIP] idx 100275: section=서울&
# [SKIP] idx 100274: section=서울&
# [SKIP] idx 100273: section=서울&
# [SKIP] idx 100272: section=한반도W
# [SAVE] idx 100271: spnews_100271 저장 완료
# [SAVE] idx 100270: spnews_100270 저장 완료
# [SAVE] idx 100269: spnews_100269 저장 완료
# [SAVE] idx 100268: spnews_100268 저장 완료
# [SAVE] idx 100267: spnews_100267 저장 완료
# [SAVE] idx 100266: spnews_100266 저장 완료
# [SAVE] idx 100265: spnews_100265 저장 완료
# [ERROR] idx 100264 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100263: section=한반도W
# [SKIP] idx 100262: section=한반도W
# [SKIP] idx 100261: section=한반도W
# [SKIP] idx 100260: section=한반도W
# [SKIP] idx 100259: section=한반도W
# [SAVE] idx 100258: spnews_100258 저장 완료
# [SKIP] idx 100257: section=서울&
# [SAVE] idx 100256: spnews_100256 저장 완료
# [SKIP] idx 100255: section=서울&
# [SKIP] idx 100254: section=서울&
# [SKIP] idx 100253: section=이슈+
# [SKIP] idx 100252: section=서울&
# [SKIP] idx 100251: section=서울&
# [SKIP] idx 100250: section=이슈+
# [SKIP] idx 100249: section=이슈+
# [SKIP] idx 100248: section=이슈+
# [SKIP] idx 100247: section=이슈+
# [ERROR] idx 100246 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 100245: spnews_100245 저장 완료
# [ERROR] idx 100244 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 100243: section=서울&
# [SKIP] idx 100242: section=서울&
# [SKIP] idx 100241: section=서울&
# [SKIP] idx 100240: section=서울&
# [ERROR] idx 100239 에러 발생: 'NoneType' object has no attribute 'split'
# ...
# [ERROR] idx 37997 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37996: spnews_37996 저장 완료
# [SKIP] idx 37995: section=서울&
# [SAVE] idx 37994: spnews_37994 저장 완료
# [ERROR] idx 37993 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37992: section=서울&
# [SKIP] idx 37991: section=서울&
# [SKIP] idx 37990: section=서울&
# [ERROR] idx 37989 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37988: section=서울&
# [ERROR] idx 37987 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37986 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37985: spnews_37985 저장 완료
# [SKIP] idx 37984: section=서울&
# [SKIP] idx 37983: section=서울&
# [ERROR] idx 37982 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37981 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37980: section=한반도W
# [ERROR] idx 37979 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37978: spnews_37978 저장 완료
# [SAVE] idx 37977: spnews_37977 저장 완료
# [SKIP] idx 37976: section=서울&
# [SKIP] idx 37975: section=서울&
# [SAVE] idx 37974: spnews_37974 저장 완료
# [SAVE] idx 37973: spnews_37973 저장 완료
# [SAVE] idx 37972: spnews_37972 저장 완료
# [SKIP] idx 37971: section=한반도W
# [ERROR] idx 37970 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37969: spnews_37969 저장 완료
# [SAVE] idx 37968: spnews_37968 저장 완료
# [SKIP] idx 37967: section=이슈+
# [ERROR] idx 37966 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37965: section=서울&
# [SAVE] idx 37964: spnews_37964 저장 완료
# [SAVE] idx 37963: spnews_37963 저장 완료
# [SAVE] idx 37962: spnews_37962 저장 완료
# [SKIP] idx 37961: section=한반도W
# [ERROR] idx 37960 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37959: spnews_37959 저장 완료
# [SKIP] idx 37958: section=서울&
# [SAVE] idx 37957: spnews_37957 저장 완료
# [SKIP] idx 37956: section=한반도W
# [SKIP] idx 37955: section=서울&
# [ERROR] idx 37954 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37953: section=한반도W
# [SKIP] idx 37952: section=한반도W
# [ERROR] idx 37951 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37950: section=한반도W
# [SAVE] idx 37949: spnews_37949 저장 완료
# [SAVE] idx 37948: spnews_37948 저장 완료
# [SKIP] idx 37947: section=이슈+
# [SKIP] idx 37946: section=한반도W
# [SKIP] idx 37945: section=서울&
# [SKIP] idx 37944: section=서울&
# [SKIP] idx 37943: section=서울&
# [SKIP] idx 37942: section=서울&
# [SAVE] idx 37941: spnews_37941 저장 완료
# [SKIP] idx 37940: section=서울&
# [SAVE] idx 37939: spnews_37939 저장 완료
# [SAVE] idx 37938: spnews_37938 저장 완료
# [SKIP] idx 37937: section=서울&
# [SKIP] idx 37936: section=이슈+
# [SKIP] idx 37935: section=이슈+
# [SKIP] idx 37934: section=이슈+
# [SKIP] idx 37933: section=한반도W
# [ERROR] idx 37932 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37931: section=서울&
# [ERROR] idx 37930 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37929: section=서울&
# [SKIP] idx 37928: section=서울&
# [SKIP] idx 37927: section=서울&
# [SKIP] idx 37926: section=서울&
# [SKIP] idx 37925: section=한반도W
# [ERROR] idx 37924 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37923 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37922: section=한반도W
# [SKIP] idx 37921: section=서울&
# [ERROR] idx 37920 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37919: section=한반도W
# [SAVE] idx 37918: spnews_37918 저장 완료
# [SKIP] idx 37917: section=한반도W
# [SAVE] idx 37916: spnews_37916 저장 완료
# [SAVE] idx 37915: spnews_37915 저장 완료
# [SKIP] idx 37914: section=한반도W
# [SKIP] idx 37913: section=한반도W
# [SKIP] idx 37912: section=이슈+
# [SKIP] idx 37911: section=이슈+
# [SKIP] idx 37910: section=서울&
# [SKIP] idx 37909: section=서울&
# [SAVE] idx 37908: spnews_37908 저장 완료
# [SAVE] idx 37907: spnews_37907 저장 완료
# [SAVE] idx 37906: spnews_37906 저장 완료
# [SKIP] idx 37905: section=서울&
# [SKIP] idx 37904: section=서울&
# [ERROR] idx 37903 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37902: section=서울&
# [SKIP] idx 37901: section=서울&
# [SKIP] idx 37900: section=한반도W
# [SKIP] idx 37899: section=서울&
# [SKIP] idx 37898: section=서울&
# [ERROR] idx 37897 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37896 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37895: section=서울&
# [ERROR] idx 37894 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37893 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37892: section=서울&
# [ERROR] idx 37891 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37890 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37889 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37888: section=서울&
# [ERROR] idx 37887 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37886 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37885: section=한반도W
# [SAVE] idx 37884: spnews_37884 저장 완료
# [SKIP] idx 37883: section=한반도W
# [SAVE] idx 37882: spnews_37882 저장 완료
# [SAVE] idx 37881: spnews_37881 저장 완료
# [SAVE] idx 37880: spnews_37880 저장 완료
# [SAVE] idx 37879: spnews_37879 저장 완료
# [SKIP] idx 37878: section=서울&
# [SKIP] idx 37877: section=서울&
# [SAVE] idx 37876: spnews_37876 저장 완료
# [ERROR] idx 37875 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37874: spnews_37874 저장 완료
# [SAVE] idx 37873: spnews_37873 저장 완료
# [SKIP] idx 37872: section=이슈+
# [SKIP] idx 37871: section=서울&
# [SAVE] idx 37870: spnews_37870 저장 완료
# [SKIP] idx 37869: section=서울&
# [SKIP] idx 37868: section=서울&
# [SKIP] idx 37867: section=서울&
# [SKIP] idx 37866: section=한반도W
# [SKIP] idx 37865: section=서울&
# [SKIP] idx 37864: section=서울&
# [SKIP] idx 37863: section=서울&
# [SAVE] idx 37862: spnews_37862 저장 완료
# [SKIP] idx 37861: section=한반도W
# [ERROR] idx 37860 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37859 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37858: section=한반도W
# [SKIP] idx 37857: section=한반도W
# [SAVE] idx 37856: spnews_37856 저장 완료
# [SAVE] idx 37855: spnews_37855 저장 완료
# [SAVE] idx 37854: spnews_37854 저장 완료
# [SAVE] idx 37853: spnews_37853 저장 완료
# [SKIP] idx 37852: section=서울&
# [SKIP] idx 37851: section=서울&
# [SAVE] idx 37850: spnews_37850 저장 완료
# [ERROR] idx 37849 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37848: section=이슈+
# [ERROR] idx 37847 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37846: section=이슈+
# [SKIP] idx 37845: section=서울&
# [SAVE] idx 37844: spnews_37844 저장 완료
# [ERROR] idx 37843 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37842: spnews_37842 저장 완료
# [SAVE] idx 37841: spnews_37841 저장 완료
# [ERROR] idx 37840 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37839: section=서울&
# [SKIP] idx 37838: section=서울&
# [SKIP] idx 37837: section=서울&
# [SKIP] idx 37836: section=서울&
# [ERROR] idx 37835 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37834: section=서울&
# [SKIP] idx 37833: section=서울&
# [SKIP] idx 37832: section=서울&
# [SKIP] idx 37831: section=서울&
# [SAVE] idx 37830: spnews_37830 저장 완료
# [SKIP] idx 37829: section=한반도W
# [ERROR] idx 37828 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37827: section=한반도W
# [SAVE] idx 37826: spnews_37826 저장 완료
# [SAVE] idx 37825: spnews_37825 저장 완료
# [SKIP] idx 37824: section=한반도W
# [ERROR] idx 37823 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37822: spnews_37822 저장 완료
# [SKIP] idx 37821: section=서울&
# [ERROR] idx 37820 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37819 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37818: section=서울&
# [SKIP] idx 37817: section=이슈+
# [SKIP] idx 37816: section=이슈+
# [SKIP] idx 37815: section=서울&
# [ERROR] idx 37814 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37813: section=서울&
# [SKIP] idx 37812: section=이슈+
# [SKIP] idx 37811: section=서울&
# [SAVE] idx 37810: spnews_37810 저장 완료
# [SKIP] idx 37809: section=서울&
# [SKIP] idx 37808: section=서울&
# [SKIP] idx 37807: section=서울&
# [ERROR] idx 37806 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37805: section=서울&
# [SKIP] idx 37804: section=서울&
# [SKIP] idx 37803: section=서울&
# [ERROR] idx 37802 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37801 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37800 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37799 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37798 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37797: spnews_37797 저장 완료
# [SKIP] idx 37796: section=서울&
# [ERROR] idx 37795 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37794: section=서울&
# [SAVE] idx 37793: spnews_37793 저장 완료
# [SAVE] idx 37792: spnews_37792 저장 완료
# [ERROR] idx 37791 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37790: spnews_37790 저장 완료
# [SKIP] idx 37789: section=서울&
# [ERROR] idx 37788 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37787: section=한반도W
# [SKIP] idx 37786: section=이슈+
# [SKIP] idx 37785: section=이슈+
# [SKIP] idx 37784: section=이슈+
# [SAVE] idx 37783: spnews_37783 저장 완료
# [SAVE] idx 37782: spnews_37782 저장 완료
# [SAVE] idx 37781: spnews_37781 저장 완료
# [SAVE] idx 37780: spnews_37780 저장 완료
# [SAVE] idx 37779: spnews_37779 저장 완료
# [SAVE] idx 37778: spnews_37778 저장 완료
# [ERROR] idx 37777 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37776 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37775 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37774: section=서울&
# [SKIP] idx 37773: section=서울&
# [ERROR] idx 37772 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37771: section=한반도W
# [SAVE] idx 37770: spnews_37770 저장 완료
# [SAVE] idx 37769: spnews_37769 저장 완료
# [SAVE] idx 37768: spnews_37768 저장 완료
# [SKIP] idx 37767: section=이슈+
# [SKIP] idx 37766: section=이슈+
# [SAVE] idx 37765: spnews_37765 저장 완료
# [SAVE] idx 37764: spnews_37764 저장 완료
# [SKIP] idx 37763: section=서울&
# [ERROR] idx 37762 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37761 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37760 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37759 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37758: section=서울&
# [SKIP] idx 37757: section=서울&
# [SKIP] idx 37756: section=한반도W
# [SKIP] idx 37755: section=서울&
# [SAVE] idx 37754: spnews_37754 저장 완료
# [SAVE] idx 37753: spnews_37753 저장 완료
# [SKIP] idx 37752: section=한반도W
# [ERROR] idx 37751 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37750: section=한반도W
# [SKIP] idx 37749: section=서울&
# [SKIP] idx 37748: section=서울&
# [SKIP] idx 37747: section=한반도W
# [SAVE] idx 37746: spnews_37746 저장 완료
# [ERROR] idx 37745 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37744: spnews_37744 저장 완료
# [SAVE] idx 37743: spnews_37743 저장 완료
# [SAVE] idx 37742: spnews_37742 저장 완료
# [ERROR] idx 37741 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37740: spnews_37740 저장 완료
# [SKIP] idx 37739: section=한반도W
# [SKIP] idx 37738: section=서울&
# [SKIP] idx 37737: section=서울&
# [SKIP] idx 37736: section=이슈+
# [SKIP] idx 37735: section=이슈+
# [SKIP] idx 37734: section=이슈+
# [SKIP] idx 37733: section=서울&
# [SKIP] idx 37732: section=서울&
# [ERROR] idx 37731 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37730 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37729: section=이슈+
# [ERROR] idx 37728 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37727: section=이슈+
# [SKIP] idx 37726: section=이슈+
# [SKIP] idx 37725: section=이슈+
# [SAVE] idx 37724: spnews_37724 저장 완료
# [SKIP] idx 37723: section=이슈+
# [ERROR] idx 37722 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37721: spnews_37721 저장 완료
# [SKIP] idx 37720: section=서울&
# [SKIP] idx 37719: section=서울&
# [SKIP] idx 37718: section=서울&
# [SKIP] idx 37717: section=한반도W
# [SKIP] idx 37716: section=서울&
# [SAVE] idx 37715: spnews_37715 저장 완료
# [ERROR] idx 37714 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37713: section=한반도W
# [SAVE] idx 37712: spnews_37712 저장 완료
# [SKIP] idx 37711: section=한반도W
# [SKIP] idx 37710: section=한반도W
# [SAVE] idx 37709: spnews_37709 저장 완료
# [SAVE] idx 37708: spnews_37708 저장 완료
# [SAVE] idx 37707: spnews_37707 저장 완료
# [SKIP] idx 37706: section=이슈+
# [SKIP] idx 37705: section=서울&
# [ERROR] idx 37704 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37703: section=서울&
# [SKIP] idx 37702: section=이슈+
# [SAVE] idx 37701: spnews_37701 저장 완료
# [SAVE] idx 37700: spnews_37700 저장 완료
# [ERROR] idx 37699 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37698: section=서울&
# [ERROR] idx 37697 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37696: spnews_37696 저장 완료
# [ERROR] idx 37695 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37694: section=서울&
# [SAVE] idx 37693: spnews_37693 저장 완료
# [SAVE] idx 37692: spnews_37692 저장 완료
# [SKIP] idx 37691: section=서울&
# [SAVE] idx 37690: spnews_37690 저장 완료
# [SAVE] idx 37689: spnews_37689 저장 완료
# [SKIP] idx 37688: section=서울&
# [SKIP] idx 37687: section=서울&
# [SKIP] idx 37686: section=서울&
# [SKIP] idx 37685: section=서울&
# [SKIP] idx 37684: section=서울&
# [ERROR] idx 37683 에러 발생: 'NoneType' object has no attribute 'split'
# [SAVE] idx 37682: spnews_37682 저장 완료
# [SKIP] idx 37681: section=한반도W
# [SKIP] idx 37680: section=한반도W
# [SKIP] idx 37679: section=한반도W
# [SAVE] idx 37678: spnews_37678 저장 완료
# [SAVE] idx 37677: spnews_37677 저장 완료
# [SAVE] idx 37676: spnews_37676 저장 완료
# [SAVE] idx 37675: spnews_37675 저장 완료
# [SKIP] idx 37674: section=서울&
# [SKIP] idx 37673: section=서울&
# [SKIP] idx 37672: section=서울&
# [ERROR] idx 37671 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37670 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37669: section=서울&
# [ERROR] idx 37668 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37667 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37666 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37665 에러 발생: 'NoneType' object has no attribute 'split'
# [SKIP] idx 37664: section=서울&
# [ERROR] idx 37663 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37662 에러 발생: 'NoneType' object has no attribute 'split'
# [ERROR] idx 37661 에러 발생: 'NoneType' object has no attribute 'split'
# CPU times: total: 4h 21min 45s
# Wall time: 15h 42min 33s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\ncrawler = SPNAllCrawler(\n    start = 101404,\n    end = 1,                        \n    filename = "spnews.csv",\n    section = "북한N",          \n    sleep_min = 0.7,\n    sleep_max = 1.5                   # 조금 여유롭게\n)\n\ncrawler.run()\n')
#
# File c:\Users\user\Desktop\MODULABS\LangchainThon\LangchainThon\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\user\Desktop\MODULABS\LangchainThon\LangchainThon\.venv\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\user\Desktop\MODULABS\LangchainThon\LangchainThon\.venv\Lib\site-packages\IPython\core\magics\execution.py:1421, in ExecutionMagics.time(self, line, cell, local_ns)
#    1419     if expr_val is not None:
#    1420         code_2 = self.shell.compile(expr_val, source, 'eval')
# -> 1421         out = eval(code_2, glob, local_ns)
#    1422 except KeyboardInterrupt as e:
#    1423     captured_exception = e
#
# File <timed exec>:10
#
# Cell In[24], line 81, in SPNAllCrawler.run(self)
#      78             print(f"[ERROR] idx {i} 에러 발생: {e}")
#      80         # 서버 부하/차단 방지를 위한 랜덤 슬립
# ---> 81         time.sleep(random.uniform(self.sleep_min, self.sleep_max))
#      83 finally:
#      84     f.close()
#
# KeyboardInterrupt:
