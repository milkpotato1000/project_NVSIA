# %%
import pandas as pd 
import pickle
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('data/full_df_final.csv.tsv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('data/full_df_final.csv.tsv')
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/full_df_final.csv.tsv'

# %%
pred_data = df[['id', 'event_title', 'summary', 'category', 'url']].copy()
news_id = []
for url in pred_data['url']:
    news_id.append(f'spnews_{str(url).split('=')[1]}')

pred_data['id'] = news_id
pred_data.rename(columns={'category': 'pred_category'}, inplace=True)
pred_data.drop(columns=['url'], inplace=True)
pred_data.head()
# Out:
#               id           event_title  \
# 0  spnews_101404     신의주온실종합농장 건설 마감단계
# 1  spnews_101403  북한, 나무 사름률 높이는 제품 소개
# 2  spnews_101402  개성시 식물방역소 및 돼지종축장 건설
# 3  spnews_101394    가을 추수로 인한 곡물 가격 하락
# 4  spnews_101392            어머니날 경축 행사
#
#                                              summary pred_category
# 0  신의주온실종합농장 건설장에서 지대정리와 잔디심기가 마감단계에 이르고 있다. 군민건설...         경제/산업
# 1  북한이 나무의 사름률을 높이는 과학기술제품으로 천연생물활성제를 소개했다. 이 제품은...         경제/산업
# 2  북한 개성시에서 식물방역소와 돼지종축장이 새로 건설되었다. 개성시식물방역소 건설에 ...         경제/산업
# 3  가을 추수가 마무리되면서 북한의 곡물 가격이 하락세를 보이고 있다. 쌀과 옥수수 등...         경제/산업
# 4  북한 각지에서 어머니날을 경축하며 김일성-김정일 동상에 꽃다발을 바쳤다. 공산주의어...      사회/문화/체육

# %%
label_data = pd.read_csv('data/spnews_final.csv')
filtered_labeled_data = label_data[label_data['id'].isin(news_id)][['id', 'category']]

# %%
test_data = pred_data.merge(filtered_labeled_data, on='id', how='left')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 🔥 label 순서를 고정 (unique 순서 통일)
labels = sorted(list(set(test_data['category']) | set(test_data['pred_category'])))

accuracy = accuracy_score(test_data["category"], test_data["pred_category"])
cm = confusion_matrix(test_data["category"], test_data["pred_category"], labels=labels)

print(f'Accuracy: {accuracy}')
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues",
            xticklabels=labels, yticklabels=labels)

plt.xlabel("예측값")
plt.ylabel("실제값")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.96

# %%
with open('pickle/s_news_cate_tfidf_xcombined_vec.pkl', 'rb') as f:
    vectorizer = pickle.load(f)

# %%
df = pd.read_csv('data/test_region_parsing_result.tsv')
df
# Out:
#     id                                            summary  \
# 0    1  신의주온실종합농장 건설장에서 지대정리와 잔디심기가 마감단계에 이르고 있다. 군민건설...
# 1    2  북한이 나무의 사름률을 높이는 과학기술제품으로 천연생물활성제를 소개했다. 이 제품은...
# 2    3  북한 개성시에서 식물방역소와 돼지종축장이 새로 건설되었다. 개성시식물방역소 건설에 ...
# 3    4  가을 추수가 마무리되면서 북한의 곡물 가격이 하락세를 보이고 있다. 쌀과 옥수수 등...
# 4    5  북한 각지에서 어머니날을 경축하며 김일성-김정일 동상에 꽃다발을 바쳤다. 공산주의어...
# 5    6  평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행되었다. 농장 일꾼들과 근...
# 6    7  북한 여자축구선수들이 2025 FIFA U-17 여자월드컵에서 우승하고 귀국했다. ...
# 7    8  양강도에서 올해 계획된 수천 세대의 농촌살림집 건설이 마무리되었다. 여러 군과 시에...
# 14          어머니날, 축하장, 발행, 평양, 김일성                 북한, 어머니날 맞아 축하장 발행
# 15    새집들이, 성암농장, 남포시, 축하공연, 이용허가증                   남포시 성암농장 새집들이 모임
# 16            박태성, 경제, 석탄, 발전소, 비료              박태성 내각총리, 경제 부문 현장 확인
# 17             날씨, 흐림, 적설, 기온, 강수량                   11월 16일 북한 날씨 예보
# 18  관광기념품전시회, 전시회, 관광상품, 옥류전시관, 제품                   관광기념품전시회-2025 개막
# 19      입사모임, 살림집, 양강도, 삼수군, 농업근로자         양강도 포성농장과 삼수군 중룡농장 입사모임 개최
# 20        정보화, 모범단위, 생산성, 기술개발, 성과                2025년 10대정보화모범단위 선정
# 21               날씨, 비, 눈, 기온, 기상청                       북한 전지역 날씨 예보
# 22      살림집, 입사모임, 양강도, 풍서군, 농업근로자                양강도 풍서군 살림집 입사모임 개최
#
#     event_date event_person  \
# 0   2025-11-17          NaN
# 1   2025-11-17          NaN
# 2   2025-11-17          NaN
# 3   2025-11-15          NaN
# 4   2025-11-16          NaN
# 5   2025-05-16     리경철, 최영송
# 6   2025-11-15          김일국
# 7   2025-11-17          NaN
# 8   2025-11-17          NaN
# 9   2025-11-11          NaN
# 10  2025-11-16          NaN
# 11  2025-11-15          NaN
# 12  2025-11-15          김남진
# 13  2025-11-16          NaN
# 14  2025-11-16          NaN
# 15  2025-11-16          NaN
# 16  2025-11-16          박태성
# 17  2025-11-16          NaN
# 18  2025-11-14          NaN
# 19  2025-11-15          NaN
# 20  2025-11-15          NaN
# 21  2025-11-15          NaN
# 22  2025-11-14          NaN
#
#                                             event_org  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                   개성시식물방역소, 개성돼지종축장
# 3                                                 NaN
# 4                                                 NaN
# 5                                  평안남도당위원회, 도농촌경리위원회
# 6                                                축구협회
# 7                                       당원대대, 평양시당원대대
# 8                                                 기상청
# 9                                                 NaN
# 10                                                 여맹
# 11  구성공작기계공장, 만경대공작기계공장, 안주펌프공장, 원산통풍기공장, 평양채굴기계공장...
# 12                                             조선화초협회
# 13                                                NaN
# 14                           문학예술출판사, 중앙미술창작사, 평양미술대학
# 15                                 남포시, 대안구역, 당, 정권기관
# 16        내각, 석탄공업성, 청년탄광연합기업소, 청천강화력발전소, 남흥청년화학연합기업소
# 17                                                기상청
# 18                                     경공업성, 문화성, 보건성
# 19                                         양강도농촌경리위원회
# 20  천리마타일공장, 신의주화장품공장, 농업과학원 농업정보화연구소, 갈마식료공장, 과학기...
# 21                                                기상청
# 22                                   양강도, 풍서군 당, 정권기관
#
#                                      event_loc  \
# 0                                    평안북도 신의주시
# 1                                          NaN
# 2                                          개성시
# 3             강원도 원산시, 양강도 혜산시, 평양시, 황해북도 사리원시
# 4          강원도, 개성시, 나선시, 양강도, 평안남도, 평양시, 황해북도
# 5                                         평안남도
# 6                                          평양시
# 7                                      양강도 혜산시
# 8                                양강도, 평안도, 함경도
# 9                                          강원도
# 10                        양강도, 평안남도, 평양시, 황해남도
# 11  강원도 원산시, 양강도 혜산시, 평안남도 안주시, 평양시, 황해북도 사리원시
# 12                                         NaN
# 13                                         카타르
# 14                                         평양시
# 18  北, '관광기념품전시회-2025' 개막...400여종  2,000여점 출품   2025-11-15
# 19               北 양강도 포성농장·삼수군 중룡농장 살림집 입사모임   2025-11-15
# 20            北, '2025년 10대정보화모범단위' 선정...성과는?   2025-11-15
# 21               [오늘의 북한 날씨] 전지역 오전까지 가끔 구름많음   2025-11-15
# 22         北 양강도, 풍서군 상리축산농장·우포축산농장 살림집 입사 모임   2025-11-14

# %%
print(str(df[df['id'] == 'spnews_101392'].url))
# Out:
# 4    https://www.spnews.co.kr/news/articleView.html...
# Name: url, dtype: object

# %%
df[df['id'] == 'spnews_101392']
# Out:
#               id                            title  \
# 4  spnews_101392  북한 각지서 어머니날 경축... 김일성-김정일 동상 참배
#
#                                             contents  source section  \
# 4  북한 각지에서 어머니날(11월 16일)을 경축했다.\n노동신문은 17일 "어머니날을...  spnews     북한N
#
#      author publish_date                                                url  \
# 4  안윤석  대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
#
#    category                                            summary  \
# 4  사회/문화/체육  북한 각지에서 어머니날을 경축하며 김일성-김정일 동상에 꽃다발을 바쳤다. 공산주의어...
#
#                   keywords event_title  event_date event_person event_org  \
# 4  어머니날, 경축, 동상, 공연, 여성근로자  어머니날 경축 행사  2025-11-16          NaN       NaN
#
#                         event_loc  p_rice(won/kg)  p_corn(won/kg)  \
# 4  평안남도, 황해북도, 강원도, 양강도, 나선시, 개성시             NaN             NaN
#
#    p_usd(won/usd)  job_cost
# 4             NaN  0.000316

# %%
df1 = pd.read_csv('data/spnews_final.csv')
df1 =  df1[df1['contents'].notnull() & df1['category'].notnull()]
df1.shape
# Out:
# (19141, 9)

# %%
df2 = pd.read_csv('data/summary_df_final.csv')
df2.shape
# Out:
# (19141, 12)

# %%
merged_df = df1.merge(df2, on='id')

# %%
merged_df.shape
# Out:
# (19141, 20)

# %%
merged_df.to_csv('data/full_df_final.csv', index=False)

# %%
summary_df = pd.read_csv('data/cached/cache_output.csv')
len(summary_df)
# Out:
# 961

# %%
sum(summary_df.job_cost)
# Out:
# 1.9660058999998153

# %%
article_df = pd.read_csv('data/spnews_ver2.csv')

# %%
merged_df = article_df.merge(summary_df, how='right', on='id')
merged_df.drop(columns=['job_cost'], inplace=True)

# %%
merged_df.to_excel('data/merged_summary.xlsx', index=False)
merged_df.to_csv('data/merged_summary.csv', index=False)

# %%
merged_df
# Out:
#                  id                                       title  \
# 0     spnews_101404             北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 1     spnews_101403                         北,  나무 사름률 높이는 제품은?
# 2     spnews_101402                       北 개성시, 식물방역소·돼지종축장 신축
# 3     spnews_101394                    [北 물가] 가을 추수 영향, 곡물가 내림세
# 4     spnews_101392             북한 각지서 어머니날 경축... 김일성-김정일 동상 참배
# ...             ...                                         ...
# 6903   spnews_63911                    [北 한컷] 토끼 기르기 "군중적으로 전개"
# 6904   spnews_63903             북한, 핀란드 NATO 가입 비난..."후안무치한 행태"
# 6905   spnews_63895  북한, '전국대학 2022년 교육총화회의'..."과학연구기지 중심돼야" 독려
# 6906  북한이 한미군사연습을 계기로 반미·대남 비난을 강화하며 내부 결속을 다지고 있다. ...
# 6907  제36차 전국과학기술축전이 10일부터 진행된다. 축전 기간 동안 학술토론회, 연구토...
#
#                                             keywords              event_title  \
# 0             ['온실농장', '잔디심기', '지대정리', '건설', '자연공원']        신의주온실종합농장 건설 마감단계
# 1               ['나무', '사름률', '천연생물활성제', '제품', '효과']     북한, 나무 사름률 높이는 제품 소개
# 2              ['식물방역소', '돼지종축장', '건설', '개성시', '농업']     개성시 식물방역소 및 돼지종축장 건설
# 3                     ['곡물', '가격', '하락', '추수', '유류']          가을 추수로 곡물 가격 하락
# 4                 ['어머니날', '김일성', '김정일', '동상', '공연']               어머니날 경축 행사
# ...                                              ...                      ...
# 6903              ['토끼', '축산정책', '군중적', '생산', '단백질']   평안북도에서 토끼 기르기 군중적으로 전개
# 6904              ['핀란드', 'NATO', '러시아', '군사', '미국']       북한, 핀란드 NATO 가입 비난
# 6905                ['교육', '과학연구', '대학', '정책', '회의']     전국대학 2022년 교육총화회의 개최
# 6906     ['한미군사연습', '내부결속', '반미', '복수결의모임', '신천박물관']  북한, 한미군사연습 계기로 내부 결속 강화
# 6907  ['과학기술축전', '가상전시회', '학술토론회', '연구토론회', '성과발표회']         제36차 전국과학기술축전 개최
#
#       event_date event_person                            event_org  \
# 0     2025-11-17           []                                   []
# 1     2025-11-17           []                                   []
# 2     2025-11-17           []  ['개성시식물방역소', '시남새온실', '시유기질복합비료공장']
# 3     2025-11-15           []                                   []
# 4     2025-11-16           []                                   []
# ...          ...          ...                                  ...
# 6903  2023-04-07           []                                   []
# 6904  2023-04-07      ['김유철']                                   []
# 6905  2023-03-07           []                              ['교육부']
# 6906  2023-04-06      ['박인철']                          ['조선직업총동맹']
# 6907  2023-04-10           []                                   []
#
#          event_loc  p_rice(won/kg)  p_corn(won/kg)  p_usd(won/usd)  job_cost
# 0     ['평안북도 신의주']             NaN             NaN             NaN  0.000263
# 1               []             NaN             NaN             NaN  0.000269
# 2          ['개성시']             NaN             NaN             NaN  0.000272
# 3          ['평양시']         19850.0          4500.0         34600.0  0.000312
# 4          ['평양시']             NaN             NaN             NaN  0.000236
# ...            ...             ...             ...             ...       ...
# 6903      ['평안북도']             NaN             NaN             NaN  0.000242
# 6904            []             NaN             NaN             NaN  0.000232
# 6905       ['평양시']             NaN             NaN             NaN  0.000303
# 6906       ['신천군']             NaN             NaN             NaN  0.000301
# 6907            []             NaN             NaN             NaN  0.000237
#
# [6908 rows x 20 columns]

# %%
merged_df[merged_df.id == 'spnews_101394']
# Out:
#               id                     title  \
# 3  spnews_101394  [北 물가] 가을 추수 영향, 곡물가 내림세
#
#                                             contents  source section   author  \
# 3  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...  spnews     북한N  안윤석 대기자
#
#   publish_date                                                url category  \
# 3   2025-11-17  https://www.spnews.co.kr/news/articleView.html...    경제/산업
#
#                                              summary  \
# 3  가을 추수가 마무리되면서 북한의 곡물 가격이 하락세를 보이고 있다. 쌀과 옥수수 가...
#
#                          keywords      event_title  event_date event_person  \
# 3  ['곡물', '가격', '하락', '추수', '유류']  가을 추수로 곡물 가격 하락  2025-11-15           []
#
#   event_org event_loc  p_rice(won/kg)  p_corn(won/kg)  p_usd(won/usd)
# 3        []   ['평양시']         19850.0          4500.0         34600.0

# %%
df = pd.read_csv('data/spnews_final.csv')
df.head(3)
# Out:
#               id                            title  \
# 0  spnews_101404  北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 1  spnews_101403              北,  나무 사름률 높이는 제품은?
# 2  spnews_101402            北 개성시, 식물방역소·돼지종축장 신축
#
#                                             contents  source section  \
# 0  북한 평안북도 신의주온실종합농장 건설장에서 방대한 면적의 지대정리와 잔디심기가 마감...  spnews     북한N
# 1  북한이 나무의 사름률을 보장에 효과적인 과학기술제품으로 천연생물활성제 등이 있다고 ...  spnews     북한N
# 2  북한 개성시에서 식물방역소와 돼지종축장 새로 건설했다.\n노동신문은 17일 "개성시...  spnews     북한N
#
#      author publish_date                                                url  \
# 0   안윤석 대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
# 1  안윤석  대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
# 2  안윤석  대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
#
#    category
# 0     경제/산업
# 1     경제/산업
# 2  사회/문화/체육

# %%
df[df.contents]
# Out:
#                   id                                   title  \
# 78     spnews_101077    [오늘의 북한 날씨] 평안도·황해도 구름많음, 함경도 대체로 흐림
# 178    spnews_100515   北 미사일총국 "극초음속비행체 시험발사 성공"...김정은 참관 안해
# 284    spnews_100091        NKDB '2025 북한인권·북한종교자유백서 발간 세미나'
# 708     spnews_97920    중·러 北대사관, 항일전쟁·반파시스트전쟁 승리 80주년 공동 기념
# 784     spnews_97452             北 건설단위, 화력발전소 등 주요 산업 건설 추진
# ...              ...                                     ...
# 19342     spnews_200  대북매체, "북 김원홍 보위상, 군총정치국 조직부국장으로 전보" 주장
# 19373      spnews_78        北 풍계리 핵실험장 '밀봉' 수준…핵실험 증거 수집 어려워
# 19374      spnews_53           英 정부, 6년간 북한에 공적개발원조로 56억원 제공
# 19375      spnews_52       중국행 북한 선박 현저히 줄어...'석탄 금수' 영향인 듯,
# 19376      spnews_39   국무부, 북한 ‘미사일 발사 계속’ 언급에 “중국, 대북 압박해야”
#
#                                                 contents  source section  \
# 78     [기상청 발표 11월 7일(금) 북한 날씨]\n□ 평안도·황해도 구름많음, 함경도 ...  spnews     북한N
# 178    북한 미사일총국이 22일 중요무기체계의 시험을 성공적으로 진행했다고 밝혔다.\n조선...  spnews     북한N
# 284                                                  NaN  spnews     북한N
# 708    북한 주재 러시아 대사관과 중국 대사관이 전승절 80주년과 항일전쟁 승리 80주년을...  spnews     북한N
# 784    북한 건설단위에서 주요 산업대상 건설을 추진하고있다.\n조선중앙통신은 21일 "청진...  spnews     북한N
# ...                                                  ...     ...     ...
# 19342                                                NaN  spnews     북한N
# 19373                                                NaN  spnews     북한N
# 19374                                                NaN  spnews     북한N
# 19375                                                NaN  spnews     북한N
# 6906     ['한미군사연습', '내부결속', '반미', '복수결의모임', '신천박물관']  북한, 한미군사연습 계기로 내부 결속 강화
# 6907  ['과학기술축전', '가상전시회', '학술토론회', '연구토론회', '성과발표회']         제36차 전국과학기술축전 개최
#
#       event_date event_person                            event_org  \
# 0     2025-11-17           []                                   []
# 1     2025-11-17           []                                   []
# 2     2025-11-17           []  ['개성시식물방역소', '시남새온실', '시유기질복합비료공장']
# 3     2025-11-15           []                                   []
# 4     2025-11-16           []                                   []
# ...          ...          ...                                  ...
# 6903  2023-04-07           []                                   []
# 6904  2023-04-07      ['김유철']                                   []
# 6905  2023-03-07           []                              ['교육부']
# 6906  2023-04-06      ['박인철']                          ['조선직업총동맹']
# 6907  2023-04-10           []                                   []
#
#          event_loc  p_rice(won/kg)  p_corn(won/kg)  p_usd(won/usd)
# 0     ['평안북도 신의주']             NaN             NaN             NaN
# 1               []             NaN             NaN             NaN
# 2          ['개성시']             NaN             NaN             NaN
# 3          ['평양시']         19850.0          4500.0         34600.0
# 4          ['평양시']             NaN             NaN             NaN
# ...            ...             ...             ...             ...
# 6903      ['평안북도']             NaN             NaN             NaN
# 6904            []             NaN             NaN             NaN
# 6905       ['평양시']             NaN             NaN             NaN
# 6906       ['신천군']             NaN             NaN             NaN
# 6907            []             NaN             NaN             NaN
#
# [6908 rows x 19 columns]

# %%
cache_data = pd.read_csv('data/cached/cache_output.csv')
cache_data.head(2)
# Out:
#               id                                            summary  \
# 0  spnews_101404  신의주온실종합농장 건설장에서 지대정리와 잔디심기가 마감단계에 이르고 있다. 군민건설...
# 1  spnews_101403  북한이 나무의 사름률을 높이는 과학기술제품으로 천연생물활성제를 소개했다. 이 제품은...
#
#                                  keywords           event_title  event_date  \
# 0  ['온실농장', '잔디심기', '지대정리', '건설', '자연공원']     신의주온실종합농장 건설 마감단계  2025-11-17
# 1    ['나무', '사름률', '천연생물활성제', '제품', '효과']  북한, 나무 사름률 높이는 제품 소개  2025-11-17
#
#   event_person event_org     event_loc  p_rice(won/kg)  p_corn(won/kg)  \
# 0           []        []  ['평안북도 신의주']             NaN             NaN
# 1           []        []            []             NaN             NaN
#
#    p_usd(won/usd)  job_cost
# 0             NaN  0.000263
# 1             NaN  0.000269

# %%
merged_df.summary.isna().sum()
# Out:
# np.int64(0)

# %%
merged_df.keywords.isna().sum()
# Out:
# np.int64(0)

# %%
columns = list(cache_data.columns[:-1])

# %%
cache_output = merged_df[columns]
cache_output.to_csv('data/cached/cache_output.csv', index=False)

# %%
test_input = pd.read_csv('data/spnews_ver2.csv')
test_input = test_input[test_input.contents.notnull() & test_input.category.notnull()]

# %%
test_input[test_input.id == 'spnews_97892']
# Out:
#                id                                  title  \
# 713  spnews_97892  김정은, 위화도 온실농장·제방공사장 시찰..."철도역, 화물역으로"
#
#                                               contents  source section  \
# 713  북한 김정은 총비서가 1일 위화도온실종합농장 건설장과 신의주시, 의주군의 섬지구 영...  spnews     북한N
#
#       author publish_date                                                url  \
# 713  안윤석 대기자   2025-08-02  https://www.spnews.co.kr/news/articleView.html...
#
#     category
# 713       정치

# %%
test_input
