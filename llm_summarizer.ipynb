# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from dotenv import load_dotenv
from openai import OpenAI
import json
import ast
import asyncio
import re

os.makedirs('data/cached', exist_ok=True)

# %% [markdown]
# # Article Crawling

# %%
class ArticleCrawling:

    def __init__(self, url):
        self.url = url
        self.soup = self._get_soup()

    def _get_soup(self):
        response = requests.get(self.url)
        return BeautifulSoup(response.text, 'html.parser')
    
    def get_article_url(self):
        meta_tag = self.soup.find("meta", property = "og:url")
        return meta_tag["content"] if meta_tag else None
    
    def get_id(self):
        url = self.get_article_url()    # https://www.spnews.co.kr/news/articleView.html?idxno=101049

        # source(spnew, ytn 등등)
        source = url.split("//")[1]
        source = source.split("/")[0]
        source = source.replace("www.", "").split(".")[0]

        # id
        if "idxno" not in url:
            return None
        idx = url.split("idxno=")[1]
        return f"{source}_{idx}"
    
    def get_title(self):
        header = self.soup.find("h1", class_ = "heading")
        return header.get_text(strip = True) if header else None
      
    def get_author(self):
        tag = self.soup.find("i", class_ = "icon-user-o")
        if tag:
            author = tag.parent.get_text(strip = True)
            return author.replace("기자명", "").strip()
        
    def get_category(self):
        breadcrumb = self.soup.find("ul", class_ = "breadcrumbs")
        if breadcrumb:
            for a in breadcrumb.find_all("a"):
                text = a.get_text(strip=True)
                if text in ["정치", "외교", "군사", "경제/산업", "사회/문화/체육"]:
                    return text
    
    def get_publish_date(self):
        tag = self.soup.find("i", class_ = "icon-clock-o")
        if tag:
            raw = tag.parent.get_text(strip = True)
            return raw.replace("입력", "").strip()
        
    def get_contents(self):
        article_body = self.soup.find_all("span", style = "font-size:18px;")
        contents = "\n".join(i.get_text(strip = True) for i in article_body)
        # return contents.rstrip("@") 
        return contents.split('@')[0].strip()
    
    def to_dict(self):
        return {
            "url": self.get_article_url(),
            "id": self.get_id(),
            "title": self.get_title(),
            "author": self.get_author(),
            "category": self.get_category(),
            "publish_date": self.get_publish_date(),
            "contents": self.get_contents()
        }
    
    def __str__(self):
        data = self.to_dict()
        return data

# %%
url_list = [
    'https://www.spnews.co.kr/news/articleView.html?idxno=101049',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101366',
    'https://www.spnews.co.kr/news/articleView.html?idxno=100345',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101306',
    'https://www.spnews.co.kr/news/articleView.html?idxno=100889',
    'https://www.spnews.co.kr/news/articleView.html?idxno=100318',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101377',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101097',
    'https://www.spnews.co.kr/news/articleView.html?idxno=100356',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101404',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101394',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101258',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101402',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101369',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101272',
    'https://www.spnews.co.kr/news/articleView.html?idxno=101394',
]

# %%
def make_test_dataset(url_list):
    test_df = pd.DataFrame(columns=['id', 'title', 'contents', 'author', 'publish_date', 'url', 'category'])

    for url in url_list:
        test1 = ArticleCrawling(url).to_dict()

        # DataFrame에 한 행 추가
        test_df.loc[len(test_df)] = [
            test1['id'],
            test1['title'],
            test1['contents'],
            test1['author'],
            test1['publish_date'],
            test1['url'],
            test1['category'],
        ]

    return test_df.reset_index(drop=True)

# %%
test_df = make_test_dataset(url_list)

# %%
test_df.head(5)
# Out:
#               id                                        title  \
# 0  spnews_101049                    北, 김영남 상임위원장 영결식...김정은 참석
# 1  spnews_101366          박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2  spnews_100345  김정은, '신의주온실종합농장' 또 현지지도..."농촌문명의 새로운 경지 개척"
# 3  spnews_101306               박태성 北 내각총리, 통싸완 폼비한 라오스 외무상 접견
# 4  spnews_100889         북한-러시아, 무역경제 및 과학기술협력 추진 회담...의정서 조인
#
#                                             contents   author  \
# 0  고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...  안윤석 대기자
# 1  박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다.\n노동신...  안윤석 대기자
# 2  김정은 북한 총비서가 17일 마감단계에 들어선 신의주온실종합농장 건설장을 또다시 방...  안윤석 대기자
# 3  박태성 북한 내각총리가 13일 만수대의사당에서 통싸완 폼비한 라오스 외무상을 만났다...  안윤석 대기자
# 4  북한과 러시아가 합의된 다방면적인 쌍무협력계획 이행을 추진하기 위한 회담을 31일 ...  안윤석 대기자
#
#        publish_date                                                url  \
# 0  2025.11.06 07:40  https://www.spnews.co.kr/news/articleView.html...
# 1  2025.11.16 06:47  https://www.spnews.co.kr/news/articleView.html...
# 2  2025.10.18 07:02  https://www.spnews.co.kr/news/articleView.html...
# 3  2025.11.14 07:17  https://www.spnews.co.kr/news/articleView.html...
# 4  2025.11.01 07:15  https://www.spnews.co.kr/news/articleView.html...
#
#   category
# 0       정치
# 1       정치
# 2       정치
# 3       외교
# 4       외교

# %%
# 테스트df 복사본 생성
test_data = test_df.copy()

# 테스트 데이터의 게재일 datetime으로 변환
test_data['publish_date'] = pd.to_datetime(test_data['publish_date']).dt.date
test_data.head(2)

# 테스트 데이터 저장
os.makedirs('data', exist_ok=True)
test_data.to_csv('data/test_dataset.tsv', index=False, sep='\t')

# %% [markdown]
# # LLM Summarizer 구현

# %%
# .env 파일 로드
load_dotenv()  # 현재 디렉토리 내 .env 파일 정보를 환경변수로 읽어옴

# 환경변수 확인
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY not found. .env 또는 시스템 환경변수에 설정하세요.")

# %%
# OpenAI 클라이언트 초기화
client = OpenAI(api_key=api_key)

# %%
def value_to_strCSV(value):
    """
    리스트 또는 쉼표 문자열을 'a, b, c' 형태의 문자열로 표준화
    """
    if not value:
        return ""

    # 이미 리스트이면 → 요소 strip 후 join
    if isinstance(value, list):
        return ", ".join(x.strip() for x in value)

    # 문자열이면 split → 다시 join 처리
    if isinstance(value, str):
        return ", ".join(x.strip() for x in value.split(","))

    # 그 외 타입은 문자열로 강제 변환
    return str(value)

# %%
# 뉴스요약 LLM 함수
def get_article_summary(title, contents, publish_date, model="gpt-4o-mini"):
    """
    뉴스 기사를 LLM으로 요약하고 항목별 데이터 반환
    
    Change Log:
        @@ 11.18 
        > 프롬프트 수정
            - 키값 정리 형식 재 설정 - 데이터 프레임의 컬럼명이 키값이 되도록 수정
            - 추가적인 컬럼 event_person 추가
            - event_obj 컬럼명 event_org로 변경
        @@ 11.19
        > 프롬프트 수정
            - 인물명은 이름만 명확하게
            - 지역명은 [국가, 도, 시] 단위로 명확하게
            - 평양 쌀, 옥수수, 달러환율 정보는 각기 별개의 데이터로 저장
            - 키워드는 인물명, 지역명을 반드시 포함 + 요약내용 대표 단어 추가
        > result 파싱 방식 수정
            - eval()에서 jason.load()로 변경
    """
    
    prompt = f"""
    아래 기사를 분석하여 요구된 정보를 작성하시오.

    # 기사 제목:
    {title}

    # 기사 내용:
    {contents}

    # 기사 작성일:
    {publish_date}

   1. 아래 형식으로 정리 (괄호안 각 key값의 한글 설명은 참고만 하고 최종 결과에는 포함하지 않음)
    - summary(주요 사건 요약):
    - event_title(사건 주제):
    - event_date(사건 발생일):
    - event_person(사건 핵심 인물):
    - event_org(사건 핵심 조직/기관):
    - event_loc(사건 발생 지명):
    - keywords(주요 키워드):
    - p_rice(won/kg)(쌀 가격):
    - p_corn(won/kg)(옥수수 가격):
    - p_usd(won/usd)(달러 가격):
    
    2. 각 카테고리의 조건
    - "summary": 3 문장 이하로 핵심 내용만 발췌.
    - "event_title": 간단한 한 문장으로 사건 주제 작성.
    - "event_date": yyyy-mm-dd 형식, 기사에 "event_date"가 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, '어제', '사흘전', '일주일 전' 등)를 참고하여 "기사 작성일" 기준 계산.
    - "event_person": 사건의 주체 인물(들)의 이름만 입력, 다수의 경우 쉼표로 구분.
    - "event_org": 사건의 주체 조직 및 기관의 이름만 입력, 다수의 경우 쉼표로 구분, **언론사명은 반드시 제외**, **신문사명은 반드시 제외**, **기자가 참고한 출처의 이름도 반드시 제외**, **"노동신문"은 반드시 제외**.
    - "event_loc": [도, 시]단위 지명만을 입력하되 "도" 와 "시" 정보가 함께 있는 경우는 반드시 행적구역별로 분리해서 입력. 건물등에서 일어난 사건의 경우는 해당 장소의 [도, 시] 지명을 입력, 행정구역이 "시"일 경우는 꼭 "시"를 명시 (개성시, 평양시, 고성시 등). 
    특히 "평양" / "평양직할시" / "평양시"와 같이 한 지명에 다양한 표기가 있을경우는 "평양시" ([시 이름] + 시)와 같은 형태로 통일. **"북한" 이라는 단어는 반드시 제외**. 북한이 아닌 해외의 사건의 경우만 국가명을 입력.
    - "keywords": "summary", "event_title", "event_person", "event_org", "event_loc" 모두를 종합적으로 고려하여 해당 뉴스 사건을 대표할 수 있는 **단어 5개 선정**, **"북한" 이라는 단어는 반드시 제외**, 쉼표로 구분하여 입력.
    - p_rice(won/kg): 반드시 **평양의 "쌀 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 쌀 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. 
    - p_corn(won/kg): 반드시 **평양의 "옥수수가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 옥수수 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. 
    - p_usd(won/usd): 반드시 **평양의 "달러 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 달러 환율이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김.
    
    - 위 결과를 종합하여 딕셔너리 형태로 출력.
    - 결과를 출력하기 전 다음 체크리스트를 스스로 검증하라:
        - [ ] 내가 사용한 모든 답과 수치는 기사 원문에 존재한다.
        - [ ] 서로 다른 가격(예: 식용유 vs 쌀 등)을 혼동하지 않았다.
        
    - 설명 출력 금지, 답만 출력.
    """
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
            {"role": "user", "content": prompt},
        ],
        temperature=0
    )
    
    # 소모 토큰량 추출
    input_tokens = response.usage.prompt_tokens
    output_tokens = response.usage.completion_tokens

    # LLM 결과 출력 가져오기
    result_text = response.choices[0].message.content.strip()

    # 문자열을 dict로 변환
    try:
        result = json.loads(result_text)  # json 파싱으로 수정(11.19)
    except:
        print("Parsing error:", result_text)
        return None

    return result, input_tokens, output_tokens

# %%
def get_summary_df(df, cache_file="cache_output.csv", model="gpt-4o-mini"):
    """
    뉴스 요약 파싱 정보를 DataFrame으로 변환

    Args:
        df (pd.DataFrame): 원본 뉴스 데이터프레임. 최소 컬럼 'id', 'title', 'contents', 'publish_date' 포함.
        cache_file (str, optional): 요약 결과를 저장/로드할 캐시 파일명. Defaults to "cache_output.csv".

    Returns:
        pd.DataFrame: 뉴스 요약 및 사건 정보가 포함된 DataFrame. 
                      컬럼:
                        - 'id': 뉴스 ID
                        - 'summary': 주요 사건 요약 (문자열)
                        - 'keywords': 주요 키워드 (리스트)
                        - 'event_title': 사건 제목 (문자열)
                        - 'event_date': 사건 발생일 (yyyy-mm-dd)
                        - 'event_person': 사건 핵심 인물 (리스트)
                        - 'event_org': 사건 핵심 조직/기관 (리스트)
                        - 'event_loc': 사건 발생 지명 (리스트)
                        - 'p_rice(won/kg)': 평양 쌀 가격 (정수)
                        - 'p_corn(won/kg)': 평양 옥수수 가격 (정수)
                        - 'p_usd(won/usd)': 원/달러 환율 (정수)
                        - 'job_cost': 처리 비용 추정 (float)
    
    Example:
        >>> df_summary = get_article_summary(news_df)
        >>> df_summary.head()

    Change Log:
        @@ 11.19
        - 캐싱 기능 추가: 뉴스 id 기반으로 이미 요약된 뉴스는 스킵하도록 수정.
        - 새로운 뉴스가 추가될 경우에만 LLM 호출 수행.
        - 쉼표로 구분된 항목(event_person, event_org, event_loc, keywords)을 리스트 형태로 변환.
        @@ 11.20
        - content 줄바꿈, 공백 문자 공백(' ')으로 처리 (실패, 원하는 결과를 얻지 못함)
        - [id 조회 --> df 필터 -->> 판다스 시리즈로 전달] 방식으로 수정 (정보가 제대로 추출되지 않는듯함.)
            > 해당 방식으로 진행시 아무런 가격 정보가 추출되지 않았다.
        - 다시 원래 content 줄바꿈, 공백 문자 공백(' ')으로 처리 방식으로 돌아옴.
        - "gpt-4.1-nano" 테스트 -> 가격 혼동 문제는 해결
        - 함수에 model 선택 파라미터 추가
    """
    
########## 코드 시작 ####bz######
    # ---------------------------------------------------------------------------------
    # 0. 기본 설정 / 스키마 정의
    # ---------------------------------------------------------------------------------
    new_cols = [
        "summary", "keywords", "event_title", "event_date", "event_person",
        "event_org", "event_loc", "p_rice(won/kg)", "p_corn(won/kg)",
        "p_usd(won/usd)", "job_cost"
    ]

    cache_dir = "data/cached"
    os.makedirs(cache_dir, exist_ok=True)
    cache_file_path = os.path.join(cache_dir, cache_file)

    # 스키마 정의 (dtype 안정화)
    schema = {
        "id": pd.Series(dtype="object"),
        "summary": pd.Series(dtype="object"),
        "keywords": pd.Series(dtype="object"),
        "event_title": pd.Series(dtype="object"),
        "event_date": pd.Series(dtype="object"),
        "event_person": pd.Series(dtype="object"),
        "event_org": pd.Series(dtype="object"),
        "event_loc": pd.Series(dtype="object"),
        "p_rice(won/kg)": pd.Series(dtype="Int64"),
        "p_corn(won/kg)": pd.Series(dtype="Int64"),
        "p_usd(won/usd)": pd.Series(dtype="Int64"),
        "job_cost": pd.Series(dtype="float"),
    }

    # ---------------------------------------------------------------------------------
    # 1. 캐시 로드 or 초기화
    # ---------------------------------------------------------------------------------
    if os.path.exists(cache_file_path):
        print("⏳ 캐시 파일 로드 중...")
        output_df = pd.read_csv(cache_file_path)

        # schema 기준으로 dtype 강제 적용
        for col, series in schema.items():
            if col not in output_df.columns:
                output_df[col] = series  # 없는 컬럼은 빈 Series 생성
            else:
                output_df[col] = output_df[col].astype(series.dtype, errors="ignore")

        print("✔ 캐시 반영 완료!")
    else:
        print("캐시 없음 → 빈 DF 생성")
        output_df = pd.DataFrame(schema)

    # ---------------------------------------------------------------------------------
    # 2. 신규 기사만 처리
    # ---------------------------------------------------------------------------------
    cached_ids = set(output_df["id"].astype(str).tolist())
    new_articles = df[~df["id"].astype(str).isin(cached_ids)]

    print(f"신규 샘플 발견: {len(new_articles)}개")

    # ---------------------------------------------------------------------------------
    # 3. 루프 처리 / row 1개씩 추가 
    # ---------------------------------------------------------------------------------
    for cnt, (i, row) in enumerate(new_articles.iterrows()): 
        article_id = row['id']
        title = row['title']
        contents = row['contents']
        publish_date = row['publish_date']

        print(f"Summarizing [{article_id}] ...")

        # LLM 호출
        result, input_tokens, output_tokens = get_article_summary(title, contents, publish_date, model)

        # 새 row 구성 (None → pd.NA)
        new_data = {
            "id": article_id,
            "summary": result.get("summary"),
            "keywords": value_to_strCSV(result.get("keywords")),
            "event_title": result.get("event_title"),
            "event_date": result.get("event_date"),
            "event_person": value_to_strCSV(result.get("event_person")),
            "event_org": value_to_strCSV(result.get("event_org")),
            "event_loc": value_to_strCSV(result.get("event_loc")),
            "p_rice(won/kg)": pd.NA if result.get("p_rice(won/kg)")==0 or result.get("p_rice(won/kg)") is None else result.get("p_rice(won/kg)"),
            "p_corn(won/kg)": pd.NA if result.get("p_rice(won/kg)")==0 or result.get("p_corn(won/kg)") is None else result.get("p_corn(won/kg)"),
            "p_usd(won/usd)": pd.NA if result.get("p_usd(won/usd)")==0 or result.get("p_usd(won/usd)") is None else result.get("p_usd(won/usd)"),
            "job_cost": (
                input_tokens * 0.15 / 1_000_000 +
                output_tokens * 0.60 / 1_000_000
            ),
        }

        # 컬럼 순서와 dtype 맞춰서 row 추가
        new_data_aligned = {col: new_data.get(col, pd.NA) for col in output_df.columns}
        
        new_row_df = pd.DataFrame([new_data_aligned]).dropna(axis=1, how='all')  # dict → DataFrame 변환, na값이 있는 컬럼 제거
        output_df = pd.concat([output_df, new_row_df], ignore_index=True)

        # 캐시 저장
        output_df.to_csv(cache_file_path, index=False)

        print(f"Job Complete! [{article_id}] ({cnt+1}/{len(new_articles)})")

    print("전체 작업 완료!")
    return output_df

# %%
df = pd.read_csv('data/spnews_final.csv')
input_data = df[df.contents.notnull() & df.category.notnull()]

# %%
len(input_data)
# Out:
# 19141

# %%
# summary_df = get_summary_df(input_data)

# %%
# summary_df.to_csv('data/summary_df_final.csv', index=False)

# %% [markdown]
# ## 테스트 (11.20) - cache 파일 관련 - csv의 리스트를 다시 리스트로 변환하는 로직 삭제 & 캐싱된 뉴스는 요약 과정 스킵

# %%
test_input = input_data.copy()
len(test_input)
# Out:
# 9104

# %%
cache_file_path = 'data/cached/test_cache.csv'

# %%
schema = {
    "id": pd.Series(dtype="object"),
    "summary": pd.Series(dtype="object"),
    "keywords": pd.Series(dtype="object"),
    "event_title": pd.Series(dtype="object"),
    "event_date": pd.Series(dtype="object"),
    "event_person": pd.Series(dtype="object"),
    "event_org": pd.Series(dtype="object"),
    "event_loc": pd.Series(dtype="object"),
    "p_rice(won/kg)": pd.Series(dtype="Int64"),
    "p_corn(won/kg)": pd.Series(dtype="Int64"),
    "p_usd(won/usd)": pd.Series(dtype="Int64"),
    "job_cost": pd.Series(dtype="float"),
}

if os.path.exists(cache_file_path):
    print("⏳ 캐시 파일 로드 중...")
    output_df = pd.read_csv(cache_file_path)

    # schema 기준으로 dtype 강제 적용
    for col, series in schema.items():
        if col not in output_df.columns:
            output_df[col] = series  # 없는 컬럼은 빈 Series 생성
        else:
            output_df[col] = output_df[col].astype(series.dtype, errors="ignore")

    print("✔ 캐시 반영 완료!")
else:
    print("캐시 없음 → 빈 DF 생성")
    output_df = pd.DataFrame(schema)
# Out:
# ⏳ 캐시 파일 로드 중...
# ✔ 캐시 반영 완료!

# %%
len(test_input) - len(output_df)
# Out:
# 2196

# %%
cached_ids = set(output_df["id"].astype(str).tolist())
new_articles = test_input[~test_input["id"].astype(str).isin(cached_ids)]

print(f"신규 샘플 발견: {len(new_articles)}개")
# Out:
# 신규 샘플 발견: 2196개

# %%
common_ids = set(new_articles["id"].astype(str)) & set(map(str, cached_ids))
print(common_ids)
# Out:
# set()

# %%
new_articles
# Out:
#                 id                                      title  \
# 7033  spnews_63891      북한, 지난 4년동안 1,930여개 단위 '사회주의애국림칭호' 수여
# 7034  spnews_63889  北, 김일성 주석 111회 생일 앞두고 경축 분위기 조성...전시회도 시작
# 7035  spnews_63888          왕야쥔 북한 주재 중국대사, 최룡해 상임위원장에 신임장 제출
# 7036  spnews_63872             북한 각지, 올해 알곡생산목표 달성...'과학영농'독려
# 7037  spnews_63867                       북한, 관개공사 대상설비·부속품 증산
# ...            ...                                        ...
# 9271  spnews_53206          北 외무성, "'림팩' 합동군사연습...패권주의 정책" 비난
# 9272  spnews_53205                북한 경공업연구원 방직연구소, 화학보조약제 국산화
# 9273  spnews_53204                        북한 각지 농촌, 논밭 김매기 한창
# 9274  spnews_53201        北 경공업부분, 김정은 질책 후 연일 "소비품 개선 노력" 선전
# 9275  spnews_53198   북한, 코로나19 신규 발열자  2만 9,910여명...2만명대로 떨어져
#
#                                                contents  source section  \
# 7033  북한에서 지난 4년동안 1,930여 개 단위가 '사회주의애국림칭호'를 수여받았다고 ...  spnews     북한N
# 7034  북한이 김일성 주석 111회 생일(태양절, 4.15)를 앞두고 경축 분위기를 조성하...  spnews     북한N
# 7035  왕야쥔 북한 주재 중국대사가 최룡해 최고인민회의 상임위원장에게 신임장을 정식으로 제...  spnews     북한N
# 7036  북한 각지에서 올해 알곡생산목표수행을 위한 투쟁을 벌이고 있다고 북한 매체가 보도했...  spnews     북한N
# 7037  북한이 관개공사에 필요한 대상설비생산을 맡은 여러 공장에서 생산 실적을 높이고 있다...  spnews     북한N
# ...                                                 ...     ...     ...
# 9271  북한 외무성은 15일 미국이 주도하는 안보동맹을 비난하고 나섰다.\n북한은 이날 외...  spnews     북한N
# 9272  북한 경공업연구원 방직연구소에서 최근 방직공업에서 쓰이는 여러가지 화학보조약제를 국...  spnews     북한N
# 9273  북한 각지 농촌에서 논밭 김매기를 본격적으로 실시하고 있다고 노동신문이 15일 보도...  spnews     북한N
# 9274  북한 김정은 총비서가 당 전원회의에서 인민소비품에 대해 질책한 이후 북한 매체들은 ...  spnews     북한N
# 9275  북한에서 코로나19 신규 발열자가 전국에서 2만 9,910여명이 발생해 2만명 대로...  spnews     북한N
#
#        author publish_date                                                url  \
# 7033  안윤석 대기자   2023-04-07  https://www.spnews.co.kr/news/articleView.html...
# 7034  안윤석 대기자   2023-04-07  https://www.spnews.co.kr/news/articleView.html...
# 7035  안윤석 대기자   2023-04-07  https://www.spnews.co.kr/news/articleView.html...
# 7036  안윤석 대기자   2023-04-06  https://www.spnews.co.kr/news/articleView.html...
# 7037  안윤석 대기자   2023-04-06  https://www.spnews.co.kr/news/articleView.html...
# ...       ...          ...                                                ...
# 9271  안윤석 대기자   2022-06-15  https://www.spnews.co.kr/news/articleView.html...
# 9272  안윤석 대기자   2022-06-15  https://www.spnews.co.kr/news/articleView.html...
# 9273  안윤석 대기자   2022-06-15  https://www.spnews.co.kr/news/articleView.html...
# 9274  안윤석 대기자   2022-06-15  https://www.spnews.co.kr/news/articleView.html...
# 9275  안윤석 대기자   2022-06-15  https://www.spnews.co.kr/news/articleView.html...
#
#       category
# 7033  사회/문화/체육
# 7034        정치
# 7035        정치
# 7036     경제/산업
# 7037     경제/산업
# ...        ...
# 9271        외교
# 9272  사회/문화/체육
# 9273     경제/산업
# 9274     경제/산업
# 9275  사회/문화/체육
#
# [2196 rows x 9 columns]

# %%
for cnt, (i, row) in enumerate(new_articles.iterrows()): 
    article_id = row['id']
    title = row['title']
    contents = row['contents']
    publish_date = row['publish_date']
    
    print(f"Summarizing [{article_id}] ...")
    
    # LLM 호출
    result, input_tokens, output_tokens = get_article_summary(title, contents, publish_date, model)
    
    # 새 row 구성 (None → pd.NA)
    new_data = {
        "id": article_id,
        "summary": result.get("summary"),
        "keywords": normalize_to_strCSV(result.get("keywords")),
        "event_title": result.get("event_title"),
        "event_date": result.get("event_date"),
        "event_person": normalize_to_strCSV(result.get("event_person")),
        "event_org": normalize_to_strCSV(result.get("event_org")),
        "event_loc": normalize_to_strCSV(result.get("event_loc")),
        "p_rice(won/kg)": pd.NA if result.get("p_rice(won/kg)")==0 or result.get("p_rice(won/kg)") is None else result.get("p_rice(won/kg)"),
        "p_corn(won/kg)": pd.NA if result.get("p_rice(won/kg)")==0 or result.get("p_corn(won/kg)") is None else result.get("p_corn(won/kg)"),
        "p_usd(won/usd)": pd.NA if result.get("p_usd(won/usd)")==0 or result.get("p_usd(won/usd)") is None else result.get("p_usd(won/usd)"),
        "job_cost": (
            input_tokens * 0.15 / 1_000_000 +
            output_tokens * 0.60 / 1_000_000
        ),
    }
    
    # 컬럼 순서와 dtype 맞춰서 row 추가
    new_data_aligned = {col: new_data.get(col, pd.NA) for col in output_df.columns}
    
    new_row_df = pd.DataFrame([new_data_aligned]).dropna(axis=1, how='all')  # dict → DataFrame 변환, na값이 있는 컬럼 제거
    output_df = pd.concat([output_df, new_row_df], ignore_index=True)
    
    # 캐시 저장
    output_df.to_csv(cache_file_path, index=False)
    
    print(f"Job Complete! [{article_id}] ({cnt+1}/{len(new_articles)})")

# %% [markdown]
# ## ISSUE (11.20) - 가격 추출 관련 ISSUE 탐구 (해결 실패)

# %%
def promt_tester(title, contents, publish_date):
    """
    뉴스 기사를 LLM으로 요약하고 항목별 데이터 반환
    
    Change Log:
        @@ 11.18 
        > 프롬프트 수정
            - 키값 정리 형식 재 설정 - 데이터 프레임의 컬럼명이 키값이 되도록 수정
            - 추가적인 컬럼 event_person 추가
            - event_obj 컬럼명 event_org로 변경
        @@ 11.19
        > 프롬프트 수정
            - 인물명은 이름만 명확하게
            - 지역명은 [국가, 도, 시] 단위로 명확하게
            - 평양 쌀, 옥수수, 달러환율 정보는 각기 별개의 데이터로 저장
            - 키워드는 인물명, 지역명을 반드시 포함 + 요약내용 대표 단어 추가
        > result 파싱 방식 수정
            - eval()에서 jason.load()로 변경
    """
    
    prompt = f"""
    아래 기사를 분석하여 요구된 정보를 작성하시오.

    # 기사 제목:
    {title}

    # 기사 내용:
    {contents}

    # 기사 작성일:
    {publish_date}

   1. 아래 형식으로 정리 (괄호안 각 key값의 한글 설명은 참고만 하고 최종 결과에는 포함하지 않음)
    - summary(주요 사건 요약):
    - event_title(사건 주제):
    - event_date(사건 발생일):
    - event_person(사건 핵심 인물):
    - event_org(사건 핵심 조직/기관):
    - event_loc(사건 발생 지명):
    - keywords(뉴스 주요 키워드):
    - p_rice(won/kg)(쌀 가격):
    - p_corn(won/kg)(옥수수 가격):
    - p_usd(won/usd)(달러 가격):
    
    2. 각 카테고리의 조건
    - "summary": 3 문장 이하로 핵심 내용만 발췌.
    - "event_title": 간단한 한 문장으로 사건 주제 작성.
    - "event_date": yyyy-mm-dd 형식, 기사에 "event_date"가 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, '어제', '사흘전', '일주일 전' 등)를 참고하여 "기사 작성일" 기준 계산.
    - "event_person": 사건의 주체 인물(들)의 이름만 입력, 다수의 경우 쉼표로 구분.
    - "event_org": 사건의 주체 조직 및 기관의 이름만 입력, 다수의 경우 쉼표로 구분, **언론사명은 반드시 제외**, **신문사명은 반드시 제외**, **기자가 참고한 출처의 이름도 반드시 제외**, **"노동신문"은 반드시 제외**.
    - "event_loc": [도, 시]단위 지명만을 입력하되 "도" 와 "시" 정보가 함께 있는 경우는 반드시 행적구역별로 분리해서 입력. 건물등에서 일어난 사건의 경우는 해당 장소의 [도, 시] 지명을 입력, 행정구역이 "시"일 경우는 꼭 "시"를 명시 (개성시, 평양시, 고성시 등). 
    특히 "평양" / "평양직할시" / "평양시"와 같이 한 지명에 다양한 표기가 있을경우는 "평양시" ([시 이름] + 시)와 같은 형태로 통일. **"북한" 이라는 단어는 반드시 제외**. 북한이 아닌 해외의 사건의 경우만 국가명을 입력.
    - "keywords": "summary", "event_title", "event_person", "event_org", "event_loc" 모두를 종합적으로 고려하여 해당 뉴스 사건을 대표할 수 있는 **단어 5개 선정**, **"북한" 이라는 단어는 반드시 제외**, 쉼표로 구분하여 입력.
    - p_rice(won/kg): 반드시 **평양의 "쌀 1kg 가격"**이 정확하게 명시되어있는 경우만 추출, **정수**로 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 물가 정보임을 100% 단언 할 수 없는 경우 **절대로 지어내지 말고** 빈칸으로 남김. 
    - p_corn(won/kg): 반드시 **평양의 "옥수수 1kg 가격"**이 정확하게 명시되어있는 경우만 추출, **정수**로 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 물가 정보임을 100% 단언 할 수 없는 경우 **절대로 지어내지 말고** 빈칸으로 남김. 
    - p_usd(won/usd): 반드시 **평양의 "1 달러 가격"**이 정확하게 명시되어있는 경우만 추출, **정수**로 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 물가 정보임을 100% 단언 할  수  없는 경우 **절대로 지어내지 말고** 빈칸으로 남김.
    - 위 결과를 종합하여 딕셔너리 형태로 출력.
    - 설명 금지, 답만 출력.
    """
    messages=[
            {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
            {"role": "user", "content": prompt},
        ]

    print("📌 Sent Prompt:\n", messages)

# %%
test_data = pd.read_csv('data/spnews_ver2.csv')
test_id = pd.read_csv('data/price_notna.csv')['id'].values
test_data = test_data[test_data['id'].isin(list(test_id))]
test_data.shape
# Out:
# (107, 9)

# %%
test_data.head()
# Out:
#                 id                                      title  \
# 3    spnews_101394                   [北 물가] 가을 추수 영향, 곡물가 내림세
# 49   spnews_101188         北, 벼 결산 분배 시작...수매 계획 달성 못하면 분배 삭감
# 59   spnews_101146  [北 물가] 쌀·배추 값 오름세, 대부분 물가 내림세...달러화 하락 원인
# 207  spnews_100377            [北 물가] 달러화 하락·추수철 맞아 곡물류 가격 내림세
# 318   spnews_99985           [北 물가] 달러화 하락·가을 추수기, 곡물류 가격 내림세
#
#                                               contents  source section  \
# 3    북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...  spnews     북한N
# 49   북한이 벼 탈곡이 마무리된 지역에서 결산분배를 진행하고 있다.\n노동신문은 11일 ...  spnews     북한N
# 59   북한에서 쌀값과 배춧값이 오르고 나머지 대부분 물가는 내림세를 보였다.\n'SPN'...  spnews     북한N
# 207  북한 장마당에서 달러화 하락과 가을 수확철을 맞아 곡물류 가격이 계속 내리고 있다....  spnews     북한N
# 318  북한 지역에서 달러화 하락과 가을 추수기에 들면서 곡물류 가격이 내림세를 보이고 있...  spnews     북한N
#
#       author publish_date                                                url  \
# 3    안윤석 대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
# 49   안윤석 대기자   2025-11-11  https://www.spnews.co.kr/news/articleView.html...
# 59   안윤석 대기자   2025-11-10  https://www.spnews.co.kr/news/articleView.html...
# 207  안윤석 대기자   2025-10-20  https://www.spnews.co.kr/news/articleView.html...
# 318  안윤석 대기자   2025-10-07  https://www.spnews.co.kr/news/articleView.html...
#
#     category
# 3      경제/산업
# 49     경제/산업
# 59     경제/산업
# 207    경제/산업
# 318    경제/산업

# %%
price_test_1 = get_summary_df(test_data, 'price_test_cache_gpt-4o-mini.csv')
# Out:
# 캐시 없음 → 빈 DF 생성
# 신규 샘플 발견: 107개
# Summarizing [spnews_101394] ...
# ERROR! Session/line number was not unique in database. History logging moved to new session 506
# Job Complete! [spnews_101394] (1/107)
# Summarizing [spnews_101188] ...
# Job Complete! [spnews_101188] (2/107)
# Summarizing [spnews_101146] ...
# Job Complete! [spnews_101146] (3/107)
# Summarizing [spnews_100377] ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 price_test_1 = get_summary_df(test_data, 'price_test_cache_gpt-4o-mini.csv')
#
# Cell In[208], line 120, in get_summary_df(df, cache_file, model)
#     117 print(f"Summarizing [{article_id}] ...")
#     119 # LLM 호출
# --> 120 result, input_tokens, output_tokens = get_article_summary(title, contents, publish_date, model)
#     122 # 새 row 구성 (None → pd.NA)
#     123 new_data = {
#     124     "id": article_id,
#     125     "summary": result.get("summary"),
#    (...)    138     ),
#     139 }
#
# Cell In[207], line 67, in get_article_summary(title, contents, publish_date, model)
#       3 """
#       4 뉴스 기사를 LLM으로 요약하고 항목별 데이터 반환
#       5
#    (...)     19         - eval()에서 jason.load()로 변경
#      20 """
#      22 prompt = f"""
#      23 아래 기사를 분석하여 요구된 정보를 작성하시오.
#      24
#    (...)     65 - 설명 출력 금지, 답만 출력.
#      66 """
# ---> 67 response = client.chat.completions.create(
#      68     model=model,
#      69     messages=[
#      70         {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
#      71         {"role": "user", "content": prompt},
#      72     ],
#      73     temperature=0
#      74 )
#      76 # 소모 토큰량 추출
#      77 input_tokens = response.usage.prompt_tokens
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\miniconda3\envs\myenv\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~\miniconda3\envs\myenv\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
price_test_2 = get_summary_df(test_data, 'price_test_cache_gpt-41-nano.csv', model='gpt-4.1-nano')
# Out:
# 캐시 없음 → 빈 DF 생성
# 신규 샘플 발견: 107개
# Summarizing [spnews_101394] ...
# Job Complete! [spnews_101394] (1/107)
# Summarizing [spnews_101188] ...
# Job Complete! [spnews_101188] (2/107)
# Summarizing [spnews_101146] ...
# Job Complete! [spnews_101146] (3/107)
# Summarizing [spnews_100377] ...
# Job Complete! [spnews_100377] (4/107)
# Summarizing [spnews_99985] ...
# Job Complete! [spnews_99985] (5/107)
# Summarizing [spnews_99492] ...
# Job Complete! [spnews_99492] (6/107)
# Summarizing [spnews_99061] ...
# Job Complete! [spnews_99061] (7/107)
# Summarizing [spnews_98357] ...
# Job Complete! [spnews_98357] (8/107)
# Summarizing [spnews_97937] ...
# Job Complete! [spnews_97937] (9/107)
# Summarizing [spnews_97892] ...
# Job Complete! [spnews_97892] (10/107)
# Summarizing [spnews_97434] ...
# Job Complete! [spnews_97434] (11/107)
# Summarizing [spnews_97217] ...
# Job Complete! [spnews_97217] (12/107)
# Summarizing [spnews_96394] ...
# Job Complete! [spnews_96394] (13/107)
# Summarizing [spnews_96054] ...
# Job Complete! [spnews_96054] (14/107)
# Summarizing [spnews_95392] ...
# Job Complete! [spnews_95392] (15/107)
# Summarizing [spnews_95033] ...
# Job Complete! [spnews_95033] (16/107)
# Summarizing [spnews_94993] ...
# Job Complete! [spnews_94993] (17/107)
# Summarizing [spnews_94524] ...
# Job Complete! [spnews_94524] (18/107)
# Summarizing [spnews_92926] ...
# Job Complete! [spnews_92926] (19/107)
# Summarizing [spnews_92810] ...
# Job Complete! [spnews_92810] (20/107)
# Summarizing [spnews_92436] ...
# Job Complete! [spnews_92436] (21/107)
# Summarizing [spnews_92278] ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 price_test_2 = get_summary_df(test_data, 'price_test_cache_gpt-41-nano.csv', model='gpt-4.1-nano')
#
# Cell In[208], line 120, in get_summary_df(df, cache_file, model)
#     117 print(f"Summarizing [{article_id}] ...")
#     119 # LLM 호출
# --> 120 result, input_tokens, output_tokens = get_article_summary(title, contents, publish_date, model)
#     122 # 새 row 구성 (None → pd.NA)
#     123 new_data = {
#     124     "id": article_id,
#     125     "summary": result.get("summary"),
#    (...)    138     ),
#     139 }
#
# Cell In[207], line 67, in get_article_summary(title, contents, publish_date, model)
#       3 """
#       4 뉴스 기사를 LLM으로 요약하고 항목별 데이터 반환
#       5
#    (...)     19         - eval()에서 jason.load()로 변경
#      20 """
#      22 prompt = f"""
#      23 아래 기사를 분석하여 요구된 정보를 작성하시오.
#      24
#    (...)     65 - 설명 출력 금지, 답만 출력.
#      66 """
# ---> 67 response = client.chat.completions.create(
#      68     model=model,
#      69     messages=[
#      70         {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
#      71         {"role": "user", "content": prompt},
#      72     ],
#      73     temperature=0
#      74 )
#      76 # 소모 토큰량 추출
#      77 input_tokens = response.usage.prompt_tokens
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\miniconda3\envs\myenv\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~\miniconda3\envs\myenv\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py:3381, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3377 exec_count = self.execution_count
#    3378 if result.error_in_exec:
#    3379     # Store formatted traceback and error details
#    3380     self.history_manager.exceptions[exec_count] = (
# -> 3381         self._format_exception_for_storage(result.error_in_exec)
#    3382     )
#    3384 # Each cell is a *single* input, regardless of how many lines it has
#    3385 self.execution_count += 1
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py:3435, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3432         stb = evalue._render_traceback_()
#    3433     else:
#    3434         # Otherwise, use InteractiveTB to format the traceback.
# -> 3435         stb = self.InteractiveTB.structured_traceback(
#    3436             etype, evalue, tb, tb_offset=1
#    3437         )
#    3438 except Exception:
#    3439     # In case formatting fails, fallback to Python's built-in formatting.
#    3440     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\IPython\core\tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\stack_data\core.py:360, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     358 if pygmented and self.frame_info.scope:
#     359     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 360     start_line, lines = self.frame_info._pygmented_scope_lines
#     361     result = lines[self.lineno - start_line]
#     362     if strip_leading_indent:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\stack_data\core.py:780, in FrameInfo._pygmented_scope_lines(self)
#     777     ranges = []
#     779 code = atok.get_text(scope)
# --> 780 lines = _pygmented_with_ranges(formatter, code, ranges)
#     782 start_line = line_range(scope)[0]
#     784 return start_line, lines
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\stack_data\utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 return pygments.highlight(code, lexer, formatter).splitlines()
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\regexopt.py:72, in regex_opt_inner(strings, open_paren)
#      69     slen = len(suffix)
#      70     # print '-> suffix:', suffix[::-1]
#      71     return open_paren \
# ---> 72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
#      77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\pygments\regexopt.py:67, in regex_opt_inner(strings, open_paren)
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
# ---> 67 suffix = commonprefix(strings_rev)
#      68 if suffix:
#      69     slen = len(suffix)
#
# File ~\miniconda3\envs\myenv\Lib\genericpath.py:115, in commonprefix(m)
#     113     m = tuple(map(os.fspath, m))
#     114 s1 = min(m)
# --> 115 s2 = max(m)
#     116 for i, c in enumerate(s1):
#     117     if c != s2[i]:
#
# KeyboardInterrupt:

# %%
price_test_1.to_excel('data/price_test_gpt4omini.xlsx', index=False)
price_test_2.to_excel('data/price_test_gpt41nano.xlsx', index=False)

# %%
test_data_2 = test_data[test_data.id.str.contains('72819') | test_data.id.str.contains('73221') | test_data.id.str.contains('77811') | test_data.id.str.contains('78363') | test_data.id.str.contains('66651')]
test_data_2
# Out:
#                 id                                     title  \
# 4006  spnews_78363  북 "소금공업국, 1.4분기 소금생산계획 초과 달성"..소금 부족난 겪어
# 4129  spnews_77811       북, 지방공업공장 건설 계기...해바라기 등 기름작물 재배 독려
# 5109  spnews_73221         [北 물가] 곡물류·기초식품 가격 내림세...물가 점차 안정
# 5199  spnews_72819     북 사리원기초식품공장, 개건현대화공사 완공...기초식품 부족난 계속
# 6490  spnews_66651            북한 국경지역 밀수 서서히 증가 움직임...환율도 올라
#
#                                                contents  source section  \
# 4006  북한 소금공업국에서 1.4분기 소금생산계획을 초과 달성했다고 노동신문이 29일 보도...  spnews     북한N
# 4129  북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물...  spnews     북한N
# 5109  북한에서 가을 추수가 끝나고 수입 물량이 늘면서 곡물류와 기초식품 등의 물가가 내림...  spnews     북한N
# 5199  북한 황해북도 사리원기초식품공장 개건현대화(리모델링)공사가 완공돼 9일 준공식을 가...  spnews     북한N
# 6490  북한지역에서 최근 봄철 춘궁기와 국경봉쇄 장기화로 식량과 식품류 부족 현상이 계속되...  spnews     북한N
#
#        author publish_date                                                url  \
# 4006  안윤석 대기자   2024-03-29  https://www.spnews.co.kr/news/articleView.html...
# 4129  안윤석 대기자   2024-03-15  https://www.spnews.co.kr/news/articleView.html...
# 5109  안윤석 대기자   2023-11-20  https://www.spnews.co.kr/news/articleView.html...
# 5199  안윤석 대기자   2023-11-10  https://www.spnews.co.kr/news/articleView.html...
# 6490  안윤석 대기자   2023-06-11  https://www.spnews.co.kr/news/articleView.html...
#
#       category
# 4006     경제/산업
# 4129     경제/산업
# 5109     경제/산업
# 5199     경제/산업
# 6490  사회/문화/체육

# %%
get_summary_df(test_data_2, 'price_test_cache_10.csv')
# Out:
# 캐시 없음 → 빈 DF 생성
# 신규 샘플 발견: 5개
# Summarizing [spnews_78363] ...
# Job Complete! [spnews_78363] (1/5)
# Summarizing [spnews_77811] ...
# Job Complete! [spnews_77811] (2/5)
# Summarizing [spnews_73221] ...
# Job Complete! [spnews_73221] (3/5)
# Summarizing [spnews_72819] ...
# Job Complete! [spnews_72819] (4/5)
# Summarizing [spnews_66651] ...
# Job Complete! [spnews_66651] (5/5)
# 전체 작업 완료!
#                                              id  \
# 0  4006    spnews_78363
# Name: id, dtype: object
# 1  4129    spnews_77811
# Name: id, dtype: object
# 2  5109    spnews_73221
# Name: id, dtype: object
# 3  5199    spnews_72819
# Name: id, dtype: object
# 4  6490    spnews_66651
# Name: id, dtype: object
#
#                                              summary  \
# 0  북한 소금공업국이 1.4분기 소금생산계획을 초과 달성했다. 그러나 소금 부족난이 발...
# 1  북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물...
# 2  북한에서 가을 추수가 끝나고 수입 물량이 늘면서 곡물류와 기초식품 등의 물가가 내림...
# 3  북한 황해북도 사리원기초식품공장 개건현대화공사가 완공됐다. 준공식은 9일에 진행되었...
# 4  북한 국경지역에서 밀수가 서서히 증가하고 있으며, 이는 봄철 춘궁기와 국경봉쇄 장기...
#
#                      keywords               event_title  event_date  \
# 0     소금, 생산계획, 초과달성, 부족난, 북한       소금공업국, 소금생산계획 초과 달성  2024-03-29
# 1  식용유, 기름작물, 재배, 지방공업공장, 부족난  지방공업공장 건설 계기로 기름작물 재배 독려  2024-03-15
# 2        물가, 곡물, 기초식품, 안정, 수입                 북한 물가 안정세  2023-11-20
# 3   사리원, 기초식품, 공장, 개건현대화, 부족난      사리원기초식품공장 개건현대화공사 완공  2023-11-09
# 4          밀수, 국경, 식량, 환율, 부족     북한 국경지역 밀수 증가 및 환율 상승  2023-06-11
#
#   event_person event_org   event_loc p_rice(won/kg) p_corn(won/kg)  \
# 0                  소금공업국                        NaN            NaN
# 1
# 2
# 3                         황해북도, 사리원시            NaN            NaN
# 4
#
#   p_usd(won/usd)  job_cost
# 0            NaN  0.000264
# 1                 0.000270
# 2                 0.000259
# 3            NaN  0.000269
# 4                 0.000261

# %% [markdown]
# ### 계속해서 잘못된 가격이 출력되는 아이템 개별적으로 테스트

# %%
test_item = test_data[test_data.id == 'spnews_77811']

# %%
type(test_item)
# Out:
# pandas.core.frame.DataFrame

# %%
article_id = test_item['id']
title = test_item['title']
contents = test_item["contents"]
publish_date = test_item["publish_date"]

type(contents)
# Out:
# pandas.core.series.Series

# %%
title
# Out:
# 4129    북, 지방공업공장 건설 계기...해바라기 등 기름작물 재배 독려
# Name: title, dtype: object

# %%
promt_tester(title, contents, publish_date)
# Out:
# 📌 Sent Prompt:
#  [{'role': 'system', 'content': '당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다.'}, {'role': 'user', 'content': '\n    아래 기사를 분석하여 요구된 정보를 작성하시오.\n\n    # 기사 제목:\n    4129    북, 지방공업공장 건설 계기...해바라기 등 기름작물 재배 독려\nName: title, dtype: object\n\n    # 기사 내용:\n    4129    북한 주민들이 식용유 부족난을 겪고 있는 가운데\xa0지방공업공장 건설을 계기로\xa0기름작물...\nName: contents, dtype: object\n\n    # 기사 작성일:\n    4129    2024-03-15\nName: publish_date, dtype: object\n\n   1. 아래 형식으로 정리 (괄호안 각 key값의 한글 설명은 참고만 하고 최종 결과에는 포함하지 않음)\n    - summary(주요 사건 요약):\n    - event_title(사건 주제):\n    - event_date(사건 발생일):\n    - event_person(사건 핵심 인물):\n    - event_org(사건 핵심 조직/기관):\n    - event_loc(사건 발생 지명):\n    - keywords(주요 키워드):\n    - p_rice(won/kg)(쌀 가격):\n    - p_corn(won/kg)(옥수수 가격):\n    - p_usd(won/usd)(달러 가격):\n\n    2. 각 카테고리의 조건\n    - "summary": 3 문장 이하로 핵심 내용만 발췌.\n    - "event_title": 간단한 한 문장으로 사건 주제 작성.\n    - "event_date": yyyy-mm-dd 형식, 기사에 "event_date"가 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, \'어제\', \'사흘전\', \'일주일 전\' 등)를 참고하여 "기사 작성일" 기준 계산.\n    - "event_person": 사건의 주체 인물(들)의 이름만 입력, 다수의 경우 쉼표로 구분.\n    - "event_org": 사건의 주체 조직 및 기관의 이름만 입력, 다수의 경우 쉼표로 구분, **언론사명은 반드시 제외**, **신문사명은 반드시 제외**, **기자가 참고한 출처의 이름도 반드시 제외**, **"노동신문"은 반드시 제외**.\n    - "event_loc": [도, 시]단위 지명만을 입력하되 "도" 와 "시" 정보가 함께 있는 경우는 반드시 행적구역별로 분리해서 입력. 건물등에서 일어난 사건의 경우는 해당 장소의 [도, 시] 지명을 입력, 행정구역이 "시"일 경우는 꼭 "시"를 명시 (개성시, 평양시, 고성시 등). \n    특히 "평양" / "평양직할시" / "평양시"와 같이 한 지명에 다양한 표기가 있을경우는 "평양시" ([시 이름] + 시)와 같은 형태로 통일. **"북한" 이라는 단어는 반드시 제외**. 북한이 아닌 해외의 사건의 경우만 국가명을 입력.\n    - "keywords": "summary", "event_title", "event_person", "event_org", "event_loc" 모두를 종합적으로 고려하여 해당 뉴스 사건을 대표할 수 있는 **단어 5개 선정**, **"북한" 이라는 단어는 반드시 제외**, 쉼표로 구분하여 입력.\n    - p_rice(won/kg): 반드시 **평양의 "쌀 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 쌀 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. \n    - p_corn(won/kg): 반드시 **평양의 "옥수수가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 옥수수 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. \n    - p_usd(won/usd): 반드시 **평양의 "달러 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 달러 환율이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김.\n\n    - 위 결과를 종합하여 딕셔너리 형태로 출력.\n    - 결과를 출력하기 전 다음 체크리스트를 스스로 검증하라:\n        - [ ] 내가 사용한 모든 답과 수치는 기사 원문에 존재한다.\n        - [ ] 서로 다른 가격(예: 식용유 vs 쌀 등)을 혼동하지 않았다.\n        - [ ] 원문의 수치는 \n\n    - 설명 출력 금지, 답만 출력.\n    '}]

# %%
get_article_summary(title, contents, publish_date)
# Out:
# ({'summary': '북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물 재배가 독려되고 있다. 해바라기 등 기름작물이 주요 재배 품목으로 언급되었다. 이는 식량 자급자족을 위한 노력의 일환으로 보인다.',
#   'event_title': '지방공업공장 건설 계기로 기름작물 재배 독려',
#   'event_date': '2024-03-15',
#   'event_person': '',
#   'event_org': '',
#   'event_loc': '',
#   'keywords': '식용유, 기름작물, 해바라기, 지방공업공장, 재배',
#   'p_rice(won/kg)': '',
#   'p_corn(won/kg)': '',
#   'p_usd(won/usd)': ''},
#  1180,
#  196)

# %%
contents
# Out:
# 4129    북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물...
# Name: contents, dtype: object

# %%
for i, row in test_item.iterrows():
    title = row.title
    contents = re.sub(r'[\xa0\n]+', ' ', row.contents)
    publish_date = row.publish_date
    
    promt_tester(title, contents, publish_date)
# Out:
# 📌 Sent Prompt:
#  [{'role': 'system', 'content': '당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다.'}, {'role': 'user', 'content': '\n    아래 기사를 분석하여 요구된 정보를 작성하시오.\n\n    # 기사 제목:\n    북, 지방공업공장 건설 계기...해바라기 등 기름작물 재배 독려\n\n    # 기사 내용:\n    북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물을 전군중적 운동으로 재배하자고 독려했다. 노동신문은 15일 "\'지방발전 20×10 정책\' 실현과 관련해 원료기지를 조성하는데 기름작물을 많이 심는 것이 갖는 의의는 매우 크다"며 이같이 보도했다. 이어 "당의 지방공업발전 정책실행을 위해 원료기지조성을 통이 크게 하여야 할 오늘 기름작물도 마땅히 더 많이 심어야 한다"며 "지금 도, 시, 군에서 이 사업이 활발히 벌어지고 있다"고 전했다. 그러면서 "책임일꾼(간부)들이 직접 틀어쥐고 수유나무림을 조성하고 피마주(아주까리), 역삼, 해바라기와 같은 기름작물을 대대적으로 심기 위한 작전과 지휘를 박력있게 하고있다"고 소개했다. 신문은 "20개 시, 군에서 지방공업공장 건설 착공식이 연이어 진행되고 있는 가운데 여러가지 원료와 함께 기름생산 원료 보장 준비도 단단히 하고 완강하게 해 나갈 것을 요구하고 있다"고 분발을 촉구했다. 북한에서는 자체적으로 생산되는 식용유가 부족해 해마다 중국 등지에서 대량으로 수입하고 있다. 이달 1일 기준 북한 장마당에서 거래되는 식용유(1kg) 가격은 11,000원 선으로 같은 양의 쌀값(5000원)의 두 배다.\n\n    # 기사 작성일:\n    2024-03-15\n\n   1. 아래 형식으로 정리 (괄호안 각 key값의 한글 설명은 참고만 하고 최종 결과에는 포함하지 않음)\n    - summary(주요 사건 요약):\n    - event_title(사건 주제):\n    - event_date(사건 발생일):\n    - event_person(사건 핵심 인물):\n    - event_org(사건 핵심 조직/기관):\n    - event_loc(사건 발생 지명):\n    - keywords(주요 키워드):\n    - p_rice(won/kg)(쌀 가격):\n    - p_corn(won/kg)(옥수수 가격):\n    - p_usd(won/usd)(달러 가격):\n\n    2. 각 카테고리의 조건\n    - "summary": 3 문장 이하로 핵심 내용만 발췌.\n    - "event_title": 간단한 한 문장으로 사건 주제 작성.\n    - "event_date": yyyy-mm-dd 형식, 기사에 "event_date"가 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, \'어제\', \'사흘전\', \'일주일 전\' 등)를 참고하여 "기사 작성일" 기준 계산.\n    - "event_person": 사건의 주체 인물(들)의 이름만 입력, 다수의 경우 쉼표로 구분.\n    - "event_org": 사건의 주체 조직 및 기관의 이름만 입력, 다수의 경우 쉼표로 구분, **언론사명은 반드시 제외**, **신문사명은 반드시 제외**, **기자가 참고한 출처의 이름도 반드시 제외**, **"노동신문"은 반드시 제외**.\n    - "event_loc": [도, 시]단위 지명만을 입력하되 "도" 와 "시" 정보가 함께 있는 경우는 반드시 행적구역별로 분리해서 입력. 건물등에서 일어난 사건의 경우는 해당 장소의 [도, 시] 지명을 입력, 행정구역이 "시"일 경우는 꼭 "시"를 명시 (개성시, 평양시, 고성시 등). \n    특히 "평양" / "평양직할시" / "평양시"와 같이 한 지명에 다양한 표기가 있을경우는 "평양시" ([시 이름] + 시)와 같은 형태로 통일. **"북한" 이라는 단어는 반드시 제외**. 북한이 아닌 해외의 사건의 경우만 국가명을 입력.\n    - "keywords": "summary", "event_title", "event_person", "event_org", "event_loc" 모두를 종합적으로 고려하여 해당 뉴스 사건을 대표할 수 있는 **단어 5개 선정**, **"북한" 이라는 단어는 반드시 제외**, 쉼표로 구분하여 입력.\n    - p_rice(won/kg): 반드시 **평양의 "쌀 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 쌀 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. \n    - p_corn(won/kg): 반드시 **평양의 "옥수수가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 옥수수 가격이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김. \n    - p_usd(won/usd): 반드시 **평양의 "달러 가격"**이 확실하게 명시되어있는 경우만 추출, **숫자만** 입력. "평양"의 물가 정보만을 추출하기 위함. "평양"의 달러 환율이라는 근거가 100% 명확하지 않은 경우 **절대로 지어내지 말고 빈칸**으로 남김.\n\n    - 위 결과를 종합하여 딕셔너리 형태로 출력.\n    - 결과를 출력하기 전 다음 체크리스트를 스스로 검증하라:\n        - [ ] 내가 사용한 모든 답과 수치는 기사 원문에 존재한다.\n        - [ ] 서로 다른 가격(예: 식용유 vs 쌀 등)을 혼동하지 않았다.\n        - [ ] 원문의 수치는 \n\n    - 설명 출력 금지, 답만 출력.\n    '}]

# %%
contents
# Out:
# '북한 주민들이 식용유 부족난을 겪고 있는 가운데\xa0지방공업공장 건설을 계기로\xa0기름작물을\xa0전군중적 운동으로\xa0재배하자고 독려했다.\n노동신문은 15일 "\'지방발전 20×10\xa0정책\' 실현과 관련해 원료기지를 조성하는데\xa0기름작물을 많이 심는 것이 갖는 의의는 매우 크다"며 이같이 보도했다.\n이어 "당의 지방공업발전 정책실행을 위해 원료기지조성을 통이 크게 하여야 할 오늘 기름작물도 마땅히 더 많이 심어야 한다"며 "지금 도, 시, 군에서 이 사업이 활발히 벌어지고 있다"고 전했다.\n그러면서 "책임일꾼(간부)들이 직접 틀어쥐고 수유나무림을 조성하고 피마주(아주까리), 역삼, 해바라기와 같은 기름작물을 대대적으로 심기 위한 작전과 지휘를 박력있게 하고있다"고 소개했다.\n신문은 "20개 시, 군에서 지방공업공장 건설 착공식이 연이어 진행되고 있는 가운데 여러가지 원료와 함께 기름생산 원료 보장 준비도 단단히 하고 완강하게 해 나갈 것을 요구하고 있다"고 분발을 촉구했다.\n북한에서는 자체적으로 생산되는 식용유가 부족해 해마다 중국 등지에서 대량으로 수입하고 있다.\n이달 1일 기준 북한 장마당에서 거래되는 식용유(1kg) 가격은\xa011,000원 선으로 같은 양의 쌀값(5000원)의 두 배다.'

# %%
# gpt-4o-mini
for i, row in test_item.iterrows():
    title = row.title
    contents = re.sub(r"[\xa0\n]+", "", row.contents)
    publish_date = row.publish_date
    print(get_article_summary(title, contents, publish_date))
# Out:
# ({'summary': '북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물 재배를 독려했다. 노동신문은 기름작물 재배의 중요성을 강조하며, 각 지역에서 이 사업이 활발히 진행되고 있다고 보도했다. 북한은 식용유를 중국 등에서 수입하고 있으며, 장마당에서 식용유 가격이 쌀 가격의 두 배에 달하고 있다.', 'event_title': '북, 기름작물 재배 독려', 'event_date': '2024-03-15', 'event_person': '', 'event_org': '', 'event_loc': '', 'keywords': '식용유, 기름작물, 지방공업, 재배, 북한', 'p_rice(won/kg)': '11000', 'p_corn(won/kg)': '', 'p_usd(won/usd)': ''}, 1483, 213)

# %%
# gpt-4.1-nano
for i, row in test_item.iterrows():
    title = row.title
    contents = re.sub(r"[\xa0\n]+", "", row.contents)
    publish_date = row.publish_date
    print(get_article_summary(title, contents, publish_date, model="gpt-4.1-nano"))
# Out:
# ({'summary': '북한은 식용유 부족 문제 해결을 위해 지방공업공장 건설과 기름작물 재배를 독려하고 있다. 지방발전 정책에 따라 해바라기 등 기름작물 재배를 적극 추진하며 원료기지 조성을 강조하고 있다. 이와 함께 식용유 가격이 높아 수입에 의존하는 현실을 개선하려는 움직임이 나타나고 있다.', 'event_title': '북, 지방공업공장 건설 계기 기름작물 재배 독려', 'event_date': '2024-03-15', 'event_person': '', 'event_org': '', 'event_loc': '', 'keywords': '기름작물,공장건설,재배운동,식용유부족,원료기지', 'p_rice': '', 'p_corn': '', 'p_usd': ''}, 1483, 207)

# %%
for i, row in test_item.iterrows():
    title = row.title
    contents = re.sub(r'[\xa0\n]+', ' ', row.contents)
    publish_date = row.publish_date
    print(get_article_summary(title, contents, publish_date))

# %%
# 변경 후
for idx, i in enumerate(test_item['id']):
    sample = test_item[test_item["id"] == i]
    
    title = sample["title"]
    contents = sample["contents"]
    publish_date = sample["publish_date"]

    print(idx)
    print(get_article_summary(title, contents, publish_date))
# Out:
# 0
# ({'summary': '북한 주민들이 식용유 부족난을 겪고 있는 가운데 지방공업공장 건설을 계기로 기름작물 재배가 독려되고 있다.', 'event_title': '지방공업공장 건설 계기 기름작물 재배 독려', 'event_date': '2024-03-15', 'event_person': '', 'event_org': '', 'event_loc': '', 'keywords': '식용유, 부족난, 지방공업공장, 기름작물, 재배', 'p_rice(won/kg)': '', 'p_corn(won/kg)': '', 'p_usd(won/usd)': ''}, 1180, 157)

# %% [markdown]
# ## ISSUE (11.20) - 데이터에 리스트로 저장되는 문제 - 쉼표+space 로 구분방식으로 변경 (해결 완료)

# %%
merged_sum = pd.read_csv('data/merged_summary.csv')

# %%
def parse_list_string(s):
    # s가 NaN이면 그대로 반환
    if pd.isna(s):
        return s
    
    # 앞뒤 불필요한 큰따옴표 제거
    s = s.strip('"').strip("'")
    
    try:
        # 문자열을 실제 파이썬 리스트로 변환
        lst = ast.literal_eval(s)
        # 리스트를 콤마 문자열로 변환
        return ", ".join(lst)
    except:
        return s  # 파싱 실패 시 원본 반환

# 적용할 컬럼들
cols = ["keywords", "event_person", "event_loc", "event_org"]

for c in cols:
    merged_sum[c] = merged_sum[c].apply(parse_list_string)

# %%
merged_sum.head(2)
# Out:
#               id                            title  \
# 0  spnews_101404  北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 1  spnews_101403              北,  나무 사름률 높이는 제품은?
#
#                                             contents  source section  \
# 0  북한 평안북도 신의주온실종합농장 건설장에서 방대한 면적의 지대정리와 잔디심기가 마감...  spnews     북한N
# 1  북한이 나무의 사름률을 보장에 효과적인 과학기술제품으로 천연생물활성제 등이 있다고 ...  spnews     북한N
#
#      author publish_date                                                url  \
# 0   안윤석 대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
# 1  안윤석  대기자   2025-11-17  https://www.spnews.co.kr/news/articleView.html...
#
#   category                                            summary  \
# 0    경제/산업  신의주온실종합농장 건설장에서 지대정리와 잔디심기가 마감단계에 이르고 있다. 군민건설...
# 1    경제/산업  북한이 나무의 사름률을 높이는 과학기술제품으로 천연생물활성제를 소개했다. 이 제품은...
#
#                      keywords           event_title  event_date event_person  \
# 0  온실농장, 잔디심기, 지대정리, 건설, 자연공원     신의주온실종합농장 건설 마감단계  2025-11-17
# 1    나무, 사름률, 천연생물활성제, 제품, 효과  북한, 나무 사름률 높이는 제품 소개  2025-11-17
#
#   event_org event_loc  p_rice(won/kg)  p_corn(won/kg)  p_usd(won/usd)
# 0            평안북도 신의주             NaN             NaN             NaN
# 1                                 NaN             NaN             NaN

# %%
merged_sum.shape
# Out:
# (6908, 19)

# %%
type(merged_sum.keywords[0])
# Out:
# str

# %%
merged_sum.keywords[0]
# Out:
# '온실농장, 잔디심기, 지대정리, 건설, 자연공원'

# %%
merged_sum.to_csv('data/merged_summary_stringVer.tsv', sep='\t', index=False)

# %%
marked_data = pd.DataFrame(columns=merged_sum.columns)
marked_data
# Out:
# Empty DataFrame
# Columns: [id, title, contents, source, section, author, publish_date, url, category, summary, keywords, event_title, event_date, event_person, event_org, event_loc, p_rice(won/kg), p_corn(won/kg), p_usd(won/usd)]
# Index: []

# %%
import pandas as pd
import numpy as np
import random
import string

def randstr(n=8):
    return ''.join(random.choice(string.ascii_lowercase) for _ in range(n))

# 빈 구조 생성
cols = [
    "id", "title", "contents", "source", "section", "author", 
    "publish_date", "url", "category", "summary", "keywords",
    "event_title", "event_date", "event_person", "event_org", "event_loc",
    "p_rice(won/kg)", "p_corn(won/kg)", "p_usd(won/usd)"
]

marked_data = pd.DataFrame(columns=cols)

# 1~3번째 row 생성 (랜덤)
for i in range(3):
    row = {col: randstr() for col in cols}
    
    # 3번째 row만 가격 3개를 null 처리
    if i == 2:
        row["p_rice(won/kg)"] = np.nan
        row["p_corn(won/kg)"] = np.nan
        row["p_usd(won/usd)"] = np.nan
    
    marked_data.loc[i] = row

marked_data
# Out:
#          id     title  contents    source   section    author publish_date  \
# 0  lckzuoki  orjpalxp  krfyirwk  tuquvdfq  jajkywol  zdxuutcd     oqbzcqwk
# 1  yeukwszi  lpkifnca  mdpeuvxj  wriisaoo  oidsyokg  azxdojyh     kjqlcszx
# 2  pxxxvmzd  abaurtoo  qskjcbwe  wjzpqlrw  xwcflouh  ffzvjcgl     srkhamcg
#
#         url  category   summary  keywords event_title event_date event_person  \
# 0  yuebjkii  rskbropc  fiwoyjed  jbukqvzi    fghapdxd   utyrvsdl     cozqlhtt
# 1  uihertfm  hcuboxyl  quqxccet  axqkiznv    meqdcaph   pdsnnfob     kyqspmnp
# 2  fylercyr  ixerzlsb  ducutegz  ihwenouk    shbzxyze   mgupcvnh     ufxdbsyj
#
#   event_org event_loc p_rice(won/kg) p_corn(won/kg) p_usd(won/usd)
# 0  gwdiwmge  qdgphcvq       rqtzoslu       kbybnveb       trhiuine
# 1  qanlnxve  zimyfnmk       bwzmwkhn       ufyazddm       edjtsbbs
# 2  cmqunuek  mjvdmbow            NaN            NaN            NaN

# %%
marked_data.loc[0, 'event_person'] = 'cozqlhtt, cofdas, adfeff'

# %%
marked_data.to_csv('data/test_foundry.csv', index=False)

# %% [markdown]
# ## 테스트 (11.19) - spnews_ver2.csv 결과중 50개 랜덤 추출 후 요약

# %%
df = pd.read_csv('data/spnews_ver2.csv')

test_df = pd.concat([
    df.head(13),
    df[df.title.str.contains('물가')].iloc[1:3] # 물가 정보 파싱 관련 테스트 위해 추가
])

# %%
summary_df = get_summary_df(test_df)
# Out:
# 캐시 없음 → 빈 DF 생성
# 신규 샘플 발견: 15개
# Summarizing [spnews_101404] ...
# Job Complete! [spnews_101404] (1/15)
# Summarizing [spnews_101403] ...
# Job Complete! [spnews_101403] (2/15)
# Summarizing [spnews_101402] ...
# Job Complete! [spnews_101402] (3/15)
# Summarizing [spnews_101394] ...
# Job Complete! [spnews_101394] (4/15)
# Summarizing [spnews_101392] ...
# Job Complete! [spnews_101392] (5/15)
# Summarizing [spnews_101391] ...
# Job Complete! [spnews_101391] (6/15)
# Summarizing [spnews_101390] ...
# Job Complete! [spnews_101390] (7/15)
# Summarizing [spnews_101389] ...
# Job Complete! [spnews_101389] (8/15)
# Summarizing [spnews_101383] ...
# Job Complete! [spnews_101383] (9/15)
# Summarizing [spnews_101377] ...
# Job Complete! [spnews_101377] (10/15)
# Summarizing [spnews_101376] ...
# Job Complete! [spnews_101376] (11/15)
# Summarizing [spnews_101374] ...
# Job Complete! [spnews_101374] (12/15)
# Summarizing [spnews_101373] ...
# Job Complete! [spnews_101373] (13/15)
# Summarizing [spnews_101146] ...
# Job Complete! [spnews_101146] (14/15)
# Summarizing [spnews_100377] ...
# Job Complete! [spnews_100377] (15/15)
# 전체 작업 완료!

# %%
summary_df.to_excel('data/test_llm_summary_1119.xlsx', index=False)

# %% [markdown]
# ## ISSUE (11.19) - None 타입 반환 에러 (해결 완료)

# %%
df = pd.read_csv('data/spnews_ver2.csv')
df = df[df.contents.notnull() & df.category.notnull()]
test_df = df[df.id == 'spnews_101391']

# %%
summary_df = get_article_summary(test_df)
# Out:
# Summarizing [spnews_101391] ...
# Parsing error: {
#     "summary": "북한 평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행되었다. 농장 일꾼들과 근로자들의 노력으로 국가알곡생산계획이 127.5% 달성되었다. 결산분배모임에는 평안남도당위원회 책임비서와 도농촌경리위원회 위원장이 참석했다.",
#     "event_title": "첫 모내기 결산분배",
#     "event_date": "2025-11-16",
#     "event_person": "리경철, 최영송",
#     "event_org": "평안남도당위원회, 도농촌경리위원회",
#     "event_loc": "북한, 평안남도, 원화농장",
#     "keywords": "리경철, 최영송, 평안남도, 원화농장, 결산분배, 첫 모내기",
#     "p_rice(won/kg)": null,
#     "p_corn(won/kg)": null,
#     "p_usd(won/usd)": null
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 summary_df = get_article_summary(test_df)
#
# Cell In[172], line 31, in get_article_summary(df, cache_path)
#      28 publish_date = orig_row["publish_date"]
#      30 # LLM call
# ---> 31 result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)
#      33 if result:
#      34     output_df.loc[output_df["id"] == article_id, "summary"] = result.get("summary")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
title = test_df.iloc[0].title
contents = test_df.iloc[0].contents
publish_date = test_df.iloc[0].publish_date

# %%
# result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)
# Out:
# Parsing error: {
#     "summary": "북한 평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행됐다. 농장 일꾼들과 근로자들의 노력으로 국가알곡생산계획이 127.5% 달성되었다. 결산분배모임에는 평안남도당위원회 책임비서와 도농촌경리위원회 위원장이 참석했다.",
#     "event_title": "첫 모내기 결산분배",
#     "event_date": "2025-05-16",
#     "event_person": "리경철, 최영송",
#     "event_org": "평안남도당위원회, 도농촌경리위원회",
#     "event_loc": "북한, 평안남도",
#     "keywords": "리경철, 최영송, 평안남도, 첫 모내기, 결산분배",
#     "p_rice(won/kg)": null,
#     "p_corn(won/kg)": null,
#     "p_usd(won/usd)": null
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
prompt = f"""
아래 기사를 분석하여 요구된 정보를 작성하시오.

# 기사 제목:
{title}

# 기사 내용:
{contents}

# 기사 작성일:
{publish_date}

1. 아래 형식으로 정리 (괄호안 각 key값의 한글 설명은 참고만 하고 최종 결과에는 포함하지 않음)
- summary(주요 사건 요약):
- event_title(사건 주제):
- event_date(사건 발생일):
- event_person(사건 핵심 인물):
- event_org(사건 핵심 조직/기관):
- event_loc(사건 발생 지명):
- keywords(주요 키워드):
- p_rice(won/kg)(쌀 가격):
- p_corn(won/kg)(옥수수 가격):
- p_usd(won/usd)(달러 가격)

2. 각 카테고리의 조건
- "주요 사건 요약"은 3 문장 이하로 핵심 내용만 발췌
- "사건 발생일" 과 "기사 작성일"은 yyyy-mm-dd 형식, 
- "사건 발생일"이 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, '어제', '사흘전', '일주일 전' 등)를 참고하여 "기사 작성일" 기준 계산
- "사건 핵심 인물"은 뉴스의 중심 인물(들)의 이름만을 입력, 다수의 경우 쉼표로 구분
- "사건 핵심 조직/기관"은 뉴스에서 중요하게 다루고 있는 조직 및 기관의 이름만 입력, 다수면 쉼표로 구분, 해당 뉴스의 출처 정보는 제외(예, 노동신문 등).
- "사건 발생 지명"은 [국가, 도, 시]단위 지명만을 입력, 건물등에서 일어난 사건의 경우는 해당 장소의 [국가, 도, 시] 지명을 입력.
- "주요 키워드"는 "사건 핵심 인물", "사건 핵심 조직/기관", "사건 발생 지명"을 반드시 포함하고, "주요 사건 요약" 정보를 가장 잘 묘사하는 최소의 단어들로 쉼표 구분하여 임력.
- 물가 관련 뉴스에 쌀, 옥수수 kg당 가격 및 원달러 환율이 제공될 경우, 반드시 평양의 정보만 선택하여 각 값을 정수로 입력. 
- 위 결과를 종합하여 딕셔너리 형태로 출력
- 설명 금지, 답만 출력
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
        {"role": "user", "content": prompt},
    ],
    temperature=0
)

# 소모 토큰량 추출
input_tokens = response.usage.prompt_tokens
output_tokens = response.usage.completion_tokens


result_text = response.choices[0].message.content.strip()

# %%
result_text
# Out:
# '{\n    "summary": "북한 평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행됐다. 농장 일꾼들과 근로자들의 노력으로 국가 알곡 생산 계획이 127.5% 달성되었다. 결산분배 모임에는 평안남도당위원회 책임비서와 도농촌경리위원회 위원장이 참석했다.",\n    "event_title": "첫 모내기 결산분배",\n    "event_date": "2025-11-16",\n    "event_person": "리경철, 최영송",\n    "event_org": "평안남도당위원회, 도농촌경리위원회",\n    "event_loc": "북한, 평안남도, 원화농장",\n    "keywords": "리경철, 최영송, 평안남도당위원회, 도농촌경리위원회, 북한, 원화농장, 첫 모내기",\n    "p_rice(won/kg)": null,\n    "p_corn(won/kg)": null,\n    "p_usd(won/usd)": null\n}'

# %%
result = json.loads(result_text)  # dict로 파싱 (구조가 명확하므로 안전)
result
# Out:
# {'summary': '북한 평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행됐다. 농장 일꾼들과 근로자들의 노력으로 국가 알곡 생산 계획이 127.5% 달성되었다. 결산분배 모임에는 평안남도당위원회 책임비서와 도농촌경리위원회 위원장이 참석했다.',
#  'event_title': '첫 모내기 결산분배',
#  'event_date': '2025-11-16',
#  'event_person': '리경철, 최영송',
#  'event_org': '평안남도당위원회, 도농촌경리위원회',
#  'event_loc': '북한, 평안남도, 원화농장',
#  'keywords': '리경철, 최영송, 평안남도당위원회, 도농촌경리위원회, 북한, 원화농장, 첫 모내기',
#  'p_rice(won/kg)': None,
#  'p_corn(won/kg)': None,
#  'p_usd(won/usd)': None}

# %% [markdown]
# -  Json으로 파싱하면 잘 뽑힘

# %%
# 수정된 generate_event_info() 사용
result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)

# %%
result
# Out:
# {'summary': '북한 평안남도 원화농장에서 첫 모내기를 기념하여 결산분배가 진행됐다. 농장 일꾼들과 근로자들의 노력으로 국가알곡생산계획이 127.5% 달성되었다. 결산분배모임에는 평안남도당위원회 책임비서와 도농촌경리위원회 위원장이 참석했다.',
#  'event_title': '첫 모내기 결산분배',
#  'event_date': '2025-05-16',
#  'event_person': '리경철, 최영송',
#  'event_org': '평안남도당위원회, 도농촌경리위원회',
#  'event_loc': '북한, 평안남도',
#  'keywords': '리경철, 최영송, 평안남도, 첫 모내기, 결산분배',
#  'p_rice(won/kg)': None,
#  'p_corn(won/kg)': None,
#  'p_usd(won/usd)': None}

# %% [markdown]
# ## 테스트 (11.19) - LLM 요약 함수 캐시 기능 테스트

# %%
df = pd.read_csv('data/spnews_ver2.csv')

test_df = pd.concat([
    df.head(13),
    df[df.title.str.contains('물가')].iloc[1:3] # 물가 정보 파싱 관련 테스트 위해 추가
])

# %%
new_cols = ["summary", "keywords", "event_title", "event_date", "event_person",
            "event_org", "event_loc", "p_rice(won/kg)", "p_corn(won/kg)",
            "p_usd(won/usd)", "job_cost"]

# 캐시가 있으면 로드, 없으면 빈 DataFrame 생성
if os.path.exists(cache_path):
    print("⏳ 캐시 파일 로드 중...")
    output_df = pd.read_csv(cache_path)
    print("✔ 캐시 반영 완료!")
else:
    output_df = pd.DataFrame(columns=(["id"]+new_cols))

# %%
 # 캐시에 이미 존재하는 id 목록
cached_ids = set(output_df["id"].tolist())

# 새 df에서 캐시에 없던 id들만 처리
new_rows = test_df[~test_df["id"].isin(cached_ids)]

# %% [markdown]
# ---

# %% [markdown]
# ## 테스트 (11.18) - 토큰 비용 계산

# %%
# 테스트df 복사본 생성
test_data = test_df.copy()

# 테스트 데이터의 게재일 datetime으로 변환
test_data['publish_date'] = pd.to_datetime(test_data['publish_date']).dt.date
test_data.head(2)

# 테스트 데이터 저장
os.makedirs('data', exist_ok=True)
test_data.to_csv('data/test_dataset.csv', index=False)

# %%
test_item = test_data.iloc[-1]
title, contents, publish_date = test_item['title'], test_item['contents'], test_item['publish_date']

print(title, contents, publish_date, sep='\n')
# Out:
# [北 물가] 가을 추수 영향, 곡물가 내림세
# 북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아섰다
# 'SPN'이 11월 15일 기준 북한 평양시와 양강도 혜산시, 강원도 원산시, 황해북도 사리원시 장마당 물가를 조사한 결과 이같이 나타났다.
# 달러는 평양 34,600원(+400원), 혜산 34,630원(+330원), 원산 34,580원(-1,600원), 사리원 34,600원(-1,600원)으로 오르고 내렸다.
# 쌀(1kg)은 평양 19,850원(보름전보다 -1,150원), 혜산 20,000원(-1,400원), 원산 19,700원(-1,200원), 사리원  19,800원(-1,150원)으로 내림세를 보였다.
# 옥수수(1kg)는 평양 4,500원(-500원), 혜산 4,500원(-350원), 원산 4,300원(-600원), 사리원 4,600원(-350원)으로 하락했다.
# 현지 소식통들은 "가을 추수가 마무리되면서 출하량이  늘어나 곡물류 가격이 내리고 있다"고 전했다.
# 기초식품인 식용유는 달러화가 소폭 상승하거나 내리면서 가격이 들쭉날쭉했다.
# 식용유(1kg)는 평양 55,800원(-350원), 혜산 55,400원(+300원), 원산 56,000원(-500원)로 조사됐다. 설탕은 평양 40,900원(-600원), 혜산 40,600원(-600원)에 거래됐다.
# 휘발유(1kg)는 평양 41,100원(-700원), 혜산 41,400원(-600원)으로 내림세를 보였다. 경유(1kg)는 평양 39,400원(-900원), 혜산 39,700원(-1,100원)으로 소폭 내렸다.
# 소식통들은 "유류가 하락은 가을 추수가 마무리 되면서 수요가 감소하고 공급량이 증가한 것이 원인"이라고 밝혔다.
# 돼지고기(1kg)는 평양 70,000원(0원), 혜산 71,000원(+200원)에 거래됐다.
# 2025-11-17

# %%
prompt = f"""
아래 기사를 분석하여 요구된 정보를 작성하시오.

# 기사 제목:
{title}

# 기사 내용:
{contents}

# 기사 작성일:
{publish_date}

1. 아래 형식으로 정리
- 주요 사건 요약(summary):
- 사건 주제(event_title):
- 사건 발생일(event_date):
- 사건 발생 핵심 인물(event_person):
- 사건 관련 핵심 조직(event_org):
- 사건 발생 지명(event_loc):
- 주요 키워드(keywords):

2. 각 카테고리의 조건
- "주요 사건 요약"은 3문장 이하로 핵심 내용만 발췌
- "사건 발생일" 과 "기사 작성일"은 yyyy-mm-dd 형식, 
- 사건 발생일"이 명시되지 않았으면 "기사 내용" 중 시간 또는 기간을 나타내는 단어(예시로, '어제', '사흘전', '일주일 전' 등)를 참고하여 "기사 작성일" 기준 계산
- "사건 발생 핵심 인물"은 뉴스의 주체가 되는 주요 인물명만, 다수면 쉼표로 구분
- "사건 관련 핵심 조직"은 뉴스에서 중요하게 다루고 있는 단체 및 기관명만, 다수면 쉼표로 구분, 해당 뉴스의 출처에 해당하는 정보는 제외(예시로, 노동신문 등).
- "사건 발생 지명"은 사건이 발생한 지역 또는 사건의 주체에 해당하는 단 하나의 지명만 입력
- "주요 키워드"는 뉴스를 가장 잘 표현할 수 있는 단어들로만 구성, 다섯개 까지, '북한' 이라는 단어는 제외
- 출력은 딕셔너리 형태로, 값이 여러 개면 리스트로 묶어서 출력
- 설명 금지, 답만 출력
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 북한 관련 뉴스 사건 정보를 추출하는 전문 분석 모델입니다."},
        {"role": "user", "content": prompt},
    ],
    temperature=0
)

# 소모 토큰량 추출
input_tokens = response.usage.prompt_tokens
output_tokens = response.usage.completion_tokens


result_text = response.choices[0].message.content.strip()

# 문자열을 dict로 변환
try:
    result = eval(result_text)  # dict로 파싱 (구조가 명확하므로 안전)
except:
    print("Parsing error:", result_text)

# %%
result
# Out:
# {'주요 사건 요약': '북한에서 가을 추수가 마무리되면서 쌀과 옥수수 등 곡물류 가격이 하락세를 보이고 있다. 평양, 혜산, 원산, 사리원 등지에서 곡물 가격이 내림세로 돌아섰으며, 유류 가격도 하락했다. 현지 소식통은 출하량 증가가 가격 하락의 원인이라고 전했다.',
#  '사건 주제': '곡물가 하락',
#  '사건 발생일': '2025-11-15',
#  '사건 발생 핵심 인물': '',
#  '사건 관련 핵심 조직': '',
#  '사건 발생 지명': '평양',
#  '주요 키워드': ['곡물', '가격', '추수', '하락', '유류']}

# %%
# 프롬프트 변경 후(6차 변경 프롬프트 사용)
result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)
result

# %%
# 토큰 사용량 조회
print(f'***토큰 사용량***\n입력: {input_tokens}\n출력: {output_tokens}')
print(f'-'*30)

# 전체 소비 토큰 가격 계산
costs = sum([(input_tokens * 0.15 / 1_000_000), (output_tokens * 0.60 / 1_000_000)]) # 가독성을 위해 1000단위 underscore(_) 사용
print(f'***Total Cost***\n${costs}')
# Out:
# ***토큰 사용량***
# 입력: 1085
# 출력: 175
# ------------------------------
# ***Total Cost***
# $0.00026775

# %% [markdown]
# ## 테스트 (11.18) - 뉴스 요약 테스트 (임의의 16개 뉴스 샘플)

# %%
df = pd.read_csv('data/test_dataset.csv')
print(len(df))
df.head()
# Out:
# 16
#               id                                        title  \
# 0  spnews_101049                    北, 김영남 상임위원장 영결식...김정은 참석
# 1  spnews_101366          박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2  spnews_100345  김정은, '신의주온실종합농장' 또 현지지도..."농촌문명의 새로운 경지 개척"
# 3  spnews_101306               박태성 北 내각총리, 통싸완 폼비한 라오스 외무상 접견
# 4  spnews_100889         북한-러시아, 무역경제 및 과학기술협력 추진 회담...의정서 조인
#
#                                             contents   author publish_date  \
# 0  고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...  안윤석 대기자   2025-11-06
# 1  박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다.\n노동신...  안윤석 대기자   2025-11-16
# 2  김정은 북한 총비서가 17일 마감단계에 들어선 신의주온실종합농장 건설장을 또다시 방...  안윤석 대기자   2025-10-18
# 3  박태성 북한 내각총리가 13일 만수대의사당에서 통싸완 폼비한 라오스 외무상을 만났다...  안윤석 대기자   2025-11-14
# 4  북한과 러시아가 합의된 다방면적인 쌍무협력계획 이행을 추진하기 위한 회담을 31일 ...  안윤석 대기자   2025-11-01
#
#                                                  url category
# 0  https://www.spnews.co.kr/news/articleView.html...       정치
# 1  https://www.spnews.co.kr/news/articleView.html...       정치
# 2  https://www.spnews.co.kr/news/articleView.html...       정치
# 3  https://www.spnews.co.kr/news/articleView.html...       외교
# 4  https://www.spnews.co.kr/news/articleView.html...       외교

# %%
# 새 컬럼 추가 (job_cost 컬럼은 임시 컬럼)
new_cols = ["summary", "keywords", "event_title", "event_date", "event_obj", "event_loc", "job_cost"]
for col in new_cols:
    df[col] = None

# 각 row 반복 → LLM 호출 → 결과 입력
for idx, row in df.iterrows():
    print(f"Processing index {idx} ...")

    title = row["title"]
    contents = row["contents"]
    publish_date = row["publish_date"]  # datetime.date

    result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)

    if result:
        df.at[idx, "summary"] = result.get("summary")
        df.at[idx, "keywords"] = result.get("keywords")
        df.at[idx, "event_title"] = result.get("event_title")
        df.at[idx, "event_date"] = result.get("event_date")
        df.at[idx, "event_obj"] = result.get("event_obj")
        df.at[idx, "event_loc"] = result.get("event_loc")
        
        # LLM 토큰 비용 컬럼 추가(테스트용)
        df.at[idx, "job_cost"] = sum([(input_tokens * 0.15 / 1_000_000), (output_tokens * 0.60 / 1_000_000)])
    
    print(f'Work Finish ({idx+1}/{len(df)})')
print("전체 작업 완료!")
# Out:
# Processing index 0 ...
# Work Finish (1/16)
# Processing index 1 ...
# Work Finish (2/16)
# Processing index 2 ...
# Work Finish (3/16)
# Processing index 3 ...
# Work Finish (4/16)
# Processing index 4 ...
# Work Finish (5/16)
# Processing index 5 ...
# Work Finish (6/16)
# Processing index 6 ...
# Work Finish (7/16)
# Processing index 7 ...
# Work Finish (8/16)
# Processing index 8 ...
# Work Finish (9/16)
# Processing index 9 ...
# Work Finish (10/16)
# Processing index 10 ...
# Work Finish (11/16)
# Processing index 11 ...
# Work Finish (12/16)
# Processing index 12 ...
# Work Finish (13/16)
# Processing index 13 ...
# Work Finish (14/16)
# Processing index 14 ...
# Work Finish (15/16)
# Processing index 15 ...
# Work Finish (16/16)
# 전체 작업 완료!

# %% [markdown]
# ### --- Issue 발생--- 요약 정보 추출 실패 하는 경우 발생

# %%
df
# Out:
#                id                                          title  \
# 0   spnews_101049                      北, 김영남 상임위원장 영결식...김정은 참석
# 1   spnews_101366            박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2   spnews_100345    김정은, '신의주온실종합농장' 또 현지지도..."농촌문명의 새로운 경지 개척"
# 3   spnews_101306                 박태성 北 내각총리, 통싸완 폼비한 라오스 외무상 접견
# 4   spnews_100889           북한-러시아, 무역경제 및 과학기술협력 추진 회담...의정서 조인
# 5   spnews_100318               북러 과학기술협조위 임업분과위 회의...벌목공 송출 논의?
# 6   spnews_101377            北, 한미 해군 연합훈련 기간 강원도 고성항에 호위함 추가 배치
# 7   spnews_101097    北, 동해로 탄도미사일 발사...美제재에 '반발 담화' 하루 만에 도발(종합)
# 8   spnews_100356            북한, 일본 자위대 구축함 미국산 '장거리순항미사일' 탑재 비난
# 9   spnews_101404                北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 10  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
# 11  spnews_101258                 北, 산림과학연구부문 '국가산림병해충예찰예보체계' 가동
# 12  spnews_101402                          北 개성시, 식물방역소·돼지종축장 신축
# 13  spnews_101369                     北, FIFA U-17 월드컵대회 16강전 진출
# 14  spnews_101272  北, '일본 죄악 폭로단죄 역사학부문 토론회' 개최..."만고죄악, 반드시 결산"
# 15  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
#
#                                              contents      author  \
# 0   고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...     안윤석 대기자
# 1   박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다.\n노동신...     안윤석 대기자
# 2   김정은 북한 총비서가 17일 마감단계에 들어선 신의주온실종합농장 건설장을 또다시 방...     안윤석 대기자
# 3   박태성 북한 내각총리가 13일 만수대의사당에서 통싸완 폼비한 라오스 외무상을 만났다...     안윤석 대기자
# 4   북한과 러시아가 합의된 다방면적인 쌍무협력계획 이행을 추진하기 위한 회담을 31일 ...     안윤석 대기자
# 5   북한과 러시아 무역경제 및 과학기술협조위원회 임업분과위원회 제28차회의가 16일 평...     안윤석 대기자
# 6   북한이 최근 진행된 한미 해군 연합훈련 기간 강원도 고성항에 두만급(1천500t급)...      유영목 기자
# 7   북한이 16일 만에 탄도미사일을 또다시 발사했다.\n합동참모본보는 "우리 군은 7일...      유영목 기자
# 8   북한이 일본 자위대 구축함의 미국산 토마호크 장거리순항미사일 탑재를 비난했다.\n북...     안윤석 대기자
# 9   북한 평안북도 신의주온실종합농장 건설장에서 방대한 면적의 지대정리와 잔디심기가 마감...     안윤석 대기자
# 10  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
# 11  북한 산림과학연구부문 과학자들이 개발한 국가산림병해충예찰예보체계가 원활히 가동되고 ...     안윤석 대기자
# 12  북한 개성시에서 식물방역소와 돼지종축장 새로 건설했다.\n노동신문은 17일 "개성시...    안윤석  대기자
# 13  북한이 국제축구연맹(FIFA) 2025년 17살 미만(U-17) 월드컵대회에서 16...  SPN 서울평양뉴스
# 14  북한이 "천년숙적 일본의 만고죄악을 폭로단죄하는 역사학부문 토론회'를 12일 사회과...     안윤석 대기자
# 15  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
#
#    publish_date                                                url  category  \
# 0    2025-11-06  https://www.spnews.co.kr/news/articleView.html...        정치
# 1    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        정치
# 2    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        정치
# 3    2025-11-14  https://www.spnews.co.kr/news/articleView.html...        외교
# 4    2025-11-01  https://www.spnews.co.kr/news/articleView.html...        외교
# 5    2025-10-17  https://www.spnews.co.kr/news/articleView.html...        외교
# 6    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        군사
# 7    2025-11-07  https://www.spnews.co.kr/news/articleView.html...        군사
# 8    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        군사
# 9    2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 10   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 11   2025-11-12  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 12   2025-11-17  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 13   2025-11-16  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 14   2025-11-13  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 15   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
#
#                                               summary  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   북한이 16일 만에 동해로 단거리 탄도미사일을 발사했다. 이번 발사는 미국의 대북 ...
# 8                                                None
# 9                                                None
# 10                                               None
# 11  북한의 산림과학연구부문 과학자들이 개발한 국가산림병해충예찰예보체계가 가동되고 있다....
# 12                                               None
# 13  북한이 FIFA 2025년 U-17 월드컵대회에서 16강전에 진출했다. 북한팀은 3...
# 14                                               None
# 15                                               None
#
#                            keywords                 event_title  event_date  \
# 0                              None                        None        None
# 1                              None                        None        None
# 2                              None                        None        None
# 3                              None                        None        None
# 4                              None                        None        None
# 5                              None                        None        None
# 6                              None                        None        None
# 7        [북한, 탄도미사일, 대북 제재, 동해, 미국]                 북한 탄도미사일 발사  2025-11-07
# 8                              None                        None        None
# 9                              None                        None        None
# 10                             None                        None        None
# 11      [산림, 병해충, 예찰예보체계, 과학화, 정보화]            국가산림병해충예찰예보체계 가동  2025-11-12
# 12                             None                        None        None
# 13  [북한, U-17 월드컵, 16강전, 베네수엘라, 축구]  북, FIFA U-17 월드컵대회 16강전 진출  2025-11-16
# 14                             None                        None        None
# 15                             None                        None        None
#
#    event_obj event_loc  job_cost
# 0       None      None  0.000259
# 1       None      None  0.000253
# 2       None      None   0.00027
# 3       None      None  0.000208
# 4       None      None  0.000258
# 5       None      None  0.000245
# 6       None      None  0.000231
# 7       None  북한 평북 대관   0.00025
# 8       None      None  0.000269
# 9       None      None  0.000237
# 10      None      None  0.000273
# 11      None        북한  0.000225
# 12      None      None  0.000213
# 13      None       카타르  0.000181
# 14      None      None  0.000293
# 15      None      None  0.000277

# %% [markdown]
# ##### Idx 0번 뉴스 하나만 가지고 테스트

# %%
df = pd.read_csv('data/test_dataset.csv')
sample_data = df.iloc[[0]]
sample_data
# Out:
#               id                      title  \
# 0  spnews_101049  北, 김영남 상임위원장 영결식...김정은 참석
#
#                                             contents   author publish_date  \
# 0  고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...  안윤석 대기자   2025-11-06
#
#                                                  url category
# 0  https://www.spnews.co.kr/news/articleView.html...       정치

# %%
title = sample_data['title']
contents = sample_data['contents']
publish_date = sample_data['publish_date']

print(title, contents, publish_date, sep='\n')
# Out:
# 0    北, 김영남 상임위원장 영결식...김정은 참석
# Name: title, dtype: object
# 0    고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...
# Name: contents, dtype: object
# 0    2025-11-06
# Name: publish_date, dtype: object

# %%
result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)

# %%
result
# Out:
# {'summary': '고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로 진행되었다. 김정은이 참석하여 고인의 마지막 길을 배웅했다. 장례식은 북한의 공식적인 절차에 따라 치러졌다.',
#  'event_title': '김영남 상임위원장 영결식',
#  'event_date': '2025-11-05',
#  'event_person': '김영남, 김정은',
#  'event_org': '북한 최고인민회의',
#  'event_loc': '평양',
#  'keywords': ['김영남', '영결식', '김정은', '북한', '국장']}

# %% [markdown]
# ###### 문제 해결: 컬럼명 불일치 문제 - event_person추가필요, event_org로 수정 필요
#
# - 컬럼 구성 및 순서 정리
#
# new_cols = ["summary", "keywords", "event_title", "event_date", "event_person", "event_org", "event_loc", "job_cost"]

# %% [markdown]
# ### --- Issue 해결 --- 수정된 테스트 코드 (5개의 샘플만 테스트)

# %%
df = pd.read_csv('data/test_dataset.csv')
print(len(df))
df
# Out:
# 16
#                id                                          title  \
# 0   spnews_101049                      北, 김영남 상임위원장 영결식...김정은 참석
# 1   spnews_101366            박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2   spnews_100345    김정은, '신의주온실종합농장' 또 현지지도..."농촌문명의 새로운 경지 개척"
# 3   spnews_101306                 박태성 北 내각총리, 통싸완 폼비한 라오스 외무상 접견
# 4   spnews_100889           북한-러시아, 무역경제 및 과학기술협력 추진 회담...의정서 조인
# 5   spnews_100318               북러 과학기술협조위 임업분과위 회의...벌목공 송출 논의?
# 6   spnews_101377            北, 한미 해군 연합훈련 기간 강원도 고성항에 호위함 추가 배치
# 7   spnews_101097    北, 동해로 탄도미사일 발사...美제재에 '반발 담화' 하루 만에 도발(종합)
# 8   spnews_100356            북한, 일본 자위대 구축함 미국산 '장거리순항미사일' 탑재 비난
# 9   spnews_101404                北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 10  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
# 11  spnews_101258                 北, 산림과학연구부문 '국가산림병해충예찰예보체계' 가동
# 12  spnews_101402                          北 개성시, 식물방역소·돼지종축장 신축
# 13  spnews_101369                     北, FIFA U-17 월드컵대회 16강전 진출
# 14  spnews_101272  北, '일본 죄악 폭로단죄 역사학부문 토론회' 개최..."만고죄악, 반드시 결산"
# 15  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
#
#                                              contents      author  \
# 0   고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...     안윤석 대기자
# 1   박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다.\n노동신...     안윤석 대기자
# 2   김정은 북한 총비서가 17일 마감단계에 들어선 신의주온실종합농장 건설장을 또다시 방...     안윤석 대기자
# 3   박태성 북한 내각총리가 13일 만수대의사당에서 통싸완 폼비한 라오스 외무상을 만났다...     안윤석 대기자
# 4   북한과 러시아가 합의된 다방면적인 쌍무협력계획 이행을 추진하기 위한 회담을 31일 ...     안윤석 대기자
# 5   북한과 러시아 무역경제 및 과학기술협조위원회 임업분과위원회 제28차회의가 16일 평...     안윤석 대기자
# 6   북한이 최근 진행된 한미 해군 연합훈련 기간 강원도 고성항에 두만급(1천500t급)...      유영목 기자
# 7   북한이 16일 만에 탄도미사일을 또다시 발사했다.\n합동참모본보는 "우리 군은 7일...      유영목 기자
# 8   북한이 일본 자위대 구축함의 미국산 토마호크 장거리순항미사일 탑재를 비난했다.\n북...     안윤석 대기자
# 9   북한 평안북도 신의주온실종합농장 건설장에서 방대한 면적의 지대정리와 잔디심기가 마감...     안윤석 대기자
# 10  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
# 11  북한 산림과학연구부문 과학자들이 개발한 국가산림병해충예찰예보체계가 원활히 가동되고 ...     안윤석 대기자
# 12  북한 개성시에서 식물방역소와 돼지종축장 새로 건설했다.\n노동신문은 17일 "개성시...    안윤석  대기자
# 13  북한이 국제축구연맹(FIFA) 2025년 17살 미만(U-17) 월드컵대회에서 16...  SPN 서울평양뉴스
# 14  북한이 "천년숙적 일본의 만고죄악을 폭로단죄하는 역사학부문 토론회'를 12일 사회과...     안윤석 대기자
# 15  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
#
#    publish_date                                                url  category
# 0    2025-11-06  https://www.spnews.co.kr/news/articleView.html...        정치
# 1    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        정치
# 2    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        정치
# 3    2025-11-14  https://www.spnews.co.kr/news/articleView.html...        외교
# 4    2025-11-01  https://www.spnews.co.kr/news/articleView.html...        외교
# 5    2025-10-17  https://www.spnews.co.kr/news/articleView.html...        외교
# 6    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        군사
# 7    2025-11-07  https://www.spnews.co.kr/news/articleView.html...        군사
# 8    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        군사
# 9    2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 10   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 11   2025-11-12  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 12   2025-11-17  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 13   2025-11-16  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 14   2025-11-13  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 15   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업

# %%
# 새 컬럼 추가 (job_cost 컬럼은 임시 컬럼)
new_cols = ["summary", "keywords", "event_title", "event_date", "event_person", "event_org", "event_loc", "job_cost"] # 파싱 문제 일으킨 col명 리스트 수정
for col in new_cols:
    df[col] = None

# 각 row 반복 → LLM 호출 → 결과 입력
for idx, row in df.iterrows():
    print(f"Processing index {idx} ...")

    title = row["title"]
    contents = row["contents"]
    publish_date = row["publish_date"]  # datetime.date

    result, input_tokens, output_tokens = generate_event_info(title, contents, publish_date)

    if result:
        df.at[idx, "summary"] = result.get("summary")
        df.at[idx, "keywords"] = result.get("keywords")
        df.at[idx, "event_title"] = result.get("event_title")
        df.at[idx, "event_date"] = result.get("event_date")
        df.at[idx, "event_person"] = result.get("event_person")
        df.at[idx, "event_org"] = result.get("event_org")
        df.at[idx, "event_loc"] = result.get("event_loc")
        
        # LLM 토큰 비용 컬럼 추가(테스트용)
        df.at[idx, "job_cost"] = sum([(input_tokens * 0.15 / 1_000_000), (output_tokens * 0.60 / 1_000_000)])
    
    print(f'Work Finish ({idx+1}/{len(df)})')
print("전체 작업 완료!")
# Out:
# Processing index 0 ...
# Work Finish (1/16)
# Processing index 1 ...
# Work Finish (2/16)
# Processing index 2 ...
# Work Finish (3/16)
# Processing index 3 ...
# Work Finish (4/16)
# Processing index 4 ...
# Work Finish (5/16)
# Processing index 5 ...
# Work Finish (6/16)
# Processing index 6 ...
# Work Finish (7/16)
# Processing index 7 ...
# Work Finish (8/16)
# Processing index 8 ...
# Work Finish (9/16)
# Processing index 9 ...
# Work Finish (10/16)
# Processing index 10 ...
# Work Finish (11/16)
# Processing index 11 ...
# Work Finish (12/16)
# Processing index 12 ...
# Work Finish (13/16)
# Processing index 13 ...
# Work Finish (14/16)
# Processing index 14 ...
# Work Finish (15/16)
# Processing index 15 ...
# Work Finish (16/16)
# 전체 작업 완료!

# %%
df
# Out:
#                id                                          title  \
# 0   spnews_101049                      北, 김영남 상임위원장 영결식...김정은 참석
# 1   spnews_101366            박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2   spnews_100345    김정은, '신의주온실종합농장' 또 현지지도..."농촌문명의 새로운 경지 개척"
# 3   spnews_101306                 박태성 北 내각총리, 통싸완 폼비한 라오스 외무상 접견
# 4   spnews_100889           북한-러시아, 무역경제 및 과학기술협력 추진 회담...의정서 조인
# 5   spnews_100318               북러 과학기술협조위 임업분과위 회의...벌목공 송출 논의?
# 6   spnews_101377            北, 한미 해군 연합훈련 기간 강원도 고성항에 호위함 추가 배치
# 7   spnews_101097    北, 동해로 탄도미사일 발사...美제재에 '반발 담화' 하루 만에 도발(종합)
# 8   spnews_100356            북한, 일본 자위대 구축함 미국산 '장거리순항미사일' 탑재 비난
# 9   spnews_101404                北, 신의주온실종합농장 건설장 지대정리·잔디심기 마감단계
# 10  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
# 11  spnews_101258                 北, 산림과학연구부문 '국가산림병해충예찰예보체계' 가동
# 12  spnews_101402                          北 개성시, 식물방역소·돼지종축장 신축
# 13  spnews_101369                     北, FIFA U-17 월드컵대회 16강전 진출
# 14  spnews_101272  北, '일본 죄악 폭로단죄 역사학부문 토론회' 개최..."만고죄악, 반드시 결산"
# 15  spnews_101394                       [北 물가] 가을 추수 영향, 곡물가 내림세
#
#                                              contents      author  \
# 0   고(故) 김영남 북한 최고인민회의 상임위원회 위원장 장례식이 5일 평양에서 국장으로...     안윤석 대기자
# 1   박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다.\n노동신...     안윤석 대기자
# 2   김정은 북한 총비서가 17일 마감단계에 들어선 신의주온실종합농장 건설장을 또다시 방...     안윤석 대기자
# 3   박태성 북한 내각총리가 13일 만수대의사당에서 통싸완 폼비한 라오스 외무상을 만났다...     안윤석 대기자
# 4   북한과 러시아가 합의된 다방면적인 쌍무협력계획 이행을 추진하기 위한 회담을 31일 ...     안윤석 대기자
# 5   북한과 러시아 무역경제 및 과학기술협조위원회 임업분과위원회 제28차회의가 16일 평...     안윤석 대기자
# 6   북한이 최근 진행된 한미 해군 연합훈련 기간 강원도 고성항에 두만급(1천500t급)...      유영목 기자
# 7   북한이 16일 만에 탄도미사일을 또다시 발사했다.\n합동참모본보는 "우리 군은 7일...      유영목 기자
# 8   북한이 일본 자위대 구축함의 미국산 토마호크 장거리순항미사일 탑재를 비난했다.\n북...     안윤석 대기자
# 9   북한 평안북도 신의주온실종합농장 건설장에서 방대한 면적의 지대정리와 잔디심기가 마감...     안윤석 대기자
# 10  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
# 11  북한 산림과학연구부문 과학자들이 개발한 국가산림병해충예찰예보체계가 원활히 가동되고 ...     안윤석 대기자
# 12  북한 개성시에서 식물방역소와 돼지종축장 새로 건설했다.\n노동신문은 17일 "개성시...    안윤석  대기자
# 13  북한이 국제축구연맹(FIFA) 2025년 17살 미만(U-17) 월드컵대회에서 16...  SPN 서울평양뉴스
# 14  북한이 "천년숙적 일본의 만고죄악을 폭로단죄하는 역사학부문 토론회'를 12일 사회과...     안윤석 대기자
# 15  북한지역에서 가을 추수가 마무리 되면서 쌀과 옥수수 등 곡물류 가격이 내림세로 돌아...     안윤석 대기자
#
#    publish_date                                                url  category  \
# 0    2025-11-06  https://www.spnews.co.kr/news/articleView.html...        정치
# 1    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        정치
# 2    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        정치
# 3    2025-11-14  https://www.spnews.co.kr/news/articleView.html...        외교
# 4    2025-11-01  https://www.spnews.co.kr/news/articleView.html...        외교
# 5    2025-10-17  https://www.spnews.co.kr/news/articleView.html...        외교
# 6    2025-11-16  https://www.spnews.co.kr/news/articleView.html...        군사
# 7    2025-11-07  https://www.spnews.co.kr/news/articleView.html...        군사
# 8    2025-10-18  https://www.spnews.co.kr/news/articleView.html...        군사
# 9    2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 10   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 11   2025-11-12  https://www.spnews.co.kr/news/articleView.html...     경제/산업
# 12   2025-11-17  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 13   2025-11-16  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 14   2025-11-13  https://www.spnews.co.kr/news/articleView.html...  사회/문화/체육
# 15   2025-11-17  https://www.spnews.co.kr/news/articleView.html...     경제/산업
#
#                                               summary  \
# 0   김영남 북한 최고인민회의 상임위원장 장례식이 평양에서 국장으로 치러졌다. 김정은 총...
# 1   박태성 북한 내각총리가 광산과 발전소 등 경제 여러 부문 현장을 확인했다. 그는 석...
# 2   김정은 총비서가 신의주온실종합농장 건설장을 방문하여 진행 상황을 점검했다. 그는 농...
# 3   박태성 북한 내각총리가 라오스 외무상 통싸완 폼비한을 만났다. 이 자리에는 외무성 ...
# 4   북한과 러시아가 무역경제 및 과학기술협력 강화를 위한 회담을 평양에서 개최했다. 회...
# 5   북한과 러시아의 임업분과위원회 제28차 회의가 평양에서 열렸다. 회의에서는 임업 분...
# 6   북한이 한미 해군 연합훈련 기간 동안 강원도 고성항에 두만급 호위함을 추가 배치했다...
# 7   북한이 16일 만에 동해로 단거리 탄도미사일을 발사했다. 이번 발사는 미국의 대북 ...
# 8   북한이 일본 자위대 구축함의 미국산 토마호크 장거리순항미사일 탑재를 비난했다. 북한...
# 9   북한 신의주온실종합농장에서 지대정리와 잔디심기가 마감단계에 이르고 있다. 군민건설자...
# 10  북한에서 가을 추수가 마무리되면서 쌀과 옥수수 등 곡물류 가격이 하락세를 보이고 있...
# 11  북한의 산림과학연구부문 과학자들이 개발한 국가산림병해충예찰예보체계가 가동되고 있다....
# 12  북한 개성시에서 식물방역소와 돼지종축장이 새로 건설되었다. 개성시식물방역소는 붉은눈...
# 13  북한이 FIFA 2025년 U-17 월드컵대회에서 16강전에 진출했다. 북한팀은 3...
# 14  북한이 일본의 만고죄악을 폭로하는 역사학부문 토론회를 개최했다. 참석자들은 일본 제...
# 15  북한에서 가을 추수가 마무리되면서 쌀과 옥수수 등 곡물류 가격이 하락세를 보이고 있...
#
#                           keywords                          event_title  \
# 0         김영남, 영결식, 김정은, 평양, 애국열사릉                        김영남 상임위원장 영결식
# 1       박태성, 광산, 발전소, 석탄 생산, 비료 생산  박태성 北 내각총리, 광산·발전소 등 경제 여러 부문 현장 확인
# 2   김정은, 신의주온실종합농장, 농촌문명, 건설, 지역경제                       신의주온실종합농장 현지지도
# 3             북한, 라오스, 외무상, 접견, 참배              박태성 북한 내각총리, 라오스 외무상 접견
# 4       북한, 러시아, 무역경제, 과학기술협력, 의정서              북한-러시아 무역경제 및 과학기술협력 회담
# 5              북러, 임업, 벌목공, 송출, 협조                  북러 과학기술협조위 임업분과위 회의
# 6        북한, 호위함, 한미 해군, 연합훈련, 고성항                         북한 호위함 추가 배치
# 7      북한, 탄도미사일, 동해, 대북제재, 이재명 정부                          북한 탄도미사일 발사
# 8            북한, 일본, 자위대, 토마호크, 군사  북한, 일본 자위대 구축함 미국산 '장거리순항미사일' 탑재 비난
# 9        신의주, 온실농장, 지대정리, 잔디심기, 건설                      신의주온실종합농장 건설 진행
# 10          북한, 곡물가, 하락, 가을 추수, 물가                            북한 곡물가 하락
# 11          산림, 병해충, 예찰, 예보체계, 과학화                     국가산림병해충예찰예보체계 가동
# 12       식물방역소, 돼지종축장, 건설, 북한, 개성시                 개성시 식물방역소 및 돼지종축장 신축
# 13       북한, U-17, 월드컵, 16강, 베네수엘라          북한, FIFA U-17 월드컵대회 16강전 진출
# 14          일본, 역사, 토론회, 만고죄악, 문화재                 일본 죄악 폭로단죄 역사학부문 토론회
# 15          북한, 곡물가, 하락, 가을 추수, 물가                            북한 곡물가 하락
#
#     event_date          event_person                          event_org  \
# 0   2025-11-05         김정은, 박태성, 김영남   당 정치국, 국가장의위원회, 최고인민회의 상임위원회, 내각
# 1   2025-11-16                   박태성          북한 내각, 석탄공업성, 남흥청년화학연합기업소
# 2   2025-10-17                   김정은                         군부대, 청년돌격대
# 3   2025-11-13          박태성, 통싸완 폼비한                     북한 내각, 라오스 외무부
# 4   2025-10-31  윤정호, 알렉산드르 코즐로프, 김덕훈  북러 정부간 무역경제 및 과학기술협조위원회, 북한 대외경제성
# 5   2025-10-16         한영호, 그리고리 구세프   북러 무역경제 및 과학기술협조위원회, 공업무역성 임업대표단
# 6   2025-11-11                                             북한 해군, 한미 해군
# 7   2025-11-07                                     합동참모본부, 미 재무부, 미 국무부
# 8   2025-10-18                                               북한, 일본 자위대
# 9   2025-11-17                                                   군민건설자들
# 10  2025-11-15
# 11  2025-11-12                                     김일성종합대학 산림과학부, 산림연구원
# 12  2025-11-17                                        개성시식물방역소, 개성돼지종축장
# 13  2025-11-16                                                     FIFA
# 14  2025-11-12    조희승, 조명철, 김영희, 윤신영          사회과학원, 조선중앙역사박물관, 김일성종합대학
# 15  2025-11-15
#
#    event_loc  job_cost
# 0         평양  0.000251
# 1         북한  0.000254
# 2        신의주  0.000256
# 3     만수대의사당  0.000199
# 4         평양  0.000259
# 5         평양  0.000255
# 6        고성항  0.000228
# 7   북한 평북 대관  0.000249
# 8         일본  0.000246
# 9        신의주  0.000222
# 10        평양  0.000266
# 11        북한  0.000228
# 12       개성시  0.000226
# 13       카타르  0.000184
# 14        북한  0.000268
# 15        평양  0.000267

# %%
df.to_csv('data/test_dataset_llm.tsv', index=False, sep='\t')

# %%
df.to_excel('data/test_dataset_llm.xlsx', index=False)

# %% [markdown]
# ## 테스트 (11.18) - 사과 농장 뉴스

# %%
test_item = ArticleCrawling('https://www.spnews.co.kr/news/articleView.html?idxno=101229').to_dict()

# %%
test_item
# Out:
# {'url': 'https://www.spnews.co.kr/news/articleView.html?idxno=101229',
#  'id': 'spnews_101229',
#  'title': '[북한 경제 단신] 함남 북청군 과일가공공장 개건현대화공사 준공',
#  'author': '안윤석 대기자',
#  'category': '경제/산업',
#  'publish_date': '2025.11.12 07:00',
#  'contents': '북한 과수의 고향인 함경남도 북청군에서 과일가공공장 개건현대화공사를 마무리했다.\n노동신문은 12일\xa0\xa0"수만㎡의 부지에 연건축면적이 1만 수천㎡에 이르는 사무청사와 생산건물들을 개건하고 모든 공정이 자동화, 흐름선화된 과일가공품생산기지를 건설했다"고 보도했다.\n"공장에서는\xa0과일농축즙, 과일단물, 과일살즙음료, 말린과일, 과일가루, 과일단묵생산공정을 완공한데 이어 최근 과일통졸임, 과일단졸임, 과일발효식초생산공정을 간춰 총 9가지에 달하는 과일가공품을 생산할 수 있다"고 소개했다.\n신문은 또 "황해북도농업과학연구소에서 지역의 기상기후적 특성에 맞는 두벌농사다수확재배기술을 개발도입했다"고 전했다.\n"연구소에서 올해 생육기일이 짧으면서도 가뭄견딜성이 강하고 불리한 토양조건에서도 수확고가 높은 다수확품종을 육종해 국가품종으로 등록되게 했으며, 재배기술을 확립했다"고 밝혔다.\n"연구소에서는 새로 육종한 다수확품종을 도내 농촌에 확대도입하고 사리원시와 서흥군, 은파군 등 여러 지역에 연구사들을 파견해 재배기술을 보급일반화하는 사업을 진행했다"고 신문은 덧붙였다.'}

# %%
result, input_tokens, output_tokens =generate_event_info(test_item['title'], test_item['contents'], pd.to_datetime(test_item['publish_date']).date())
result
# Out:
# {'summary': '함경남도 북청군에서 과일가공공장 개건현대화공사가 완료되었다. 이 공장은 자동화된 과일가공품 생산기지로, 총 9가지의 과일가공품을 생산할 수 있다. 또한, 황해북도농업과학연구소는 지역에 맞는 다수확재배기술을 개발하여 농촌에 보급하고 있다.',
#  'event_title': '과일가공공장 개건현대화공사 준공',
#  'event_date': '2025-11-12',
#  'event_person': '',
#  'event_org': '황해북도농업과학연구소',
#  'event_loc': '북청군',
#  'keywords': '과일가공, 현대화, 자동화, 다수확, 농업기술'}
